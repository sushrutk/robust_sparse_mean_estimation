# %%
import numpy as np
import scipy
import robustlib as rl
import importlib as il
from scipy import special
from numpy import linalg as LA
import matplotlib.pyplot as plt
# %matplotlib inline
import mpld3
mpld3.enable_notebook()

# %%
""" Testing stuff """

il.reload(rl)

d, k, eps = 1000, 40, 0.1
m = 10000
params = rl.Params(d=d, k=k, eps=eps, m = m)


model = rl.DenseNoiseModel(-2)
# model = rl.BimodalModel()

print(f"Running on d={d}, k={k}, eps={eps}, m={m}")
inp, S, indicator, tm = model.generate(params)

A = rl.RME(inp)
A.do_plot_linear = True
ans = A.alg(S, indicator)
print(LA.norm(tm - ans))

# err = rl.get_error(f, inp, tm=tm)
# print(f'Error for {f.__name__}: {err}')


# for f in [rl.RME_sp]:
#     err = rl.get_error(f, *inp)
#     print(f'Error for {f.__name__}: {err}')
# Out:
# Running on d=1000, k=40, eps=0.1, m=10000
# Linear filter...
# Filtered out 1124/9991, 136.0 false (0.12 vs 0.1)
# Linear filter...
# Filtered out 180/8867, 180.0 false (1.00 vs 0.1)
# Could not filter
# 0.0711840696922215

# %%
"loss vs sample complexity"

il.reload(rl)

trials = 10
d, k, eps = 1000, 40, 0.1
m_bounds = (50, 8000, 1000)
# model = rl.DenseNoiseModel(-100)

# model = rl.BimodalModel()
model = rl.DenseNoiseModel(-2)
keys = [rl.RME_sp, rl.RME_sp_L, rl.RME] #, rl.NP_sp, rl.RME_sp_L, rl.ransacGaussianMean]
model_params = rl.Params(d=d, k=k, eps=eps)
ylims = (0, 1)

def err(a,b): return LA.norm(a-b)

plot_m_loss = rl.plot(model, model_params, err, keys)
plot_m_loss.setdata('m', m_bounds, trials, ylims)




# Runs_l_samples = rl.RunCollection(rl.sparse_samp_loss, model, model_params, m_bounds, keys)
# Runs_l_samples.run(s)
# Out:
# Linear filter...
# Filtered out 0/46, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/46, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/46, 0.0 false (nan vs 0.1)
# Could not filter
# Linear filter...
# Filtered out 0/46, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/46, 0.0 false (nan vs 0.1)
# Could not filter
# Linear filter...
# Filtered out 2/46, 1.0 false (0.50 vs 0.1)
# Linear filter...
# Filtered out 37/44, 37.0 false (1.00 vs 0.1)
# Could not filter
# Linear filter...
# Filtered out 99/1044, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/945, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/945, 0.0 false (nan vs 0.1)
# Could not filter
# Linear filter...
# Filtered out 99/1044, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/945, 0.0 false (nan vs 0.1)
# Could not filter
# Linear filter...
# Filtered out 105/1044, 6.0 false (0.06 vs 0.1)
# Linear filter...
# Filtered out 278/939, 278.0 false (1.00 vs 0.1)
# Could not filter
# Linear filter...
# Filtered out 197/2042, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/1845, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/1845, 0.0 false (nan vs 0.1)
# Could not filter
# Linear filter...
# Filtered out 197/2042, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/1845, 0.0 false (nan vs 0.1)
# Could not filter
# Linear filter...
# Filtered out 219/2042, 22.0 false (0.10 vs 0.1)
# Linear filter...
# Filtered out 313/1823, 313.0 false (1.00 vs 0.1)
# Could not filter
# Linear filter...
# Filtered out 295/3040, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/2745, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/2745, 0.0 false (nan vs 0.1)
# Could not filter
# Linear filter...
# Filtered out 295/3040, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/2745, 0.0 false (nan vs 0.1)
# Could not filter
# Linear filter...
# Filtered out 332/3040, 37.0 false (0.11 vs 0.1)
# Linear filter...
# Filtered out 301/2708, 301.0 false (1.00 vs 0.1)
# Could not filter
# Linear filter...
# Filtered out 385/4030, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/3645, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/3645, 0.0 false (nan vs 0.1)
# Could not filter
# Linear filter...
# Filtered out 385/4030, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/3645, 0.0 false (nan vs 0.1)
# Could not filter
# Linear filter...
# Filtered out 422/4030, 37.0 false (0.09 vs 0.1)
# Linear filter...
# Filtered out 310/3608, 310.0 false (1.00 vs 0.1)
# Could not filter
# Linear filter...
# Filtered out 490/5035, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/4545, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/4545, 0.0 false (nan vs 0.1)
# Could not filter
# Linear filter...
# Filtered out 490/5035, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/4545, 0.0 false (nan vs 0.1)
# Could not filter
# Linear filter...
# Filtered out 536/5035, 46.0 false (0.09 vs 0.1)
# Linear filter...
# Filtered out 270/4499, 270.0 false (1.00 vs 0.1)
# Could not filter
# Linear filter...
# Filtered out 589/6034, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/5445, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/5445, 0.0 false (nan vs 0.1)
# Could not filter
# Linear filter...
# Filtered out 589/6034, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/5445, 0.0 false (nan vs 0.1)
# Could not filter
# Linear filter...
# Filtered out 643/6034, 54.0 false (0.08 vs 0.1)
# Linear filter...
# Filtered out 282/5391, 282.0 false (1.00 vs 0.1)
# Could not filter
# Linear filter...
# Filtered out 683/7028, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/6345, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/6345, 0.0 false (nan vs 0.1)
# Could not filter
# Linear filter...
# Filtered out 683/7028, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/6345, 0.0 false (nan vs 0.1)
# Could not filter
# Linear filter...
# Filtered out 754/7028, 71.0 false (0.09 vs 0.1)
# Linear filter...
# Filtered out 250/6274, 250.0 false (1.00 vs 0.1)
# Could not filter
# Linear filter...
# Filtered out 0/46, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/46, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 45/46, 44.0 false (0.98 vs 0.1)
# Could not filter
# Linear filter...
# Filtered out 0/46, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/46, 0.0 false (nan vs 0.1)
# Could not filter
# Linear filter...
# Filtered out 1/46, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 36/45, 36.0 false (1.00 vs 0.1)
# Could not filter
# Linear filter...
# Filtered out 89/1034, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/945, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/945, 0.0 false (nan vs 0.1)
# Could not filter
# Linear filter...
# Filtered out 89/1034, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/945, 0.0 false (nan vs 0.1)
# Could not filter
# Linear filter...
# Filtered out 98/1034, 9.0 false (0.09 vs 0.1)
# Linear filter...
# Filtered out 257/936, 257.0 false (1.00 vs 0.1)
# Could not filter
# Linear filter...
# Filtered out 183/2028, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/1845, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/1845, 0.0 false (nan vs 0.1)
# Could not filter
# Linear filter...
# Filtered out 183/2028, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/1845, 0.0 false (nan vs 0.1)
# Could not filter
# Linear filter...
# Filtered out 201/2028, 18.0 false (0.09 vs 0.1)
# Linear filter...
# Filtered out 329/1827, 329.0 false (1.00 vs 0.1)
# Could not filter
# Linear filter...
# Filtered out 291/3036, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/2745, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/2745, 0.0 false (nan vs 0.1)
# Could not filter
# Linear filter...
# Filtered out 291/3036, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/2745, 0.0 false (nan vs 0.1)
# Could not filter
# Linear filter...
# Filtered out 327/3036, 36.0 false (0.11 vs 0.1)
# Linear filter...
# Filtered out 336/2709, 336.0 false (1.00 vs 0.1)
# Could not filter
# Linear filter...
# Filtered out 389/4034, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/3645, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/3645, 0.0 false (nan vs 0.1)
# Could not filter
# Linear filter...
# Filtered out 389/4034, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/3645, 0.0 false (nan vs 0.1)
# Could not filter
# Linear filter...
# Filtered out 429/4034, 40.0 false (0.09 vs 0.1)
# Linear filter...
# Filtered out 306/3605, 306.0 false (1.00 vs 0.1)
# Could not filter
# Linear filter...
# Filtered out 487/5032, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/4545, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/4545, 0.0 false (nan vs 0.1)
# Could not filter
# Linear filter...
# Filtered out 487/5032, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/4545, 0.0 false (nan vs 0.1)
# Could not filter
# Linear filter...
# Filtered out 538/5032, 51.0 false (0.09 vs 0.1)
# Linear filter...
# Filtered out 270/4494, 270.0 false (1.00 vs 0.1)
# Could not filter
# Linear filter...
# Filtered out 588/6033, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/5445, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/5445, 0.0 false (nan vs 0.1)
# Could not filter
# Linear filter...
# Filtered out 588/6033, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/5445, 0.0 false (nan vs 0.1)
# Could not filter
# Linear filter...
# Filtered out 650/6033, 62.0 false (0.10 vs 0.1)
# Linear filter...
# Filtered out 288/5383, 288.0 false (1.00 vs 0.1)
# Could not filter
# Linear filter...
# Filtered out 686/7031, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/6345, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/6345, 0.0 false (nan vs 0.1)
# Could not filter
# Linear filter...
# Filtered out 686/7031, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/6345, 0.0 false (nan vs 0.1)
# Could not filter
# Linear filter...
# Filtered out 747/7031, 61.0 false (0.08 vs 0.1)
# Linear filter...
# Filtered out 227/6284, 227.0 false (1.00 vs 0.1)
# Could not filter
# Linear filter...
# Filtered out 0/46, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/46, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/46, 0.0 false (nan vs 0.1)
# Could not filter
# Linear filter...
# Filtered out 0/46, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/46, 0.0 false (nan vs 0.1)
# Could not filter
# Linear filter...
# Filtered out 5/46, 4.0 false (0.80 vs 0.1)
# Linear filter...
# Filtered out 28/41, 28.0 false (1.00 vs 0.1)
# Could not filter
# Linear filter...
# Filtered out 93/1038, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/945, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/945, 0.0 false (nan vs 0.1)
# Could not filter
# Linear filter...
# Filtered out 93/1038, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/945, 0.0 false (nan vs 0.1)
# Could not filter
# Linear filter...
# Filtered out 105/1038, 12.0 false (0.11 vs 0.1)
# Linear filter...
# Filtered out 266/933, 266.0 false (1.00 vs 0.1)
# Could not filter
# Linear filter...
# Filtered out 190/2035, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/1845, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/1845, 0.0 false (nan vs 0.1)
# Could not filter
# Linear filter...
# Filtered out 190/2035, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/1845, 0.0 false (nan vs 0.1)
# Could not filter
# Linear filter...
# Filtered out 214/2035, 24.0 false (0.11 vs 0.1)
# Linear filter...
# Filtered out 303/1821, 303.0 false (1.00 vs 0.1)
# Could not filter
# Linear filter...
# Filtered out 286/3031, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/2745, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/2745, 0.0 false (nan vs 0.1)
# Could not filter
# Linear filter...
# Filtered out 286/3031, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/2745, 0.0 false (nan vs 0.1)
# Could not filter
# Linear filter...
# Filtered out 304/3031, 18.0 false (0.06 vs 0.1)
# Linear filter...
# Filtered out 291/2727, 291.0 false (1.00 vs 0.1)
# Could not filter
# Linear filter...
# Filtered out 395/4040, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/3645, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/3645, 0.0 false (nan vs 0.1)
# Could not filter
# Linear filter...
# Filtered out 395/4040, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/3645, 0.0 false (nan vs 0.1)
# Could not filter
# Linear filter...
# Filtered out 442/4040, 47.0 false (0.11 vs 0.1)
# Linear filter...
# Filtered out 296/3598, 296.0 false (1.00 vs 0.1)
# Could not filter
# Linear filter...
# Filtered out 487/5032, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/4545, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/4545, 0.0 false (nan vs 0.1)
# Could not filter
# Linear filter...
# Filtered out 487/5032, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/4545, 0.0 false (nan vs 0.1)
# Could not filter
# Linear filter...
# Filtered out 541/5032, 54.0 false (0.10 vs 0.1)
# Linear filter...
# Filtered out 273/4491, 273.0 false (1.00 vs 0.1)
# Could not filter
# Linear filter...
# Filtered out 591/6036, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/5445, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/5445, 0.0 false (nan vs 0.1)
# Could not filter
# Linear filter...
# Filtered out 591/6036, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/5445, 0.0 false (nan vs 0.1)
# Could not filter
# Linear filter...
# Filtered out 641/6036, 50.0 false (0.08 vs 0.1)
# Linear filter...
# Filtered out 308/5395, 308.0 false (1.00 vs 0.1)
# Could not filter
# Linear filter...
# Filtered out 682/7027, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/6345, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/6345, 0.0 false (nan vs 0.1)
# Could not filter
# Linear filter...
# Filtered out 682/7027, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/6345, 0.0 false (nan vs 0.1)
# Could not filter
# Linear filter...
# Filtered out 754/7027, 72.0 false (0.10 vs 0.1)
# Linear filter...
# Filtered out 273/6273, 273.0 false (1.00 vs 0.1)
# Could not filter
# Linear filter...
# Filtered out 4/49, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 3/45, 3.0 false (1.00 vs 0.1)
# Quadratic filter...
# Filtered out 0/42, 0.0 false (nan vs 0.1)
# Could not filter
# Linear filter...
# Filtered out 4/49, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 3/45, 3.0 false (1.00 vs 0.1)
# Could not filter
# Linear filter...
# Filtered out 4/49, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 33/45, 33.0 false (1.00 vs 0.1)
# Could not filter
# Linear filter...
# Filtered out 96/1041, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/945, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/945, 0.0 false (nan vs 0.1)
# Could not filter
# Linear filter...
# Filtered out 96/1041, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/945, 0.0 false (nan vs 0.1)
# Could not filter
# Linear filter...
# Filtered out 103/1041, 7.0 false (0.07 vs 0.1)
# Linear filter...
# Filtered out 253/938, 253.0 false (1.00 vs 0.1)
# Could not filter
# Linear filter...
# Filtered out 190/2035, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/1845, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/1845, 0.0 false (nan vs 0.1)
# Could not filter
# Linear filter...
# Filtered out 190/2035, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/1845, 0.0 false (nan vs 0.1)
# Could not filter
# Linear filter...
# Filtered out 211/2035, 21.0 false (0.10 vs 0.1)
# Linear filter...
# Filtered out 306/1824, 306.0 false (1.00 vs 0.1)
# Could not filter
# Linear filter...
# Filtered out 286/3031, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/2745, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/2745, 0.0 false (nan vs 0.1)
# Could not filter
# Linear filter...
# Filtered out 286/3031, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/2745, 0.0 false (nan vs 0.1)
# Could not filter
# Linear filter...
# Filtered out 317/3031, 31.0 false (0.10 vs 0.1)
# Linear filter...
# Filtered out 314/2714, 314.0 false (1.00 vs 0.1)
# Could not filter
# Linear filter...
# Filtered out 391/4036, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/3645, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/3645, 0.0 false (nan vs 0.1)
# Could not filter
# Linear filter...
# Filtered out 391/4036, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/3645, 0.0 false (nan vs 0.1)
# Could not filter
# Linear filter...
# Filtered out 439/4036, 48.0 false (0.11 vs 0.1)
# Linear filter...
# Filtered out 305/3597, 305.0 false (1.00 vs 0.1)
# Could not filter
# Linear filter...
# Filtered out 485/5030, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/4545, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/4545, 0.0 false (nan vs 0.1)
# Could not filter
# Linear filter...
# Filtered out 485/5030, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/4545, 0.0 false (nan vs 0.1)
# Could not filter
# Linear filter...
# Filtered out 535/5030, 50.0 false (0.09 vs 0.1)
# Linear filter...
# Filtered out 302/4495, 302.0 false (1.00 vs 0.1)
# Could not filter
# Linear filter...
# Filtered out 578/6023, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/5445, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/5445, 0.0 false (nan vs 0.1)
# Could not filter
# Linear filter...
# Filtered out 578/6023, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/5445, 0.0 false (nan vs 0.1)
# Could not filter
# Linear filter...
# Filtered out 633/6023, 55.0 false (0.09 vs 0.1)
# Linear filter...
# Filtered out 272/5390, 272.0 false (1.00 vs 0.1)
# Could not filter
# Linear filter...
# Filtered out 684/7029, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/6345, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/6345, 0.0 false (nan vs 0.1)
# Could not filter
# Linear filter...
# Filtered out 684/7029, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/6345, 0.0 false (nan vs 0.1)
# Could not filter
# Linear filter...
# Filtered out 763/7029, 79.0 false (0.10 vs 0.1)
# Linear filter...
# Filtered out 267/6266, 267.0 false (1.00 vs 0.1)
# Could not filter
# Linear filter...
# Filtered out 2/47, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 5/45, 5.0 false (1.00 vs 0.1)
# Quadratic filter...
# Filtered out 0/40, 0.0 false (nan vs 0.1)
# Could not filter
# Linear filter...
# Filtered out 2/47, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 5/45, 5.0 false (1.00 vs 0.1)
# Could not filter
# Linear filter...
# Filtered out 3/47, 1.0 false (0.33 vs 0.1)
# Linear filter...
# Filtered out 35/44, 35.0 false (1.00 vs 0.1)
# Could not filter
# Linear filter...
# Filtered out 93/1038, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/945, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/945, 0.0 false (nan vs 0.1)
# Could not filter
# Linear filter...
# Filtered out 93/1038, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/945, 0.0 false (nan vs 0.1)
# Could not filter
# Linear filter...
# Filtered out 105/1038, 12.0 false (0.11 vs 0.1)
# Linear filter...
# Filtered out 251/933, 251.0 false (1.00 vs 0.1)
# Could not filter
# Linear filter...
# Filtered out 197/2042, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/1845, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/1845, 0.0 false (nan vs 0.1)
# Could not filter
# Linear filter...
# Filtered out 197/2042, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/1845, 0.0 false (nan vs 0.1)
# Could not filter
# Linear filter...
# Filtered out 222/2042, 25.0 false (0.11 vs 0.1)
# Linear filter...
# Filtered out 306/1820, 306.0 false (1.00 vs 0.1)
# Could not filter
# Linear filter...
# Filtered out 292/3037, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/2745, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/2745, 0.0 false (nan vs 0.1)
# Could not filter
# Linear filter...
# Filtered out 292/3037, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/2745, 0.0 false (nan vs 0.1)
# Could not filter
# Linear filter...
# Filtered out 312/3037, 20.0 false (0.06 vs 0.1)
# Linear filter...
# Filtered out 336/2725, 336.0 false (1.00 vs 0.1)
# Could not filter
# Linear filter...
# Filtered out 389/4034, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/3645, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/3645, 0.0 false (nan vs 0.1)
# Could not filter
# Linear filter...
# Filtered out 389/4034, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/3645, 0.0 false (nan vs 0.1)
# Could not filter
# Linear filter...
# Filtered out 426/4034, 37.0 false (0.09 vs 0.1)
# Linear filter...
# Filtered out 331/3608, 331.0 false (1.00 vs 0.1)
# Could not filter
# Linear filter...
# Filtered out 490/5035, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/4545, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/4545, 0.0 false (nan vs 0.1)
# Could not filter
# Linear filter...
# Filtered out 490/5035, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/4545, 0.0 false (nan vs 0.1)
# Could not filter
# Linear filter...
# Filtered out 534/5035, 44.0 false (0.08 vs 0.1)
# Linear filter...
# Filtered out 265/4501, 265.0 false (1.00 vs 0.1)
# Could not filter
# Linear filter...
# Filtered out 586/6031, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/5445, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/5445, 0.0 false (nan vs 0.1)
# Could not filter
# Linear filter...
# Filtered out 586/6031, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/5445, 0.0 false (nan vs 0.1)
# Could not filter
# Linear filter...
# Filtered out 653/6031, 67.0 false (0.10 vs 0.1)
# Linear filter...
# Filtered out 266/5378, 266.0 false (1.00 vs 0.1)
# Could not filter
# Linear filter...
# Filtered out 683/7028, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/6345, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/6345, 0.0 false (nan vs 0.1)
# Could not filter
# Linear filter...
# Filtered out 683/7028, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/6345, 0.0 false (nan vs 0.1)
# Could not filter
# Linear filter...
# Filtered out 758/7028, 75.0 false (0.10 vs 0.1)
# Linear filter...
# Filtered out 245/6270, 245.0 false (1.00 vs 0.1)
# Could not filter
# Linear filter...
# Filtered out 3/48, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 2/45, 2.0 false (1.00 vs 0.1)
# Quadratic filter...
# Filtered out 0/43, 0.0 false (nan vs 0.1)
# Could not filter
# Linear filter...
# Filtered out 3/48, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 2/45, 2.0 false (1.00 vs 0.1)
# Could not filter
# Linear filter...
# Filtered out 4/48, 1.0 false (0.25 vs 0.1)
# Linear filter...
# Filtered out 27/44, 27.0 false (1.00 vs 0.1)
# Could not filter
# Linear filter...
# Filtered out 94/1039, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/945, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/945, 0.0 false (nan vs 0.1)
# Could not filter
# Linear filter...
# Filtered out 94/1039, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/945, 0.0 false (nan vs 0.1)
# Could not filter
# Linear filter...
# Filtered out 107/1039, 13.0 false (0.12 vs 0.1)
# Linear filter...
# Filtered out 259/932, 259.0 false (1.00 vs 0.1)
# Could not filter
# Linear filter...
# Filtered out 193/2038, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/1845, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/1845, 0.0 false (nan vs 0.1)
# Could not filter
# Linear filter...
# Filtered out 193/2038, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/1845, 0.0 false (nan vs 0.1)
# Could not filter
# Linear filter...
# Filtered out 218/2038, 25.0 false (0.11 vs 0.1)
# Linear filter...
# Filtered out 315/1820, 315.0 false (1.00 vs 0.1)
# Could not filter
# Linear filter...
# Filtered out 284/3029, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/2745, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/2745, 0.0 false (nan vs 0.1)
# Could not filter
# Linear filter...
# Filtered out 284/3029, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/2745, 0.0 false (nan vs 0.1)
# Could not filter
# Linear filter...
# Filtered out 307/3029, 23.0 false (0.07 vs 0.1)
# Linear filter...
# Filtered out 304/2722, 304.0 false (1.00 vs 0.1)
# Could not filter
# Linear filter...
# Filtered out 391/4036, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/3645, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/3645, 0.0 false (nan vs 0.1)
# Could not filter
# Linear filter...
# Filtered out 391/4036, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/3645, 0.0 false (nan vs 0.1)
# Could not filter
# Linear filter...
# Filtered out 420/4036, 29.0 false (0.07 vs 0.1)
# Linear filter...
# Filtered out 304/3616, 304.0 false (1.00 vs 0.1)
# Could not filter
# Linear filter...
# Filtered out 491/5036, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/4545, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/4545, 0.0 false (nan vs 0.1)
# Could not filter
# Linear filter...
# Filtered out 491/5036, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/4545, 0.0 false (nan vs 0.1)
# Could not filter
# Linear filter...
# Filtered out 548/5036, 57.0 false (0.10 vs 0.1)
# Linear filter...
# Filtered out 307/4488, 307.0 false (1.00 vs 0.1)
# Could not filter
# Linear filter...
# Filtered out 583/6028, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/5445, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/5445, 0.0 false (nan vs 0.1)
# Could not filter
# Linear filter...
# Filtered out 583/6028, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/5445, 0.0 false (nan vs 0.1)
# Could not filter
# Linear filter...
# Filtered out 652/6028, 69.0 false (0.11 vs 0.1)
# Linear filter...
# Filtered out 254/5376, 254.0 false (1.00 vs 0.1)
# Could not filter
# Linear filter...
# Filtered out 681/7026, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/6345, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/6345, 0.0 false (nan vs 0.1)
# Could not filter
# Linear filter...
# Filtered out 681/7026, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/6345, 0.0 false (nan vs 0.1)
# Could not filter
# Linear filter...
# Filtered out 756/7026, 75.0 false (0.10 vs 0.1)
# Linear filter...
# Filtered out 249/6270, 249.0 false (1.00 vs 0.1)
# Could not filter
# Linear filter...
# Filtered out 2/47, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/45, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/45, 0.0 false (nan vs 0.1)
# Could not filter
# Linear filter...
# Filtered out 2/47, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/45, 0.0 false (nan vs 0.1)
# Could not filter
# Linear filter...
# Filtered out 2/47, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 35/45, 35.0 false (1.00 vs 0.1)
# Could not filter
# Linear filter...
# Filtered out 91/1036, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/945, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/945, 0.0 false (nan vs 0.1)
# Could not filter
# Linear filter...
# Filtered out 91/1036, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/945, 0.0 false (nan vs 0.1)
# Could not filter
# Linear filter...
# Filtered out 102/1036, 11.0 false (0.11 vs 0.1)
# Linear filter...
# Filtered out 257/934, 257.0 false (1.00 vs 0.1)
# Could not filter
# Linear filter...
# Filtered out 190/2035, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/1845, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/1845, 0.0 false (nan vs 0.1)
# Could not filter
# Linear filter...
# Filtered out 190/2035, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/1845, 0.0 false (nan vs 0.1)
# Could not filter
# Linear filter...
# Filtered out 218/2035, 28.0 false (0.13 vs 0.1)
# Linear filter...
# Filtered out 291/1817, 291.0 false (1.00 vs 0.1)
# Could not filter
# Linear filter...
# Filtered out 287/3032, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/2745, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/2745, 0.0 false (nan vs 0.1)
# Could not filter
# Linear filter...
# Filtered out 287/3032, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/2745, 0.0 false (nan vs 0.1)
# Could not filter
# Linear filter...
# Filtered out 322/3032, 35.0 false (0.11 vs 0.1)
# Linear filter...
# Filtered out 313/2710, 313.0 false (1.00 vs 0.1)
# Could not filter
# Linear filter...
# Filtered out 386/4031, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/3645, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/3645, 0.0 false (nan vs 0.1)
# Could not filter
# Linear filter...
# Filtered out 386/4031, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/3645, 0.0 false (nan vs 0.1)
# Could not filter
# Linear filter...
# Filtered out 432/4031, 46.0 false (0.11 vs 0.1)
# Linear filter...
# Filtered out 273/3599, 273.0 false (1.00 vs 0.1)
# Could not filter
# Linear filter...
# Filtered out 485/5030, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/4545, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/4545, 0.0 false (nan vs 0.1)
# Could not filter
# Linear filter...
# Filtered out 485/5030, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/4545, 0.0 false (nan vs 0.1)
# Could not filter
# Linear filter...
# Filtered out 535/5030, 50.0 false (0.09 vs 0.1)
# Linear filter...
# Filtered out 325/4495, 325.0 false (1.00 vs 0.1)
# Could not filter
# Linear filter...
# Filtered out 582/6027, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/5445, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/5445, 0.0 false (nan vs 0.1)
# Could not filter
# Linear filter...
# Filtered out 582/6027, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/5445, 0.0 false (nan vs 0.1)
# Could not filter
# Linear filter...
# Filtered out 648/6027, 66.0 false (0.10 vs 0.1)
# Linear filter...
# Filtered out 290/5379, 290.0 false (1.00 vs 0.1)
# Could not filter
# Linear filter...
# Filtered out 681/7026, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/6345, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/6345, 0.0 false (nan vs 0.1)
# Could not filter
# Linear filter...
# Filtered out 681/7026, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/6345, 0.0 false (nan vs 0.1)
# Could not filter
# Linear filter...
# Filtered out 763/7026, 82.0 false (0.11 vs 0.1)
# Linear filter...
# Filtered out 305/6263, 305.0 false (1.00 vs 0.1)
# Could not filter
# Linear filter...
# Filtered out 2/47, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/45, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/45, 0.0 false (nan vs 0.1)
# Could not filter
# Linear filter...
# Filtered out 2/47, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/45, 0.0 false (nan vs 0.1)
# Could not filter
# Linear filter...
# Filtered out 4/47, 2.0 false (0.50 vs 0.1)
# Linear filter...
# Filtered out 35/43, 35.0 false (1.00 vs 0.1)
# Could not filter
# Linear filter...
# Filtered out 95/1040, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/945, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/945, 0.0 false (nan vs 0.1)
# Could not filter
# Linear filter...
# Filtered out 95/1040, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/945, 0.0 false (nan vs 0.1)
# Could not filter
# Linear filter...
# Filtered out 102/1040, 7.0 false (0.07 vs 0.1)
# Linear filter...
# Filtered out 268/938, 268.0 false (1.00 vs 0.1)
# Could not filter
# Linear filter...
# Filtered out 191/2036, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/1845, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/1845, 0.0 false (nan vs 0.1)
# Could not filter
# Linear filter...
# Filtered out 191/2036, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/1845, 0.0 false (nan vs 0.1)
# Could not filter
# Linear filter...
# Filtered out 216/2036, 25.0 false (0.12 vs 0.1)
# Linear filter...
# Filtered out 326/1820, 326.0 false (1.00 vs 0.1)
# Could not filter
# Linear filter...
# Filtered out 287/3032, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/2745, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/2745, 0.0 false (nan vs 0.1)
# Could not filter
# Linear filter...
# Filtered out 287/3032, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/2745, 0.0 false (nan vs 0.1)
# Could not filter
# Linear filter...
# Filtered out 313/3032, 26.0 false (0.08 vs 0.1)
# Linear filter...
# Filtered out 328/2719, 328.0 false (1.00 vs 0.1)
# Could not filter
# Linear filter...
# Filtered out 382/4027, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/3645, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/3645, 0.0 false (nan vs 0.1)
# Could not filter
# Linear filter...
# Filtered out 382/4027, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/3645, 0.0 false (nan vs 0.1)
# Could not filter
# Linear filter...
# Filtered out 413/4027, 31.0 false (0.08 vs 0.1)
# Linear filter...
# Filtered out 324/3614, 324.0 false (1.00 vs 0.1)
# Could not filter
# Linear filter...
# Filtered out 483/5028, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/4545, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/4545, 0.0 false (nan vs 0.1)
# Could not filter
# Linear filter...
# Filtered out 483/5028, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/4545, 0.0 false (nan vs 0.1)
# Could not filter
# Linear filter...
# Filtered out 551/5028, 68.0 false (0.12 vs 0.1)
# Linear filter...
# Filtered out 283/4477, 283.0 false (1.00 vs 0.1)
# Could not filter
# Linear filter...
# Filtered out 588/6032, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/5444, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/5444, 0.0 false (nan vs 0.1)
# Could not filter
# Linear filter...
# Filtered out 588/6032, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/5444, 0.0 false (nan vs 0.1)
# Could not filter
# Linear filter...
# Filtered out 650/6032, 62.0 false (0.10 vs 0.1)
# Linear filter...
# Filtered out 255/5382, 255.0 false (1.00 vs 0.1)
# Could not filter
# Linear filter...
# Filtered out 682/7027, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/6345, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/6345, 0.0 false (nan vs 0.1)
# Could not filter
# Linear filter...
# Filtered out 682/7027, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/6345, 0.0 false (nan vs 0.1)
# Could not filter
# Linear filter...
# Filtered out 768/7027, 86.0 false (0.11 vs 0.1)
# Linear filter...
# Filtered out 229/6259, 229.0 false (1.00 vs 0.1)
# Could not filter
# Linear filter...
# Filtered out 0/45, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/45, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/45, 0.0 false (nan vs 0.1)
# Could not filter
# Linear filter...
# Filtered out 0/45, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/45, 0.0 false (nan vs 0.1)
# Could not filter
# Linear filter...
# Filtered out 1/45, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 28/44, 28.0 false (1.00 vs 0.1)
# Could not filter
# Linear filter...
# Filtered out 94/1039, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/945, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/945, 0.0 false (nan vs 0.1)
# Could not filter
# Linear filter...
# Filtered out 94/1039, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/945, 0.0 false (nan vs 0.1)
# Could not filter
# Linear filter...
# Filtered out 100/1039, 6.0 false (0.06 vs 0.1)
# Linear filter...
# Filtered out 260/939, 260.0 false (1.00 vs 0.1)
# Could not filter
# Linear filter...
# Filtered out 186/2031, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/1845, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/1845, 0.0 false (nan vs 0.1)
# Could not filter
# Linear filter...
# Filtered out 186/2031, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/1845, 0.0 false (nan vs 0.1)
# Could not filter
# Linear filter...
# Filtered out 212/2031, 26.0 false (0.12 vs 0.1)
# Linear filter...
# Filtered out 310/1819, 310.0 false (1.00 vs 0.1)
# Could not filter
# Linear filter...
# Filtered out 289/3034, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/2745, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/2745, 0.0 false (nan vs 0.1)
# Could not filter
# Linear filter...
# Filtered out 289/3034, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/2745, 0.0 false (nan vs 0.1)
# Could not filter
# Linear filter...
# Filtered out 323/3034, 34.0 false (0.11 vs 0.1)
# Linear filter...
# Filtered out 283/2711, 283.0 false (1.00 vs 0.1)
# Could not filter
# Linear filter...
# Filtered out 383/4028, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/3645, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/3645, 0.0 false (nan vs 0.1)
# Could not filter
# Linear filter...
# Filtered out 383/4028, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/3645, 0.0 false (nan vs 0.1)
# Could not filter
# Linear filter...
# Filtered out 414/4028, 31.0 false (0.07 vs 0.1)
# Linear filter...
# Filtered out 304/3614, 304.0 false (1.00 vs 0.1)
# Could not filter
# Linear filter...
# Filtered out 489/5034, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/4545, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/4545, 0.0 false (nan vs 0.1)
# Could not filter
# Linear filter...
# Filtered out 489/5034, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/4545, 0.0 false (nan vs 0.1)
# Could not filter
# Linear filter...
# Filtered out 545/5034, 56.0 false (0.10 vs 0.1)
# Linear filter...
# Filtered out 282/4489, 282.0 false (1.00 vs 0.1)
# Could not filter
# Linear filter...
# Filtered out 583/6028, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/5445, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/5445, 0.0 false (nan vs 0.1)
# Could not filter
# Linear filter...
# Filtered out 583/6028, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/5445, 0.0 false (nan vs 0.1)
# Could not filter
# Linear filter...
# Filtered out 638/6028, 55.0 false (0.09 vs 0.1)
# Linear filter...
# Filtered out 247/5390, 247.0 false (1.00 vs 0.1)
# Could not filter
# Linear filter...
# Filtered out 679/7024, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/6345, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/6345, 0.0 false (nan vs 0.1)
# Could not filter
# Linear filter...
# Filtered out 679/7024, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/6345, 0.0 false (nan vs 0.1)
# Could not filter
# Linear filter...
# Filtered out 743/7024, 64.0 false (0.09 vs 0.1)
# Linear filter...
# Filtered out 260/6281, 260.0 false (1.00 vs 0.1)
# Could not filter
# Linear filter...
# Filtered out 2/47, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 3/45, 3.0 false (1.00 vs 0.1)
# Quadratic filter...
# Filtered out 0/42, 0.0 false (nan vs 0.1)
# Could not filter
# Linear filter...
# Filtered out 2/47, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 3/45, 3.0 false (1.00 vs 0.1)
# Could not filter
# Linear filter...
# Filtered out 4/47, 2.0 false (0.50 vs 0.1)
# Linear filter...
# Filtered out 33/43, 33.0 false (1.00 vs 0.1)
# Could not filter
# Linear filter...
# Filtered out 90/1035, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/945, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/945, 0.0 false (nan vs 0.1)
# Could not filter
# Linear filter...
# Filtered out 90/1035, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/945, 0.0 false (nan vs 0.1)
# Could not filter
# Linear filter...
# Filtered out 102/1035, 12.0 false (0.12 vs 0.1)
# Linear filter...
# Filtered out 238/933, 238.0 false (1.00 vs 0.1)
# Could not filter
# Linear filter...
# Filtered out 188/2033, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/1845, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/1845, 0.0 false (nan vs 0.1)
# Could not filter
# Linear filter...
# Filtered out 188/2033, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/1845, 0.0 false (nan vs 0.1)
# Could not filter
# Linear filter...
# Filtered out 215/2033, 27.0 false (0.13 vs 0.1)
# Linear filter...
# Filtered out 317/1818, 317.0 false (1.00 vs 0.1)
# Could not filter
# Linear filter...
# Filtered out 286/3031, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/2745, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/2745, 0.0 false (nan vs 0.1)
# Could not filter
# Linear filter...
# Filtered out 286/3031, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/2745, 0.0 false (nan vs 0.1)
# Could not filter
# Linear filter...
# Filtered out 325/3031, 39.0 false (0.12 vs 0.1)
# Linear filter...
# Filtered out 305/2706, 305.0 false (1.00 vs 0.1)
# Could not filter
# Linear filter...
# Filtered out 390/4035, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/3645, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/3645, 0.0 false (nan vs 0.1)
# Could not filter
# Linear filter...
# Filtered out 390/4035, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/3645, 0.0 false (nan vs 0.1)
# Could not filter
# Linear filter...
# Filtered out 415/4035, 25.0 false (0.06 vs 0.1)
# Linear filter...
# Filtered out 313/3620, 313.0 false (1.00 vs 0.1)
# Could not filter
# Linear filter...
# Filtered out 490/5035, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/4545, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/4545, 0.0 false (nan vs 0.1)
# Could not filter
# Linear filter...
# Filtered out 490/5035, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/4545, 0.0 false (nan vs 0.1)
# Could not filter
# Linear filter...
# Filtered out 526/5035, 36.0 false (0.07 vs 0.1)
# Linear filter...
# Filtered out 250/4509, 250.0 false (1.00 vs 0.1)
# Could not filter
# Linear filter...
# Filtered out 591/6036, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/5445, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/5445, 0.0 false (nan vs 0.1)
# Could not filter
# Linear filter...
# Filtered out 591/6036, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/5445, 0.0 false (nan vs 0.1)
# Could not filter
# Linear filter...
# Filtered out 646/6036, 55.0 false (0.09 vs 0.1)
# Linear filter...
# Filtered out 264/5390, 264.0 false (1.00 vs 0.1)
# Could not filter
# Linear filter...
# Filtered out 678/7023, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/6345, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/6345, 0.0 false (nan vs 0.1)
# Could not filter
# Linear filter...
# Filtered out 678/7023, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/6345, 0.0 false (nan vs 0.1)
# Could not filter
# Linear filter...
# Filtered out 765/7023, 87.0 false (0.11 vs 0.1)
# Linear filter...
# Filtered out 239/6258, 239.0 false (1.00 vs 0.1)
# Could not filter

# %%
il.reload(rl)

plot_m_loss.plotxy('m', m_bounds, (0, 1))
# Out:
# <style>
#
# </style>
#
# <div id="fig_el53871348238368968739657591"></div>
# <script>
# function mpld3_load_lib(url, callback){
#   var s = document.createElement('script');
#   s.src = url;
#   s.async = true;
#   s.onreadystatechange = s.onload = callback;
#   s.onerror = function(){console.warn("failed to load library " + url);};
#   document.getElementsByTagName("head")[0].appendChild(s);
# }
#
# if(typeof(mpld3) !== "undefined" && mpld3._mpld3IsLoaded){
#    // already loaded: just create the figure
#    !function(mpld3){
#
#        mpld3.draw_figure("fig_el53871348238368968739657591", {"width": 432.0, "height": 288.0, "axes": [], "data": {}, "id": "el5387134823836896", "plugins": [{"type": "reset"}, {"type": "zoom", "button": true, "enabled": false}, {"type": "boxzoom", "button": true, "enabled": false}]});
#    }(mpld3);
# }else if(typeof define === "function" && define.amd){
#    // require.js is available: use it to load d3/mpld3
#    require.config({paths: {d3: "https://mpld3.github.io/js/d3.v3.min"}});
#    require(["d3"], function(d3){
#       window.d3 = d3;
#       mpld3_load_lib("https://mpld3.github.io/js/mpld3.v0.3.1.dev1.js", function(){
#
#          mpld3.draw_figure("fig_el53871348238368968739657591", {"width": 432.0, "height": 288.0, "axes": [], "data": {}, "id": "el5387134823836896", "plugins": [{"type": "reset"}, {"type": "zoom", "button": true, "enabled": false}, {"type": "boxzoom", "button": true, "enabled": false}]});
#       });
#     });
# }else{
#     // require.js not available: dynamically load d3 & mpld3
#     mpld3_load_lib("https://mpld3.github.io/js/d3.v3.min.js", function(){
#          mpld3_load_lib("https://mpld3.github.io/js/mpld3.v0.3.1.dev1.js", function(){
#
#                  mpld3.draw_figure("fig_el53871348238368968739657591", {"width": 432.0, "height": 288.0, "axes": [], "data": {}, "id": "el5387134823836896", "plugins": [{"type": "reset"}, {"type": "zoom", "button": true, "enabled": false}, {"type": "boxzoom", "button": true, "enabled": false}]});
#             })
#          });
# }
# </script>

# %%
"sparsity vs sample complexity for RME_sp"

il.reload(rl)

d, eps = 100, 0.1
params = rl.Params(d=d, eps=eps)
trials = 5

model = rl.BimodalModel()

print(f"Running on d={d}, eps={eps}, m={m}")
inp, S, indicator, tm = model.generate(params)

keys = [rl.RME_sp]
ylims = (0, 100)
k_bounds = (1, 60, 1)

plot_m_loss = rl.plot(model, params, err, keys)
plot_m_loss.setdata('k', k_bounds, trials, ylims, y_is_m = True, mrange = (2,2))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-dbf4cb1e4c3a> in <module>
#       9 model = rl.BimodalModel()
#      10
# ---> 11 print(f"Running on d={d}, eps={eps}, m={m}")
#      12 inp, S, indicator, tm = model.generate(params)
#      13
#
# NameError: name 'm' is not defined

# %%
plot_m_loss.plotxy('k', k_bounds, (0,100))

# %%
"dimension vs sample complexity"
il.reload(rl)

k, eps = 3, 0.1
params = rl.Params(k=k, eps=eps)
trials = 5

model = rl.BimodalModel()

print(f"Running on k={k}, eps={eps}")

keys = [rl.RME_sp]
ylims = (0, 100)
def err(a,b): return LA.norm(a-b)

d_bounds = ((k+2), 60, 10)

plot_m_loss = rl.plot(model, params, err, keys)
plot_m_loss.setdata('d', d_bounds, trials, ylims, y_is_m = True, mrange = (2,2))
# Out:
# Running on k=3, eps=0.1
# 5
# No points remaining.
# VNEW  1.7320508075688772 m  2 xvar  5 count 0
# Linear filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Neither filter filtered anything.
# VNEW  2.2236563547752377 m  2 xvar  5 count 0
# Linear filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Neither filter filtered anything.
# VNEW  2.2721605974913253 m  2 xvar  5 count 0
# Linear filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Neither filter filtered anything.
# VNEW  1.62616552793746 m  2 xvar  5 count 0
# Linear filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Neither filter filtered anything.
# VNEW  1.715401359942563 m  2 xvar  5 count 0
# Linear filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Neither filter filtered anything.
# VNEW  1.4272206471026492 m  2 xvar  5 count 0
# Linear filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Neither filter filtered anything.
# VNEW  1.7272659575218572 m  2 xvar  5 count 0
# Linear filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Neither filter filtered anything.
# VNEW  1.308566941177465 m  2 xvar  5 count 0
# Linear filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Neither filter filtered anything.
# VNEW  3.2101450333791597 m  2 xvar  5 count 0
# Linear filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Neither filter filtered anything.
# VNEW  1.5682714245604772 m  2 xvar  5 count 0
# Linear filter...
# Filtered out 0/4, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/4, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/4, 0.0 false (nan vs 0.1)
# Neither filter filtered anything.
# VNEW  1.7070293744261915 m  4 xvar  5 count 0
# Linear filter...
# Filtered out 0/4, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/4, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/4, 0.0 false (nan vs 0.1)
# Neither filter filtered anything.
# VNEW  0.6330620815591221 m  4 xvar  5 count 0
# Linear filter...
# Filtered out 0/4, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/4, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/4, 0.0 false (nan vs 0.1)
# Neither filter filtered anything.
# VNEW  1.6206210345453258 m  4 xvar  5 count 1
# Linear filter...
# Filtered out 0/4, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/4, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/4, 0.0 false (nan vs 0.1)
# Neither filter filtered anything.
# VNEW  1.5420461406257138 m  4 xvar  5 count 1
# Linear filter...
# Filtered out 0/4, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/4, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/4, 0.0 false (nan vs 0.1)
# Neither filter filtered anything.
# VNEW  1.254891269782811 m  4 xvar  5 count 1
# Linear filter...
# Filtered out 0/4, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/4, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/4, 0.0 false (nan vs 0.1)
# Neither filter filtered anything.
# VNEW  1.224997682436643 m  4 xvar  5 count 1
# Linear filter...
# Filtered out 0/4, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/4, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/4, 0.0 false (nan vs 0.1)
# Neither filter filtered anything.
# VNEW  0.5931278100618554 m  4 xvar  5 count 1
# Linear filter...
# Filtered out 0/4, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/4, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/4, 0.0 false (nan vs 0.1)
# Neither filter filtered anything.
# VNEW  0.21258122784487132 m  4 xvar  5 count 2
# Linear filter...
# Filtered out 0/4, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/4, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/4, 0.0 false (nan vs 0.1)
# Neither filter filtered anything.
# VNEW  1.2587494745633971 m  4 xvar  5 count 3
# Linear filter...
# Filtered out 0/4, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/4, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/4, 0.0 false (nan vs 0.1)
# Neither filter filtered anything.
# VNEW  1.2311753019382534 m  4 xvar  5 count 3
# Linear filter...
# Filtered out 0/6, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/6, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/6, 0.0 false (nan vs 0.1)
# Neither filter filtered anything.
# VNEW  0.5812867151206839 m  6 xvar  5 count 0
# Linear filter...
# Filtered out 0/6, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/6, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/6, 0.0 false (nan vs 0.1)
# Neither filter filtered anything.
# VNEW  0.15549475043817498 m  6 xvar  5 count 1
# Linear filter...
# Filtered out 0/6, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/6, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/6, 0.0 false (nan vs 0.1)
# Neither filter filtered anything.
# VNEW  1.2491423123339425 m  6 xvar  5 count 2
# Linear filter...
# Filtered out 0/6, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/6, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/6, 0.0 false (nan vs 0.1)
# Neither filter filtered anything.
# VNEW  1.1682668576676125 m  6 xvar  5 count 2
# Linear filter...
# Filtered out 0/6, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/6, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/6, 0.0 false (nan vs 0.1)
# Neither filter filtered anything.
# VNEW  1.5394881250031007 m  6 xvar  5 count 3
# /Users/sushrutk/GitHub/robust_sparse_mean_estimation/robustlib.py:204: RuntimeWarning: invalid value encountered in double_scalars
#   print(f"Filtered out {l - len(idx[0])}/{l}, {bad_filtered} false ({bad_filtered / (l - len(idx[0])):0.2f} vs {self.fdr})")
# /Users/sushrutk/GitHub/robust_sparse_mean_estimation/robustlib.py:220: RuntimeWarning: invalid value encountered in double_scalars
#   print(f"Filtered out {l - len(idx[0])}/{l}, {bad_filtered} false ({bad_filtered / (l - len(idx[0])):0.2f} vs {self.fdr})")
# Linear filter...
# Filtered out 0/6, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/6, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/6, 0.0 false (nan vs 0.1)
# Neither filter filtered anything.
# VNEW  1.7378739990597925 m  6 xvar  5 count 3
# Linear filter...
# Filtered out 0/6, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/6, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/6, 0.0 false (nan vs 0.1)
# Neither filter filtered anything.
# VNEW  1.187811186425554 m  6 xvar  5 count 3
# Linear filter...
# Filtered out 0/6, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/6, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/6, 0.0 false (nan vs 0.1)
# Neither filter filtered anything.
# VNEW  0.14782600477317034 m  6 xvar  5 count 4
# Linear filter...
# Filtered out 0/6, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/6, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/6, 0.0 false (nan vs 0.1)
# Neither filter filtered anything.
# VNEW  0.23114236474914873 m  6 xvar  5 count 5
# Linear filter...
# Filtered out 0/6, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/6, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/6, 0.0 false (nan vs 0.1)
# Neither filter filtered anything.
# VNEW  0.3071478344123587 m  6 xvar  5 count 6
# Linear filter...
# Filtered out 0/8, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/8, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/8, 0.0 false (nan vs 0.1)
# Neither filter filtered anything.
# VNEW  0.10265713073487225 m  8 xvar  5 count 0
# Linear filter...
# Filtered out 0/8, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/8, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/8, 0.0 false (nan vs 0.1)
# Neither filter filtered anything.
# VNEW  0.4717082515471539 m  8 xvar  5 count 1
# Linear filter...
# Filtered out 0/8, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/8, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/8, 0.0 false (nan vs 0.1)
# Neither filter filtered anything.
# VNEW  0.36267962387230857 m  8 xvar  5 count 2
# Linear filter...
# Filtered out 0/8, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/8, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/8, 0.0 false (nan vs 0.1)
# Neither filter filtered anything.
# VNEW  0.20282364027525934 m  8 xvar  5 count 3
# Linear filter...
# Filtered out 0/8, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/8, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/8, 0.0 false (nan vs 0.1)
# Neither filter filtered anything.
# VNEW  0.4695591390568857 m  8 xvar  5 count 4
# Linear filter...
# Filtered out 0/8, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/8, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/8, 0.0 false (nan vs 0.1)
# Neither filter filtered anything.
# VNEW  0.7369869468380256 m  8 xvar  5 count 5
# Linear filter...
# Filtered out 0/8, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/8, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/8, 0.0 false (nan vs 0.1)
# Neither filter filtered anything.
# VNEW  0.15199116370493435 m  8 xvar  5 count 6
# Linear filter...
# Filtered out 0/8, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/8, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/8, 0.0 false (nan vs 0.1)
# Neither filter filtered anything.
# VNEW  0.26815416579737483 m  8 xvar  5 count 7
# Linear filter...
# Filtered out 0/8, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/8, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/8, 0.0 false (nan vs 0.1)
# Neither filter filtered anything.
# VNEW  0.7008828471550702 m  8 xvar  5 count 8
# Linear filter...
# Filtered out 0/8, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/8, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/8, 0.0 false (nan vs 0.1)
# Neither filter filtered anything.
# VNEW  0.4240153143939913 m  8 xvar  5 count 9
# 15
# Linear filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Neither filter filtered anything.
# VNEW  3.0532765175205414 m  2 xvar  15 count 0
# Linear filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Neither filter filtered anything.
# VNEW  3.6954398787525182 m  2 xvar  15 count 0
# Linear filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Neither filter filtered anything.
# VNEW  2.8397716814217233 m  2 xvar  15 count 0
# Linear filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Neither filter filtered anything.
# VNEW  3.273748373887656 m  2 xvar  15 count 0
# Linear filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Neither filter filtered anything.
# VNEW  1.9540598744085618 m  2 xvar  15 count 0
# Linear filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Neither filter filtered anything.
# VNEW  2.2581036194831974 m  2 xvar  15 count 0
# Linear filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Neither filter filtered anything.
# VNEW  2.086173022263803 m  2 xvar  15 count 0
# Linear filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Neither filter filtered anything.
# VNEW  1.9975140371737756 m  2 xvar  15 count 0
# Linear filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Neither filter filtered anything.
# VNEW  3.220086937150773 m  2 xvar  15 count 0
# Linear filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Neither filter filtered anything.
# VNEW  3.066791160620053 m  2 xvar  15 count 0
# Linear filter...
# Filtered out 0/4, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/4, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/4, 0.0 false (nan vs 0.1)
# Neither filter filtered anything.
# VNEW  2.0918350926069804 m  4 xvar  15 count 0
# Linear filter...
# Filtered out 0/4, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/4, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/4, 0.0 false (nan vs 0.1)
# Neither filter filtered anything.
# VNEW  1.4506420203532868 m  4 xvar  15 count 0
# Linear filter...
# Filtered out 0/4, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/4, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/4, 0.0 false (nan vs 0.1)
# Neither filter filtered anything.
# VNEW  1.6713432578249428 m  4 xvar  15 count 0
# Linear filter...
# Filtered out 0/4, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/4, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/4, 0.0 false (nan vs 0.1)
# Neither filter filtered anything.
# VNEW  2.3939204415079685 m  4 xvar  15 count 0
# Linear filter...
# Filtered out 0/4, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/4, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/4, 0.0 false (nan vs 0.1)
# Neither filter filtered anything.
# VNEW  2.3495770119538744 m  4 xvar  15 count 0
# Linear filter...
# Filtered out 0/4, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/4, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/4, 0.0 false (nan vs 0.1)
# Neither filter filtered anything.
# VNEW  1.836095818453062 m  4 xvar  15 count 0
# Linear filter...
# Filtered out 0/4, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/4, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/4, 0.0 false (nan vs 0.1)
# Neither filter filtered anything.
# VNEW  2.584513731428583 m  4 xvar  15 count 0
# Linear filter...
# Filtered out 0/4, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/4, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/4, 0.0 false (nan vs 0.1)
# Neither filter filtered anything.
# VNEW  1.2436962234628206 m  4 xvar  15 count 0
# Linear filter...
# Filtered out 0/4, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/4, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/4, 0.0 false (nan vs 0.1)
# Neither filter filtered anything.
# VNEW  2.1273265255505147 m  4 xvar  15 count 0
# Linear filter...
# Filtered out 0/4, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/4, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/4, 0.0 false (nan vs 0.1)
# Neither filter filtered anything.
# VNEW  2.485341125385281 m  4 xvar  15 count 0
# Linear filter...
# Filtered out 0/6, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/6, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/6, 0.0 false (nan vs 0.1)
# Neither filter filtered anything.
# VNEW  1.3286380148466537 m  6 xvar  15 count 0
# Linear filter...
# Filtered out 0/6, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/6, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/6, 0.0 false (nan vs 0.1)
# Neither filter filtered anything.
# VNEW  1.7844907905896663 m  6 xvar  15 count 0
# Linear filter...
# Filtered out 0/6, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/6, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/6, 0.0 false (nan vs 0.1)
# Neither filter filtered anything.
# VNEW  1.3227290191727754 m  6 xvar  15 count 0
# Linear filter...
# Filtered out 0/6, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/6, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/6, 0.0 false (nan vs 0.1)
# Neither filter filtered anything.
# VNEW  1.2181809894290152 m  6 xvar  15 count 0
# Linear filter...
# Filtered out 0/6, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/6, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/6, 0.0 false (nan vs 0.1)
# Neither filter filtered anything.
# VNEW  2.0104561229131024 m  6 xvar  15 count 0
# Linear filter...
# Filtered out 0/6, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/6, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/6, 0.0 false (nan vs 0.1)
# Neither filter filtered anything.
# VNEW  1.4735603871923908 m  6 xvar  15 count 0
# Linear filter...
# Filtered out 0/6, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/6, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/6, 0.0 false (nan vs 0.1)
# Neither filter filtered anything.
# VNEW  1.3253718567896788 m  6 xvar  15 count 0
# Linear filter...
# Filtered out 0/6, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/6, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/6, 0.0 false (nan vs 0.1)
# Neither filter filtered anything.
# VNEW  1.2344178894040003 m  6 xvar  15 count 0
# Linear filter...
# Filtered out 0/6, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/6, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/6, 0.0 false (nan vs 0.1)
# Neither filter filtered anything.
# VNEW  1.451363319512911 m  6 xvar  15 count 0
# Linear filter...
# Filtered out 0/6, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/6, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/6, 0.0 false (nan vs 0.1)
# Neither filter filtered anything.
# VNEW  0.4211753329540238 m  6 xvar  15 count 0
# Linear filter...
# Filtered out 0/8, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/8, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/8, 0.0 false (nan vs 0.1)
# Neither filter filtered anything.
# VNEW  1.7695541445264735 m  8 xvar  15 count 0
# Linear filter...
# Filtered out 0/8, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/8, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/8, 0.0 false (nan vs 0.1)
# Neither filter filtered anything.
# VNEW  0.6312623697425848 m  8 xvar  15 count 0
# Linear filter...
# Filtered out 0/8, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/8, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/8, 0.0 false (nan vs 0.1)
# Neither filter filtered anything.
# VNEW  1.2933558273820625 m  8 xvar  15 count 1
# Linear filter...
# Filtered out 0/8, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/8, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/8, 0.0 false (nan vs 0.1)
# Neither filter filtered anything.
# VNEW  1.6041353073670381 m  8 xvar  15 count 1
# Linear filter...
# Filtered out 0/8, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/8, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/8, 0.0 false (nan vs 0.1)
# Neither filter filtered anything.
# VNEW  1.3328378132008314 m  8 xvar  15 count 1
# Linear filter...
# Filtered out 0/8, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/8, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/8, 0.0 false (nan vs 0.1)
# Neither filter filtered anything.
# VNEW  1.311372134752768 m  8 xvar  15 count 1
# Linear filter...
# Filtered out 0/8, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/8, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/8, 0.0 false (nan vs 0.1)
# Neither filter filtered anything.
# VNEW  0.28309784531334387 m  8 xvar  15 count 1
# Linear filter...
# Filtered out 0/8, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/8, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/8, 0.0 false (nan vs 0.1)
# Neither filter filtered anything.
# VNEW  0.12027899226599777 m  8 xvar  15 count 2
# Linear filter...
# Filtered out 0/8, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/8, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/8, 0.0 false (nan vs 0.1)
# Neither filter filtered anything.
# VNEW  0.3108807859705128 m  8 xvar  15 count 3
# Linear filter...
# Filtered out 0/8, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/8, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/8, 0.0 false (nan vs 0.1)
# Neither filter filtered anything.
# VNEW  1.189992349090476 m  8 xvar  15 count 4
# Linear filter...
# Filtered out 0/10, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/10, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/10, 0.0 false (nan vs 0.1)
# Neither filter filtered anything.
# VNEW  0.2972652128647419 m  10 xvar  15 count 0
# Linear filter...
# Filtered out 0/10, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/10, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/10, 0.0 false (nan vs 0.1)
# Neither filter filtered anything.
# VNEW  0.2838279978503992 m  10 xvar  15 count 1
# Linear filter...
# Filtered out 0/10, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/10, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/10, 0.0 false (nan vs 0.1)
# Neither filter filtered anything.
# VNEW  0.432305916960267 m  10 xvar  15 count 2
# Linear filter...
# Filtered out 0/10, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/10, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/10, 0.0 false (nan vs 0.1)
# Neither filter filtered anything.
# VNEW  0.3595710584644932 m  10 xvar  15 count 3
# Linear filter...
# Filtered out 0/10, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/10, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/10, 0.0 false (nan vs 0.1)
# Neither filter filtered anything.
# VNEW  1.2911316877480778 m  10 xvar  15 count 4
# Linear filter...
# Filtered out 0/10, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/10, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/10, 0.0 false (nan vs 0.1)
# Neither filter filtered anything.
# VNEW  0.3598447196640967 m  10 xvar  15 count 4
# Linear filter...
# Filtered out 0/10, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/10, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/10, 0.0 false (nan vs 0.1)
# Neither filter filtered anything.
# VNEW  1.6930359577559981 m  10 xvar  15 count 5
# Linear filter...
# Filtered out 0/10, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/10, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/10, 0.0 false (nan vs 0.1)
# Neither filter filtered anything.
# VNEW  0.25407406452011694 m  10 xvar  15 count 5
# Linear filter...
# Filtered out 0/10, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/10, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/10, 0.0 false (nan vs 0.1)
# Neither filter filtered anything.
# VNEW  0.5495281916931899 m  10 xvar  15 count 6
# Linear filter...
# Filtered out 0/10, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/10, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/10, 0.0 false (nan vs 0.1)
# Neither filter filtered anything.
# VNEW  0.5270327782575158 m  10 xvar  15 count 7
# 25
# Linear filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Neither filter filtered anything.
# VNEW  3.920201176541841 m  2 xvar  25 count 0
# Linear filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Neither filter filtered anything.
# VNEW  3.615123611522136 m  2 xvar  25 count 0
# Linear filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Neither filter filtered anything.
# VNEW  2.2358768545272523 m  2 xvar  25 count 0
# Linear filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Neither filter filtered anything.
# VNEW  3.4883695401936192 m  2 xvar  25 count 0
# Linear filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Neither filter filtered anything.
# VNEW  3.679908394765807 m  2 xvar  25 count 0
# Linear filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Neither filter filtered anything.
# VNEW  2.7968970965211795 m  2 xvar  25 count 0
# Linear filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Neither filter filtered anything.
# VNEW  2.9782374106343 m  2 xvar  25 count 0
# Linear filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Neither filter filtered anything.
# VNEW  2.8650799746097992 m  2 xvar  25 count 0
# Linear filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Neither filter filtered anything.
# VNEW  2.8337775398392187 m  2 xvar  25 count 0
# Linear filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Neither filter filtered anything.
# VNEW  2.4573283056024064 m  2 xvar  25 count 0
# Linear filter...
# Filtered out 0/4, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/4, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/4, 0.0 false (nan vs 0.1)
# Neither filter filtered anything.
# VNEW  1.6116804689959214 m  4 xvar  25 count 0
# Linear filter...
# Filtered out 0/4, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/4, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/4, 0.0 false (nan vs 0.1)
# Neither filter filtered anything.
# VNEW  2.3929171984608426 m  4 xvar  25 count 0
# Linear filter...
# Filtered out 0/4, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/4, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/4, 0.0 false (nan vs 0.1)
# Neither filter filtered anything.
# VNEW  2.1640831204205617 m  4 xvar  25 count 0
# Linear filter...
# Filtered out 0/4, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/4, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/4, 0.0 false (nan vs 0.1)
# Neither filter filtered anything.
# VNEW  2.0479077660745983 m  4 xvar  25 count 0
# Linear filter...
# Filtered out 0/4, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/4, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/4, 0.0 false (nan vs 0.1)
# Neither filter filtered anything.
# VNEW  1.4895881236156914 m  4 xvar  25 count 0
# Linear filter...
# Filtered out 0/4, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/4, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/4, 0.0 false (nan vs 0.1)
# Neither filter filtered anything.
# VNEW  2.228253718729991 m  4 xvar  25 count 0
# Linear filter...
# Filtered out 0/4, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/4, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/4, 0.0 false (nan vs 0.1)
# Neither filter filtered anything.
# VNEW  1.3474388836509525 m  4 xvar  25 count 0
# Linear filter...
# Filtered out 0/4, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/4, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/4, 0.0 false (nan vs 0.1)
# Neither filter filtered anything.
# VNEW  2.4126358419185445 m  4 xvar  25 count 0
# Linear filter...
# Filtered out 0/4, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/4, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/4, 0.0 false (nan vs 0.1)
# Neither filter filtered anything.
# VNEW  2.1502805565272256 m  4 xvar  25 count 0
# Linear filter...
# Filtered out 0/4, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/4, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/4, 0.0 false (nan vs 0.1)
# Neither filter filtered anything.
# VNEW  2.533144573372728 m  4 xvar  25 count 0
# Linear filter...
# Filtered out 0/6, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/6, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/6, 0.0 false (nan vs 0.1)
# Neither filter filtered anything.
# VNEW  1.4721348336124052 m  6 xvar  25 count 0
# Linear filter...
# Filtered out 0/6, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/6, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/6, 0.0 false (nan vs 0.1)
# Neither filter filtered anything.
# VNEW  1.427153703054855 m  6 xvar  25 count 0
# Linear filter...
# Filtered out 0/6, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/6, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/6, 0.0 false (nan vs 0.1)
# Neither filter filtered anything.
# VNEW  1.418139921244034 m  6 xvar  25 count 0
# Linear filter...
# Filtered out 0/6, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/6, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/6, 0.0 false (nan vs 0.1)
# Neither filter filtered anything.
# VNEW  1.3076014850631195 m  6 xvar  25 count 0
# Linear filter...
# Filtered out 0/6, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/6, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/6, 0.0 false (nan vs 0.1)
# Neither filter filtered anything.
# VNEW  0.6273107597797533 m  6 xvar  25 count 0
# Linear filter...
# Filtered out 0/6, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/6, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/6, 0.0 false (nan vs 0.1)
# Neither filter filtered anything.
# VNEW  1.7734070812081948 m  6 xvar  25 count 1
# Linear filter...
# Filtered out 0/6, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/6, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/6, 0.0 false (nan vs 0.1)
# Neither filter filtered anything.
# VNEW  1.3785714950458912 m  6 xvar  25 count 1
# Linear filter...
# Filtered out 0/6, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/6, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/6, 0.0 false (nan vs 0.1)
# Neither filter filtered anything.
# VNEW  1.939851716123494 m  6 xvar  25 count 1
# Linear filter...
# Filtered out 0/6, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/6, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/6, 0.0 false (nan vs 0.1)
# Neither filter filtered anything.
# VNEW  1.7860864209155016 m  6 xvar  25 count 1
# Linear filter...
# Filtered out 0/6, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/6, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/6, 0.0 false (nan vs 0.1)
# Neither filter filtered anything.
# VNEW  0.21462071758762663 m  6 xvar  25 count 1
# Linear filter...
# Filtered out 0/8, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/8, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/8, 0.0 false (nan vs 0.1)
# Neither filter filtered anything.
# VNEW  2.317883277754995 m  8 xvar  25 count 0
# Linear filter...
# Filtered out 0/8, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/8, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/8, 0.0 false (nan vs 0.1)
# Neither filter filtered anything.
# VNEW  1.470670954317591 m  8 xvar  25 count 0
# Linear filter...
# Filtered out 0/8, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/8, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/8, 0.0 false (nan vs 0.1)
# Neither filter filtered anything.
# VNEW  1.638558631963596 m  8 xvar  25 count 0
# Linear filter...
# Filtered out 0/8, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/8, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/8, 0.0 false (nan vs 0.1)
# Neither filter filtered anything.
# VNEW  0.2709417935941276 m  8 xvar  25 count 0
# Linear filter...
# Filtered out 0/8, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/8, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/8, 0.0 false (nan vs 0.1)
# Neither filter filtered anything.
# VNEW  1.3749438318138247 m  8 xvar  25 count 1
# Linear filter...
# Filtered out 0/8, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/8, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/8, 0.0 false (nan vs 0.1)
# Neither filter filtered anything.
# VNEW  1.955109915690887 m  8 xvar  25 count 1
# Linear filter...
# Filtered out 0/8, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/8, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/8, 0.0 false (nan vs 0.1)
# Neither filter filtered anything.
# VNEW  1.5497914596026308 m  8 xvar  25 count 1
# Linear filter...
# Filtered out 0/8, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/8, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/8, 0.0 false (nan vs 0.1)
# Neither filter filtered anything.
# VNEW  1.7986186874106216 m  8 xvar  25 count 1
# Linear filter...
# Filtered out 0/8, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/8, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/8, 0.0 false (nan vs 0.1)
# Neither filter filtered anything.
# VNEW  1.7371590567839421 m  8 xvar  25 count 1
# Linear filter...
# Filtered out 0/8, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/8, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/8, 0.0 false (nan vs 0.1)
# Neither filter filtered anything.
# VNEW  0.5279806719705761 m  8 xvar  25 count 1
# Linear filter...
# Filtered out 0/10, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/10, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/10, 0.0 false (nan vs 0.1)
# Neither filter filtered anything.
# VNEW  1.7191201597536896 m  10 xvar  25 count 0
# Linear filter...
# Filtered out 0/10, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/10, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/10, 0.0 false (nan vs 0.1)
# Neither filter filtered anything.
# VNEW  1.3084460245466734 m  10 xvar  25 count 0
# Linear filter...
# Filtered out 0/10, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/10, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/10, 0.0 false (nan vs 0.1)
# Neither filter filtered anything.
# VNEW  1.2044522746443083 m  10 xvar  25 count 0
# Linear filter...
# Filtered out 0/10, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/10, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/10, 0.0 false (nan vs 0.1)
# Neither filter filtered anything.
# VNEW  1.4677985050321711 m  10 xvar  25 count 0
# Linear filter...
# Filtered out 0/10, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/10, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/10, 0.0 false (nan vs 0.1)
# Neither filter filtered anything.
# VNEW  1.3846795340317795 m  10 xvar  25 count 0
# Linear filter...
# Filtered out 0/10, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/10, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/10, 0.0 false (nan vs 0.1)
# Neither filter filtered anything.
# VNEW  0.10068645703067412 m  10 xvar  25 count 0
# Linear filter...
# Filtered out 0/10, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/10, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/10, 0.0 false (nan vs 0.1)
# Neither filter filtered anything.
# VNEW  1.1930351975639188 m  10 xvar  25 count 1
# Linear filter...
# Filtered out 0/10, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/10, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/10, 0.0 false (nan vs 0.1)
# Neither filter filtered anything.
# VNEW  0.26655174692081823 m  10 xvar  25 count 2
# Linear filter...
# Filtered out 0/10, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/10, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/10, 0.0 false (nan vs 0.1)
# Neither filter filtered anything.
# VNEW  0.44755648839697515 m  10 xvar  25 count 3
# Linear filter...
# Filtered out 0/10, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/10, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/10, 0.0 false (nan vs 0.1)
# Neither filter filtered anything.
# VNEW  1.4149745518835501 m  10 xvar  25 count 4
# Linear filter...
# Filtered out 0/12, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/12, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/12, 0.0 false (nan vs 0.1)
# Neither filter filtered anything.
# VNEW  1.1694973647701752 m  12 xvar  25 count 0
# Linear filter...
# Filtered out 0/12, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/12, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/12, 0.0 false (nan vs 0.1)
# Neither filter filtered anything.
# VNEW  0.452255799926265 m  12 xvar  25 count 1
# Linear filter...
# Filtered out 0/12, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/12, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/12, 0.0 false (nan vs 0.1)
# Neither filter filtered anything.
# VNEW  1.303286721199046 m  12 xvar  25 count 2
# Linear filter...
# Filtered out 0/12, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/12, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/12, 0.0 false (nan vs 0.1)
# Neither filter filtered anything.
# VNEW  0.30704621814777205 m  12 xvar  25 count 2
# Linear filter...
# Filtered out 0/12, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/12, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/12, 0.0 false (nan vs 0.1)
# Neither filter filtered anything.
# VNEW  0.35775821235226524 m  12 xvar  25 count 3
# Linear filter...
# Filtered out 0/12, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/12, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/12, 0.0 false (nan vs 0.1)
# Neither filter filtered anything.
# VNEW  1.2944943579968415 m  12 xvar  25 count 4
# Linear filter...
# Filtered out 0/12, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/12, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/12, 0.0 false (nan vs 0.1)
# Neither filter filtered anything.
# VNEW  1.298691203873126 m  12 xvar  25 count 4
# Linear filter...
# Filtered out 0/12, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/12, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/12, 0.0 false (nan vs 0.1)
# Neither filter filtered anything.
# VNEW  0.07479492444438668 m  12 xvar  25 count 4
# Linear filter...
# Filtered out 0/12, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/12, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/12, 0.0 false (nan vs 0.1)
# Neither filter filtered anything.
# VNEW  1.2322771671131338 m  12 xvar  25 count 5
# Linear filter...
# Filtered out 0/12, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/12, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/12, 0.0 false (nan vs 0.1)
# Neither filter filtered anything.
# VNEW  0.25801088025196084 m  12 xvar  25 count 5
# Linear filter...
# Filtered out 0/14, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/14, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/14, 0.0 false (nan vs 0.1)
# Neither filter filtered anything.
# VNEW  1.3282359012307547 m  14 xvar  25 count 0
# Linear filter...
# Filtered out 0/14, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/14, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/14, 0.0 false (nan vs 0.1)
# Neither filter filtered anything.
# VNEW  0.358184032652466 m  14 xvar  25 count 0
# Linear filter...
# Filtered out 0/14, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/14, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/14, 0.0 false (nan vs 0.1)
# Neither filter filtered anything.
# VNEW  0.3281139857296088 m  14 xvar  25 count 1
# Linear filter...
# Filtered out 0/14, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/14, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/14, 0.0 false (nan vs 0.1)
# Neither filter filtered anything.
# VNEW  0.33996215429642335 m  14 xvar  25 count 2
# Linear filter...
# Filtered out 0/14, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/14, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/14, 0.0 false (nan vs 0.1)
# Neither filter filtered anything.
# VNEW  0.33699643624049436 m  14 xvar  25 count 3
# Linear filter...
# Filtered out 0/14, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/14, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/14, 0.0 false (nan vs 0.1)
# Neither filter filtered anything.
# VNEW  0.3201722532779131 m  14 xvar  25 count 4
# Linear filter...
# Filtered out 0/14, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/14, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/14, 0.0 false (nan vs 0.1)
# Neither filter filtered anything.
# VNEW  0.7161295686708429 m  14 xvar  25 count 5
# Linear filter...
# Filtered out 0/14, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/14, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/14, 0.0 false (nan vs 0.1)
# Neither filter filtered anything.
# VNEW  0.2185364402694841 m  14 xvar  25 count 6
# Linear filter...
# Filtered out 0/14, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/14, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/14, 0.0 false (nan vs 0.1)
# Neither filter filtered anything.
# VNEW  0.5038096825021112 m  14 xvar  25 count 7
# Linear filter...
# Filtered out 0/14, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/14, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/14, 0.0 false (nan vs 0.1)
# Neither filter filtered anything.
# VNEW  1.2517153223548472 m  14 xvar  25 count 8
# 35
# Linear filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Neither filter filtered anything.
# VNEW  3.4164135642189306 m  2 xvar  35 count 0
# Linear filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Neither filter filtered anything.
# VNEW  3.1959756058873654 m  2 xvar  35 count 0
# Linear filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Neither filter filtered anything.
# VNEW  3.585684180110986 m  2 xvar  35 count 0
# Linear filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Neither filter filtered anything.
# VNEW  3.884169787130343 m  2 xvar  35 count 0
# Linear filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Neither filter filtered anything.
# VNEW  3.38254039406244 m  2 xvar  35 count 0
# Linear filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Neither filter filtered anything.
# VNEW  3.0940778169336807 m  2 xvar  35 count 0
# Linear filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Neither filter filtered anything.
# VNEW  4.4607365782605 m  2 xvar  35 count 0
# Linear filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Neither filter filtered anything.
# VNEW  3.869645503931205 m  2 xvar  35 count 0
# Linear filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Neither filter filtered anything.
# VNEW  3.2223607373663103 m  2 xvar  35 count 0
# Linear filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Neither filter filtered anything.
# VNEW  3.440901086267016 m  2 xvar  35 count 0
# Linear filter...
# Filtered out 0/4, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/4, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/4, 0.0 false (nan vs 0.1)
# Neither filter filtered anything.
# VNEW  2.3027209733585745 m  4 xvar  35 count 0
# Linear filter...
# Filtered out 0/4, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/4, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/4, 0.0 false (nan vs 0.1)
# Neither filter filtered anything.
# VNEW  1.8830483247447012 m  4 xvar  35 count 0
# Linear filter...
# Filtered out 0/4, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/4, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/4, 0.0 false (nan vs 0.1)
# Neither filter filtered anything.
# VNEW  2.2324397031939482 m  4 xvar  35 count 0
# Linear filter...
# Filtered out 0/4, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/4, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/4, 0.0 false (nan vs 0.1)
# Neither filter filtered anything.
# VNEW  2.79611267284937 m  4 xvar  35 count 0
# Linear filter...
# Filtered out 0/4, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/4, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/4, 0.0 false (nan vs 0.1)
# Neither filter filtered anything.
# VNEW  2.6433734738044583 m  4 xvar  35 count 0
# Linear filter...
# Filtered out 0/4, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/4, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/4, 0.0 false (nan vs 0.1)
# Neither filter filtered anything.
# VNEW  2.5197162256850403 m  4 xvar  35 count 0
# Linear filter...
# Filtered out 0/4, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/4, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/4, 0.0 false (nan vs 0.1)
# Neither filter filtered anything.
# VNEW  3.0308180395317263 m  4 xvar  35 count 0
# Linear filter...
# Filtered out 0/4, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/4, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/4, 0.0 false (nan vs 0.1)
# Neither filter filtered anything.
# VNEW  2.4283909000832407 m  4 xvar  35 count 0
# Linear filter...
# Filtered out 0/4, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/4, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/4, 0.0 false (nan vs 0.1)
# Neither filter filtered anything.
# VNEW  2.029042576294328 m  4 xvar  35 count 0
# Linear filter...
# Filtered out 0/4, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/4, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/4, 0.0 false (nan vs 0.1)
# Neither filter filtered anything.
# VNEW  2.6030379360312317 m  4 xvar  35 count 0
# Linear filter...
# Filtered out 0/6, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/6, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/6, 0.0 false (nan vs 0.1)
# Neither filter filtered anything.
# VNEW  1.338518585449652 m  6 xvar  35 count 0
# Linear filter...
# Filtered out 0/6, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/6, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/6, 0.0 false (nan vs 0.1)
# Neither filter filtered anything.
# VNEW  1.8725461827575498 m  6 xvar  35 count 0
# Linear filter...
# Filtered out 0/6, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/6, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/6, 0.0 false (nan vs 0.1)
# Neither filter filtered anything.
# VNEW  1.4076222941071952 m  6 xvar  35 count 0
# Linear filter...
# Filtered out 0/6, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/6, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/6, 0.0 false (nan vs 0.1)
# Neither filter filtered anything.
# VNEW  2.5159379182057773 m  6 xvar  35 count 0
# Linear filter...
# Filtered out 0/6, 0.0 false (nan vs 0.1)
# Linear filter...
# ...
# Neither filter filtered anything.
# VNEW  2.450285656507886 m  4 xvar  55 count 0
# Linear filter...
# Filtered out 0/4, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/4, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/4, 0.0 false (nan vs 0.1)
# Neither filter filtered anything.
# VNEW  2.5791318038945663 m  4 xvar  55 count 0
# Linear filter...
# Filtered out 0/6, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/6, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/6, 0.0 false (nan vs 0.1)
# Neither filter filtered anything.
# VNEW  0.690367912624095 m  6 xvar  55 count 0
# Linear filter...
# Filtered out 0/6, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/6, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/6, 0.0 false (nan vs 0.1)
# Neither filter filtered anything.
# VNEW  1.9084870143748374 m  6 xvar  55 count 1
# Linear filter...
# Filtered out 0/6, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/6, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/6, 0.0 false (nan vs 0.1)
# Neither filter filtered anything.
# VNEW  1.8326345341969228 m  6 xvar  55 count 1
# Linear filter...
# Filtered out 0/6, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/6, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/6, 0.0 false (nan vs 0.1)
# Neither filter filtered anything.
# VNEW  2.4008186234251223 m  6 xvar  55 count 1
# Linear filter...
# Filtered out 0/6, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/6, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/6, 0.0 false (nan vs 0.1)
# Neither filter filtered anything.
# VNEW  1.6000221395519714 m  6 xvar  55 count 1
# Linear filter...
# Filtered out 0/6, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/6, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/6, 0.0 false (nan vs 0.1)
# Neither filter filtered anything.
# VNEW  2.4547769006623614 m  6 xvar  55 count 1
# Linear filter...
# Filtered out 0/6, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/6, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/6, 0.0 false (nan vs 0.1)
# Neither filter filtered anything.
# VNEW  2.221758916784426 m  6 xvar  55 count 1
# Linear filter...
# Filtered out 0/6, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/6, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/6, 0.0 false (nan vs 0.1)
# Neither filter filtered anything.
# VNEW  2.1313004724179536 m  6 xvar  55 count 1
# Linear filter...
# Filtered out 0/6, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/6, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/6, 0.0 false (nan vs 0.1)
# Neither filter filtered anything.
# VNEW  2.1811985574728525 m  6 xvar  55 count 1
# Linear filter...
# Filtered out 0/6, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/6, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/6, 0.0 false (nan vs 0.1)
# Neither filter filtered anything.
# VNEW  2.0704968463403 m  6 xvar  55 count 1
# Linear filter...
# Filtered out 0/8, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/8, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/8, 0.0 false (nan vs 0.1)
# Neither filter filtered anything.
# VNEW  1.9247298865098947 m  8 xvar  55 count 0
# Linear filter...
# Filtered out 0/8, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/8, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/8, 0.0 false (nan vs 0.1)
# Neither filter filtered anything.
# VNEW  1.4414215100471957 m  8 xvar  55 count 0
# Linear filter...
# Filtered out 0/8, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/8, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/8, 0.0 false (nan vs 0.1)
# Neither filter filtered anything.
# VNEW  2.141220762939786 m  8 xvar  55 count 0
# Linear filter...
# Filtered out 0/8, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/8, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/8, 0.0 false (nan vs 0.1)
# Neither filter filtered anything.
# VNEW  1.4618113551291552 m  8 xvar  55 count 0
# Linear filter...
# Filtered out 0/8, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/8, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/8, 0.0 false (nan vs 0.1)
# Neither filter filtered anything.
# VNEW  1.411463657528911 m  8 xvar  55 count 0
# Linear filter...
# Filtered out 0/8, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/8, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/8, 0.0 false (nan vs 0.1)
# Neither filter filtered anything.
# VNEW  0.7944876586645907 m  8 xvar  55 count 0
# Linear filter...
# Filtered out 0/8, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/8, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/8, 0.0 false (nan vs 0.1)
# Neither filter filtered anything.
# VNEW  1.538384517829234 m  8 xvar  55 count 1
# Linear filter...
# Filtered out 0/8, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/8, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/8, 0.0 false (nan vs 0.1)
# Neither filter filtered anything.
# VNEW  1.824655167880276 m  8 xvar  55 count 1
# Linear filter...
# Filtered out 0/8, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/8, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/8, 0.0 false (nan vs 0.1)
# Neither filter filtered anything.
# VNEW  1.7248614745894548 m  8 xvar  55 count 1
# Linear filter...
# Filtered out 0/8, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/8, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/8, 0.0 false (nan vs 0.1)
# Neither filter filtered anything.
# VNEW  1.3890590902009208 m  8 xvar  55 count 1
# Linear filter...
# Filtered out 0/10, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/10, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/10, 0.0 false (nan vs 0.1)
# Neither filter filtered anything.
# VNEW  0.4076512262369505 m  10 xvar  55 count 0
# Linear filter...
# Filtered out 0/10, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/10, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/10, 0.0 false (nan vs 0.1)
# Neither filter filtered anything.
# VNEW  1.3547161936459151 m  10 xvar  55 count 1
# Linear filter...
# Filtered out 0/10, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/10, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/10, 0.0 false (nan vs 0.1)
# Neither filter filtered anything.
# VNEW  0.19915068071572248 m  10 xvar  55 count 1
# Linear filter...
# Filtered out 0/10, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/10, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/10, 0.0 false (nan vs 0.1)
# Neither filter filtered anything.
# VNEW  0.41798391099003834 m  10 xvar  55 count 2
# Linear filter...
# Filtered out 0/10, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/10, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/10, 0.0 false (nan vs 0.1)
# Neither filter filtered anything.
# VNEW  1.3303035181822633 m  10 xvar  55 count 3
# Linear filter...
# Filtered out 0/10, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/10, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/10, 0.0 false (nan vs 0.1)
# Neither filter filtered anything.
# VNEW  0.20787321873832396 m  10 xvar  55 count 3
# Linear filter...
# Filtered out 0/10, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/10, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/10, 0.0 false (nan vs 0.1)
# Neither filter filtered anything.
# VNEW  1.3443495943208978 m  10 xvar  55 count 4
# Linear filter...
# Filtered out 0/10, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/10, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/10, 0.0 false (nan vs 0.1)
# Neither filter filtered anything.
# VNEW  1.3800326441171817 m  10 xvar  55 count 4
# Linear filter...
# Filtered out 0/10, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/10, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/10, 0.0 false (nan vs 0.1)
# Neither filter filtered anything.
# VNEW  1.3866007421450315 m  10 xvar  55 count 4
# Linear filter...
# Filtered out 0/10, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/10, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/10, 0.0 false (nan vs 0.1)
# Neither filter filtered anything.
# VNEW  1.3791744838755082 m  10 xvar  55 count 4
# Linear filter...
# Filtered out 0/12, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/12, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/12, 0.0 false (nan vs 0.1)
# Neither filter filtered anything.
# VNEW  1.278241927429643 m  12 xvar  55 count 0
# Linear filter...
# Filtered out 0/12, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/12, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/12, 0.0 false (nan vs 0.1)
# Neither filter filtered anything.
# VNEW  1.2688606138408813 m  12 xvar  55 count 0
# Linear filter...
# Filtered out 0/12, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/12, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/12, 0.0 false (nan vs 0.1)
# Neither filter filtered anything.
# VNEW  1.2050811195052002 m  12 xvar  55 count 0
# Linear filter...
# Filtered out 0/12, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/12, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/12, 0.0 false (nan vs 0.1)
# Neither filter filtered anything.
# VNEW  1.3455569713066171 m  12 xvar  55 count 0
# Linear filter...
# Filtered out 0/12, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/12, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/12, 0.0 false (nan vs 0.1)
# Neither filter filtered anything.
# VNEW  1.306182290686943 m  12 xvar  55 count 0
# Linear filter...
# Filtered out 0/12, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/12, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/12, 0.0 false (nan vs 0.1)
# Neither filter filtered anything.
# VNEW  1.1992507554807683 m  12 xvar  55 count 0
# Linear filter...
# Filtered out 0/12, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/12, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/12, 0.0 false (nan vs 0.1)
# Neither filter filtered anything.
# VNEW  1.7518717234752716 m  12 xvar  55 count 1
# Linear filter...
# Filtered out 0/12, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/12, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/12, 0.0 false (nan vs 0.1)
# Neither filter filtered anything.
# VNEW  0.3408600090762719 m  12 xvar  55 count 1
# Linear filter...
# Filtered out 0/12, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/12, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/12, 0.0 false (nan vs 0.1)
# Neither filter filtered anything.
# VNEW  1.2348799323612538 m  12 xvar  55 count 2
# Linear filter...
# Filtered out 0/12, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/12, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/12, 0.0 false (nan vs 0.1)
# Neither filter filtered anything.
# VNEW  0.20823570687424525 m  12 xvar  55 count 2
# Linear filter...
# Filtered out 0/14, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/14, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/14, 0.0 false (nan vs 0.1)
# Neither filter filtered anything.
# VNEW  1.3140327900361806 m  14 xvar  55 count 0
# Linear filter...
# Filtered out 0/14, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/14, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/14, 0.0 false (nan vs 0.1)
# Neither filter filtered anything.
# VNEW  1.2231685903935725 m  14 xvar  55 count 0
# Linear filter...
# Filtered out 0/14, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/14, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/14, 0.0 false (nan vs 0.1)
# Neither filter filtered anything.
# VNEW  1.2118235990715882 m  14 xvar  55 count 0
# Linear filter...
# Filtered out 0/14, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/14, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/14, 0.0 false (nan vs 0.1)
# Neither filter filtered anything.
# VNEW  1.236633972485403 m  14 xvar  55 count 0
# Linear filter...
# Filtered out 0/14, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/14, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/14, 0.0 false (nan vs 0.1)
# Neither filter filtered anything.
# VNEW  1.2432526773283779 m  14 xvar  55 count 0
# Linear filter...
# Filtered out 0/14, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/14, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/14, 0.0 false (nan vs 0.1)
# Neither filter filtered anything.
# VNEW  1.2426505114854631 m  14 xvar  55 count 0
# Linear filter...
# Filtered out 0/14, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/14, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/14, 0.0 false (nan vs 0.1)
# Neither filter filtered anything.
# VNEW  0.18574172239733455 m  14 xvar  55 count 0
# Linear filter...
# Filtered out 0/14, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/14, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/14, 0.0 false (nan vs 0.1)
# Neither filter filtered anything.
# VNEW  0.237240885383836 m  14 xvar  55 count 1
# Linear filter...
# Filtered out 0/14, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/14, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/14, 0.0 false (nan vs 0.1)
# Neither filter filtered anything.
# VNEW  0.21852781638789315 m  14 xvar  55 count 2
# Linear filter...
# Filtered out 0/14, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/14, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/14, 0.0 false (nan vs 0.1)
# Neither filter filtered anything.
# VNEW  0.626975000422295 m  14 xvar  55 count 3
# Linear filter...
# Filtered out 0/16, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/16, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/16, 0.0 false (nan vs 0.1)
# Neither filter filtered anything.
# VNEW  0.10674674177213471 m  16 xvar  55 count 0
# Linear filter...
# Filtered out 0/16, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/16, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/16, 0.0 false (nan vs 0.1)
# Neither filter filtered anything.
# VNEW  1.2037205999582536 m  16 xvar  55 count 1
# Linear filter...
# Filtered out 0/16, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/16, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/16, 0.0 false (nan vs 0.1)
# Neither filter filtered anything.
# VNEW  0.5405288625169729 m  16 xvar  55 count 1
# Linear filter...
# Filtered out 0/16, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/16, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/16, 0.0 false (nan vs 0.1)
# Neither filter filtered anything.
# VNEW  0.2558370964975881 m  16 xvar  55 count 2
# Linear filter...
# Filtered out 0/16, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/16, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/16, 0.0 false (nan vs 0.1)
# Neither filter filtered anything.
# VNEW  0.28001898393099617 m  16 xvar  55 count 3
# Linear filter...
# Filtered out 0/16, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/16, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/16, 0.0 false (nan vs 0.1)
# Neither filter filtered anything.
# VNEW  0.385285444118722 m  16 xvar  55 count 4
# Linear filter...
# Filtered out 0/16, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/16, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/16, 0.0 false (nan vs 0.1)
# Neither filter filtered anything.
# VNEW  1.7700248655721 m  16 xvar  55 count 5
# Linear filter...
# Filtered out 0/16, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/16, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/16, 0.0 false (nan vs 0.1)
# Neither filter filtered anything.
# VNEW  0.17941544300417137 m  16 xvar  55 count 5
# Linear filter...
# Filtered out 0/16, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/16, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/16, 0.0 false (nan vs 0.1)
# Neither filter filtered anything.
# VNEW  0.7618216077557269 m  16 xvar  55 count 6
# Linear filter...
# Filtered out 0/16, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/16, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/16, 0.0 false (nan vs 0.1)
# Neither filter filtered anything.
# VNEW  0.34362999506075526 m  16 xvar  55 count 7

# %%
plot_m_loss.plotxy('d', d_bounds, (0,100))
# Out:
# <style>
#
# </style>
#
# <div id="fig_el53223348089055688487287476"></div>
# <script>
# function mpld3_load_lib(url, callback){
#   var s = document.createElement('script');
#   s.src = url;
#   s.async = true;
#   s.onreadystatechange = s.onload = callback;
#   s.onerror = function(){console.warn("failed to load library " + url);};
#   document.getElementsByTagName("head")[0].appendChild(s);
# }
#
# if(typeof(mpld3) !== "undefined" && mpld3._mpld3IsLoaded){
#    // already loaded: just create the figure
#    !function(mpld3){
#
#        mpld3.draw_figure("fig_el53223348089055688487287476", {"width": 432.0, "height": 288.0, "axes": [], "data": {}, "id": "el5322334808905568", "plugins": [{"type": "reset"}, {"type": "zoom", "button": true, "enabled": false}, {"type": "boxzoom", "button": true, "enabled": false}]});
#    }(mpld3);
# }else if(typeof define === "function" && define.amd){
#    // require.js is available: use it to load d3/mpld3
#    require.config({paths: {d3: "https://mpld3.github.io/js/d3.v3.min"}});
#    require(["d3"], function(d3){
#       window.d3 = d3;
#       mpld3_load_lib("https://mpld3.github.io/js/mpld3.v0.3.1.dev1.js", function(){
#
#          mpld3.draw_figure("fig_el53223348089055688487287476", {"width": 432.0, "height": 288.0, "axes": [], "data": {}, "id": "el5322334808905568", "plugins": [{"type": "reset"}, {"type": "zoom", "button": true, "enabled": false}, {"type": "boxzoom", "button": true, "enabled": false}]});
#       });
#     });
# }else{
#     // require.js not available: dynamically load d3 & mpld3
#     mpld3_load_lib("https://mpld3.github.io/js/d3.v3.min.js", function(){
#          mpld3_load_lib("https://mpld3.github.io/js/mpld3.v0.3.1.dev1.js", function(){
#
#                  mpld3.draw_figure("fig_el53223348089055688487287476", {"width": 432.0, "height": 288.0, "axes": [], "data": {}, "id": "el5322334808905568", "plugins": [{"type": "reset"}, {"type": "zoom", "button": true, "enabled": false}, {"type": "boxzoom", "button": true, "enabled": false}]});
#             })
#          });
# }
# </script>

# %%
"Loss vs eps"

il.reload(rl)

trials = 10
d, k, m = 100, 1, 1000
eps_bounds = (0, 0.5, 0.01)
# model = rl.DenseNoiseModel(-100)

model = rl.TailFilpModel()
keys = [rl.RME_sp]
model_params = rl.Params(d=d, k=k, m=m)
ylims = (0, 1)

def err(a,b): return LA.norm(a-b)

plot_m_loss = rl.plot(model, model_params, err, keys)
plot_m_loss.setdata('eps', eps_bounds, trials, ylims)
# Out:
# /Users/sushrutk/GitHub/robust_sparse_mean_estimation/robustlib.py:285: RuntimeWarning: divide by zero encountered in double_scalars
#   if LA.norm(M_mask) < eps*(np.log(1/eps)):
# /Users/sushrutk/GitHub/robust_sparse_mean_estimation/robustlib.py:285: RuntimeWarning: invalid value encountered in double_scalars
#   if LA.norm(M_mask) < eps*(np.log(1/eps)):
# /Users/sushrutk/GitHub/robust_sparse_mean_estimation/robustlib.py:207: RuntimeWarning: divide by zero encountered in double_scalars
#   if ev > 1 + eps*np.sqrt(np.log(1/eps)):
# /Users/sushrutk/GitHub/robust_sparse_mean_estimation/robustlib.py:207: RuntimeWarning: invalid value encountered in double_scalars
#   if ev > 1 + eps*np.sqrt(np.log(1/eps)):
# /Users/sushrutk/GitHub/robust_sparse_mean_estimation/robustlib.py:240: RuntimeWarning: invalid value encountered in double_scalars
#   print(f"Filtered out {l - len(idx[0])}/{l}, {bad_filtered} false ({bad_filtered / (l - len(idx[0])):0.2f} vs {self.fdr})")
# /Users/sushrutk/GitHub/robust_sparse_mean_estimation/robustlib.py:224: RuntimeWarning: invalid value encountered in double_scalars
#   print(f"Filtered out {l - len(idx[0])}/{l}, {bad_filtered} false ({bad_filtered / (l - len(idx[0])):0.2f} vs {self.fdr})")
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Linear filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Linear filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Linear filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Linear filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Linear filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Linear filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Linear filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/999, 0.0 false (nan vs 0.1)
# condition 999 999
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Linear filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Linear filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Linear filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# /Users/sushrutk/GitHub/robust_sparse_mean_estimation/robustlib.py:285: RuntimeWarning: divide by zero encountered in double_scalars
#   if LA.norm(M_mask) < eps*(np.log(1/eps)):
# /Users/sushrutk/GitHub/robust_sparse_mean_estimation/robustlib.py:285: RuntimeWarning: invalid value encountered in double_scalars
#   if LA.norm(M_mask) < eps*(np.log(1/eps)):
# Linear filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Linear filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Linear filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Linear filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/999, 0.0 false (nan vs 0.1)
# condition 999 999
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Linear filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Linear filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Linear filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Linear filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Linear filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Linear filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/999, 0.0 false (nan vs 0.1)
# condition 999 999
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/999, 0.0 false (nan vs 0.1)
# condition 999 999
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Linear filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Linear filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Linear filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Linear filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Linear filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Linear filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Linear filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/999, 0.0 false (nan vs 0.1)
# condition 999 999
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Linear filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Linear filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Linear filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Linear filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Linear filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Linear filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Linear filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Linear filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Linear filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Linear filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Linear filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Linear filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Linear filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Linear filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Linear filter...
# Filtered out 0/999, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/999, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/999, 0.0 false (nan vs 0.1)
# condition 999 999
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/999, 0.0 false (nan vs 0.1)
# condition 999 999
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Linear filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Linear filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Linear filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Linear filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Linear filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Linear filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Linear filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Linear filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/999, 0.0 false (nan vs 0.1)
# condition 999 999
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Linear filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Linear filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Linear filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Linear filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Linear filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Linear filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/999, 0.0 false (nan vs 0.1)
# condition 999 999
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/999, 0.0 false (nan vs 0.1)
# condition 999 999
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Linear filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Linear filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Linear filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Linear filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Linear filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Linear filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/999, 0.0 false (nan vs 0.1)
# condition 999 999
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/998, 0.0 false (nan vs 0.1)
# condition 998 998
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Linear filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Linear filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Linear filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Linear filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Linear filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Linear filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/999, 0.0 false (nan vs 0.1)
# condition 999 999
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter
# Quadratic filter...
# Filtered out 0/1000, 0.0 false (nan vs 0.1)
# condition 1000 1000
# Could not filter

# %%
plot_m_loss.plotxy('eps', eps_bounds, (0,1))
# Out:
# <style>
#
# </style>
#
# <div id="fig_el56517347922038246414815553"></div>
# <script>
# function mpld3_load_lib(url, callback){
#   var s = document.createElement('script');
#   s.src = url;
#   s.async = true;
#   s.onreadystatechange = s.onload = callback;
#   s.onerror = function(){console.warn("failed to load library " + url);};
#   document.getElementsByTagName("head")[0].appendChild(s);
# }
#
# if(typeof(mpld3) !== "undefined" && mpld3._mpld3IsLoaded){
#    // already loaded: just create the figure
#    !function(mpld3){
#
#        mpld3.draw_figure("fig_el56517347922038246414815553", {"width": 432.0, "height": 288.0, "axes": [], "data": {}, "id": "el5651734792203824", "plugins": [{"type": "reset"}, {"type": "zoom", "button": true, "enabled": false}, {"type": "boxzoom", "button": true, "enabled": false}]});
#    }(mpld3);
# }else if(typeof define === "function" && define.amd){
#    // require.js is available: use it to load d3/mpld3
#    require.config({paths: {d3: "https://mpld3.github.io/js/d3.v3.min"}});
#    require(["d3"], function(d3){
#       window.d3 = d3;
#       mpld3_load_lib("https://mpld3.github.io/js/mpld3.v0.3.1.dev1.js", function(){
#
#          mpld3.draw_figure("fig_el56517347922038246414815553", {"width": 432.0, "height": 288.0, "axes": [], "data": {}, "id": "el5651734792203824", "plugins": [{"type": "reset"}, {"type": "zoom", "button": true, "enabled": false}, {"type": "boxzoom", "button": true, "enabled": false}]});
#       });
#     });
# }else{
#     // require.js not available: dynamically load d3 & mpld3
#     mpld3_load_lib("https://mpld3.github.io/js/d3.v3.min.js", function(){
#          mpld3_load_lib("https://mpld3.github.io/js/mpld3.v0.3.1.dev1.js", function(){
#
#                  mpld3.draw_figure("fig_el56517347922038246414815553", {"width": 432.0, "height": 288.0, "axes": [], "data": {}, "id": "el5651734792203824", "plugins": [{"type": "reset"}, {"type": "zoom", "button": true, "enabled": false}, {"type": "boxzoom", "button": true, "enabled": false}]});
#             })
#          });
# }
# </script>

# %%
"Loss vs sparsity"
il.reload(rl)

trials = 5
d, eps, m = 1000, 0.1, 9000
k_bounds = (50, 200, 25)

model = rl.DenseNoiseModel(-2)
# model = rl.BimodalModel()

keys = [rl.RME_sp, rl.RME, rl.RME_sp_L, rl.ransacGaussianMean]
model_params = rl.Params(d = d, eps = eps, m = m)
ylims = (0, 1)

def err(a,b): return LA.norm(a-b)

plot_m_loss = rl.plot(model, model_params, err, keys)
plot_m_loss.setdata('k', k_bounds, trials, ylims)
# Out:
# Linear filter...
# Filtered out 881/8981, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/8100, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/8100, 0.0 false (nan vs 0.1)
# condition 8100 8100
# Could not filter
# Linear filter...
# Filtered out 988/8981, 107.0 false (0.11 vs 0.1)
# Linear filter...
# Filtered out 244/7993, 244.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 191/7749, 191.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 216/7558, 216.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 211/7342, 211.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 225/7131, 225.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 216/6906, 216.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 217/6690, 217.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 209/6473, 209.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 187/6264, 187.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 205/6077, 205.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 221/5872, 221.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 196/5651, 196.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 222/5455, 222.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 191/5233, 191.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 216/5042, 216.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 195/4826, 195.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 244/4631, 244.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 239/4387, 239.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 233/4148, 233.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 263/3915, 263.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 257/3652, 257.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 222/3395, 222.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 269/3173, 269.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 262/2904, 262.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 249/2642, 249.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 265/2393, 265.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 266/2128, 266.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 260/1862, 260.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 257/1602, 257.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 272/1345, 272.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 284/1073, 284.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 232/789, 232.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 216/557, 216.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 165/341, 165.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 94/176, 94.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 51/82, 51.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 22/31, 22.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 8/9, 8.0 false (1.00 vs 0.1)
# 1 point remaining.
# Linear filter...
# Filtered out 881/8981, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/8100, 0.0 false (nan vs 0.1)
# Could not filter
# ransacN 4490
# Linear filter...
# Filtered out 877/8977, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/8100, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/8100, 0.0 false (nan vs 0.1)
# condition 8100 8100
# Could not filter
# Linear filter...
# Filtered out 971/8977, 94.0 false (0.10 vs 0.1)
# Linear filter...
# Filtered out 237/8006, 237.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 184/7769, 184.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 229/7585, 229.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 175/7356, 175.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 216/7181, 216.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 174/6965, 174.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 201/6791, 201.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 184/6590, 184.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 155/6406, 155.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 243/6251, 243.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 206/6008, 206.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 230/5802, 230.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 204/5572, 204.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 215/5368, 215.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 200/5153, 200.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 250/4953, 250.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 228/4703, 228.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 217/4475, 217.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 225/4258, 225.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 270/4033, 270.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 247/3763, 247.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 249/3516, 249.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 246/3267, 246.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 236/3021, 236.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 270/2785, 270.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 270/2515, 270.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 290/2245, 290.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 291/1955, 291.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 260/1664, 260.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 272/1404, 272.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 255/1132, 255.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 253/877, 253.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 204/624, 204.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 184/420, 184.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 124/236, 124.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 74/112, 74.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 30/38, 30.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 6/8, 6.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Could not filter
# Linear filter...
# Filtered out 877/8977, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/8100, 0.0 false (nan vs 0.1)
# Could not filter
# ransacN 4488
# Linear filter...
# Filtered out 871/8971, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/8100, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/8100, 0.0 false (nan vs 0.1)
# condition 8100 8100
# Could not filter
# Linear filter...
# Filtered out 965/8971, 94.0 false (0.10 vs 0.1)
# Linear filter...
# Filtered out 202/8006, 202.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 204/7804, 204.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 187/7600, 187.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 221/7413, 221.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 223/7192, 223.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 151/6969, 151.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 199/6818, 199.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 196/6619, 196.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 183/6423, 183.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 210/6240, 210.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 207/6030, 207.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 225/5823, 225.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 210/5598, 210.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 187/5388, 187.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 234/5201, 234.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 237/4967, 237.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 261/4730, 261.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 258/4469, 258.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 282/4211, 282.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 255/3929, 255.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 248/3674, 248.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 251/3426, 251.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 211/3175, 211.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 290/2964, 290.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 257/2674, 257.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 303/2417, 303.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 269/2114, 269.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 279/1845, 279.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 271/1566, 271.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 265/1295, 265.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 258/1030, 258.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 227/772, 227.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 226/545, 226.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 142/319, 142.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 112/177, 112.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 44/65, 44.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 17/21, 17.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 0/4, 0.0 false (nan vs 0.1)
# Could not filter
# Linear filter...
# Filtered out 871/8971, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/8100, 0.0 false (nan vs 0.1)
# Could not filter
# ransacN 4485
# Linear filter...
# Filtered out 879/8978, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/8099, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/8099, 0.0 false (nan vs 0.1)
# condition 8099 8099
# Could not filter
# Linear filter...
# Filtered out 955/8978, 76.0 false (0.08 vs 0.1)
# Linear filter...
# Filtered out 202/8023, 202.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 169/7821, 169.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 203/7652, 203.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 190/7449, 190.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 202/7259, 202.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 229/7057, 229.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 170/6828, 170.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 202/6658, 202.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 173/6456, 173.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 205/6283, 205.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 208/6078, 208.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 213/5870, 213.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 180/5657, 180.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 179/5477, 179.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 214/5298, 214.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 229/5084, 229.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 237/4855, 237.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 221/4618, 221.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 226/4397, 226.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 255/4171, 255.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 206/3916, 206.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 260/3710, 260.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 248/3450, 248.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 251/3202, 251.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 240/2951, 240.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 284/2711, 284.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 265/2427, 265.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 267/2162, 267.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 264/1895, 264.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 276/1631, 276.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 250/1355, 250.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 277/1105, 277.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 245/828, 245.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 202/583, 202.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 152/381, 152.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 118/229, 118.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 69/111, 69.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 27/42, 27.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 11/15, 11.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 0/4, 0.0 false (nan vs 0.1)
# Could not filter
# Linear filter...
# Filtered out 879/8978, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/8099, 0.0 false (nan vs 0.1)
# Could not filter
# ransacN 4489
# Linear filter...
# Filtered out 872/8972, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/8100, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/8100, 0.0 false (nan vs 0.1)
# condition 8100 8100
# Could not filter
# Linear filter...
# Filtered out 950/8972, 78.0 false (0.08 vs 0.1)
# Linear filter...
# Filtered out 194/8022, 194.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 202/7828, 202.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 198/7626, 198.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 193/7428, 193.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 178/7235, 178.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 163/7057, 163.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 203/6894, 203.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 171/6691, 171.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 215/6520, 215.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 175/6305, 175.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 196/6130, 196.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 230/5934, 230.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 213/5704, 213.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 208/5491, 208.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 284/5283, 284.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 260/4999, 260.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 251/4739, 251.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 213/4488, 213.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 236/4275, 236.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 258/4039, 258.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 268/3781, 268.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 225/3513, 225.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 275/3288, 275.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 307/3013, 307.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 251/2706, 251.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 247/2455, 247.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 277/2208, 277.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 243/1931, 243.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 286/1688, 286.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 274/1402, 274.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 256/1128, 256.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 243/872, 243.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 228/629, 228.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 160/401, 160.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 108/241, 108.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 79/133, 79.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 37/54, 37.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 14/17, 14.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 0/3, 0.0 false (nan vs 0.1)
# Could not filter
# Linear filter...
# Filtered out 872/8972, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/8100, 0.0 false (nan vs 0.1)
# Could not filter
# ransacN 4486
# Linear filter...
# Filtered out 872/8972, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/8100, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/8100, 0.0 false (nan vs 0.1)
# condition 8100 8100
# Could not filter
# Linear filter...
# Filtered out 965/8972, 93.0 false (0.10 vs 0.1)
# Linear filter...
# Filtered out 236/8007, 236.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 190/7771, 190.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 178/7581, 178.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 216/7403, 216.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 201/7187, 201.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 205/6986, 205.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 252/6781, 252.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 201/6529, 201.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 247/6328, 247.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 201/6081, 201.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 217/5880, 217.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 210/5663, 210.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 211/5453, 211.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 231/5242, 231.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 227/5011, 227.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 228/4784, 228.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 241/4556, 241.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 254/4315, 254.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 196/4061, 196.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 270/3865, 270.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 247/3595, 247.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 273/3348, 273.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 245/3075, 245.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 271/2830, 271.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 298/2559, 298.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 266/2261, 266.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 256/1995, 256.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 282/1739, 282.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 265/1457, 265.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 298/1192, 298.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 253/894, 253.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 199/641, 199.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 179/442, 179.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 127/263, 127.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 83/136, 83.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 37/53, 37.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 12/16, 12.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 0/4, 0.0 false (nan vs 0.1)
# Could not filter
# Linear filter...
# Filtered out 872/8972, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/8100, 0.0 false (nan vs 0.1)
# Could not filter
# ransacN 4486
# Linear filter...
# Filtered out 871/8971, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/8100, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/8100, 0.0 false (nan vs 0.1)
# condition 8100 8100
# Could not filter
# Linear filter...
# Filtered out 961/8971, 90.0 false (0.09 vs 0.1)
# Linear filter...
# Filtered out 190/8010, 190.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 212/7820, 212.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 189/7608, 189.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 197/7419, 197.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 200/7222, 200.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 190/7022, 190.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 209/6832, 209.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 234/6623, 234.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 216/6389, 216.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 245/6173, 245.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 188/5928, 188.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 217/5740, 217.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 202/5523, 202.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 220/5321, 220.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 216/5101, 216.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 218/4885, 218.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 234/4667, 234.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 206/4433, 206.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 248/4227, 248.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 237/3979, 237.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 241/3742, 241.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 234/3501, 234.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 228/3267, 228.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 276/3039, 276.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 266/2763, 266.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 282/2497, 282.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 291/2215, 291.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 259/1924, 259.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 265/1665, 265.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 272/1400, 272.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 232/1128, 232.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 254/896, 254.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 219/642, 219.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 168/423, 168.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 122/255, 122.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 78/133, 78.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 41/55, 41.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 12/14, 12.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Could not filter
# Linear filter...
# Filtered out 871/8971, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/8100, 0.0 false (nan vs 0.1)
# Could not filter
# ransacN 4485
# Linear filter...
# Filtered out 874/8974, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/8100, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/8100, 0.0 false (nan vs 0.1)
# condition 8100 8100
# Could not filter
# Linear filter...
# Filtered out 956/8974, 82.0 false (0.09 vs 0.1)
# Linear filter...
# Filtered out 220/8018, 220.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 179/7798, 179.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 186/7619, 186.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 166/7433, 166.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 215/7267, 215.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 211/7052, 211.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 169/6841, 169.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 173/6672, 173.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 210/6499, 210.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 206/6289, 206.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 210/6083, 210.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 236/5873, 236.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 240/5637, 240.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 155/5397, 155.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 186/5242, 186.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 219/5056, 219.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 196/4837, 196.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 227/4641, 227.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 222/4414, 222.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 245/4192, 245.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 203/3947, 203.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 258/3744, 258.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 250/3486, 250.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 261/3236, 261.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 273/2975, 273.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 267/2702, 267.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 255/2435, 255.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 305/2180, 305.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 292/1875, 292.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 265/1583, 265.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 295/1318, 295.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 251/1023, 251.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 203/772, 203.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 175/569, 175.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 159/394, 159.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 104/235, 104.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 79/131, 79.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 46/52, 46.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 0/6, 0.0 false (nan vs 0.1)
# Could not filter
# Linear filter...
# Filtered out 874/8974, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/8100, 0.0 false (nan vs 0.1)
# Could not filter
# ransacN 4487
# Linear filter...
# Filtered out 883/8983, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/8100, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/8100, 0.0 false (nan vs 0.1)
# condition 8100 8100
# Could not filter
# Linear filter...
# Filtered out 988/8983, 105.0 false (0.11 vs 0.1)
# Linear filter...
# Filtered out 167/7995, 167.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 183/7828, 183.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 156/7645, 156.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 189/7489, 189.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 193/7300, 193.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 231/7107, 231.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 201/6876, 201.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 227/6675, 227.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 234/6448, 234.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 197/6214, 197.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 209/6017, 209.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 228/5808, 228.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 212/5580, 212.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 236/5368, 236.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 202/5132, 202.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 234/4930, 234.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 207/4696, 207.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 245/4489, 245.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 236/4244, 236.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 243/4008, 243.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 243/3765, 243.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 237/3522, 237.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 278/3285, 278.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 274/3007, 274.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 271/2733, 271.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 254/2462, 254.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 257/2208, 257.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 281/1951, 281.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 258/1670, 258.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 274/1412, 274.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 262/1138, 262.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 238/876, 238.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 194/638, 194.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 186/444, 186.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 126/258, 126.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 75/132, 75.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 32/57, 32.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 23/25, 23.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Could not filter
# Linear filter...
# Filtered out 883/8983, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/8100, 0.0 false (nan vs 0.1)
# Could not filter
# ransacN 4491
# Linear filter...
# Filtered out 888/8988, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/8100, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/8100, 0.0 false (nan vs 0.1)
# condition 8100 8100
# Could not filter
# Linear filter...
# Filtered out 974/8988, 86.0 false (0.09 vs 0.1)
# Linear filter...
# Filtered out 231/8014, 231.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 195/7783, 195.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 217/7588, 217.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 214/7371, 214.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 215/7157, 215.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 262/6942, 262.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 141/6680, 141.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 188/6539, 188.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 177/6351, 177.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 208/6174, 208.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 214/5966, 214.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 234/5752, 234.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 189/5518, 189.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 222/5329, 222.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 214/5107, 214.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 209/4893, 209.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 247/4684, 247.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 232/4437, 232.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 234/4205, 234.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 248/3971, 248.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 247/3723, 247.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 244/3476, 244.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 277/3232, 277.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 305/2955, 305.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 285/2650, 285.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 267/2365, 267.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 304/2098, 304.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 288/1794, 288.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 309/1506, 309.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 255/1197, 255.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 229/942, 229.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 235/713, 235.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 190/478, 190.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 149/288, 149.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 78/139, 78.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 44/61, 44.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 13/17, 13.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 0/4, 0.0 false (nan vs 0.1)
# Could not filter
# Linear filter...
# Filtered out 888/8988, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/8100, 0.0 false (nan vs 0.1)
# Could not filter
# ransacN 4494
# Linear filter...
# Filtered out 885/8985, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/8100, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/8100, 0.0 false (nan vs 0.1)
# condition 8100 8100
# Could not filter
# Linear filter...
# Filtered out 987/8985, 102.0 false (0.10 vs 0.1)
# Linear filter...
# Filtered out 192/7998, 192.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 226/7806, 226.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 190/7580, 190.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 187/7390, 187.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 205/7203, 205.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 185/6998, 185.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 211/6813, 211.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 226/6602, 226.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 183/6376, 183.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 173/6193, 173.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 230/6020, 230.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 204/5790, 204.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 221/5586, 221.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 204/5365, 204.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 203/5161, 203.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 211/4958, 211.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 215/4747, 215.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 256/4532, 256.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 242/4276, 242.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 193/4034, 193.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 230/3841, 230.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 273/3611, 273.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 256/3338, 256.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 278/3082, 278.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 266/2804, 266.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 267/2538, 267.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 279/2271, 279.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 294/1992, 294.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 299/1698, 299.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 290/1399, 290.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 263/1109, 263.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 243/846, 243.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 209/603, 209.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 157/394, 157.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 122/237, 122.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 83/115, 83.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 25/32, 25.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 6/7, 6.0 false (1.00 vs 0.1)
# 1 point remaining.
# Linear filter...
# Filtered out 885/8985, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/8100, 0.0 false (nan vs 0.1)
# Could not filter
# ransacN 4492
# Linear filter...
# Filtered out 880/8980, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/8100, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/8100, 0.0 false (nan vs 0.1)
# condition 8100 8100
# Could not filter
# Linear filter...
# Filtered out 951/8980, 71.0 false (0.07 vs 0.1)
# Linear filter...
# Filtered out 203/8029, 203.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 211/7826, 211.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 210/7615, 210.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 137/7405, 137.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 183/7268, 183.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 221/7085, 221.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 191/6864, 191.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 181/6673, 181.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 174/6492, 174.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 189/6318, 189.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 208/6129, 208.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 215/5921, 215.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 241/5706, 241.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 213/5465, 213.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 234/5252, 234.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 237/5018, 237.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 215/4781, 215.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 265/4566, 265.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 246/4301, 246.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 240/4055, 240.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 224/3815, 224.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 252/3591, 252.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 236/3339, 236.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 267/3103, 267.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 246/2836, 246.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 266/2590, 266.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 264/2324, 264.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 296/2060, 296.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 269/1764, 269.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 268/1495, 268.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 267/1227, 267.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 233/960, 233.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 230/727, 230.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 177/497, 177.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 146/320, 146.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 94/174, 94.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 51/80, 51.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 21/29, 21.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 0/8, 0.0 false (nan vs 0.1)
# Could not filter
# Linear filter...
# Filtered out 880/8980, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/8100, 0.0 false (nan vs 0.1)
# Could not filter
# ransacN 4490
# Linear filter...
# Filtered out 867/8967, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/8100, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/8100, 0.0 false (nan vs 0.1)
# condition 8100 8100
# Could not filter
# Linear filter...
# Filtered out 959/8967, 92.0 false (0.10 vs 0.1)
# Linear filter...
# Filtered out 215/8008, 215.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 189/7793, 189.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 166/7604, 166.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 218/7438, 218.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 202/7220, 202.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 200/7018, 200.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 159/6818, 159.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 195/6659, 195.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 181/6464, 181.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 233/6283, 233.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 232/6050, 232.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 216/5818, 216.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 229/5602, 229.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 203/5373, 203.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 209/5170, 209.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 192/4961, 192.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 254/4769, 254.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 227/4515, 227.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 212/4288, 212.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 256/4076, 256.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 268/3820, 268.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 253/3552, 253.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 246/3299, 246.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 275/3053, 275.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 247/2778, 247.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 285/2531, 285.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 271/2246, 271.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 279/1975, 279.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 247/1696, 247.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 248/1449, 248.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 245/1201, 245.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 247/956, 247.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 205/709, 205.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 187/504, 187.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 125/317, 125.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 112/192, 112.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 51/80, 51.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 25/29, 25.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 0/4, 0.0 false (nan vs 0.1)
# Could not filter
# Linear filter...
# Filtered out 867/8967, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/8100, 0.0 false (nan vs 0.1)
# Could not filter
# ransacN 4483
# Linear filter...
# Filtered out 877/8977, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/8100, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/8100, 0.0 false (nan vs 0.1)
# condition 8100 8100
# Could not filter
# Linear filter...
# Filtered out 980/8977, 103.0 false (0.11 vs 0.1)
# Linear filter...
# Filtered out 165/7997, 165.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 230/7832, 230.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 195/7602, 195.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 211/7407, 211.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 217/7196, 217.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 210/6979, 210.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 230/6769, 230.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 208/6539, 208.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 216/6331, 216.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 215/6115, 215.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 217/5900, 217.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 205/5683, 205.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 198/5478, 198.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 199/5280, 199.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 218/5081, 218.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 206/4863, 206.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 231/4657, 231.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 225/4426, 225.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 262/4201, 262.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 250/3939, 250.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 250/3689, 250.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 236/3439, 236.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 287/3203, 287.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 284/2916, 284.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 279/2632, 279.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 281/2353, 281.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 261/2072, 261.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 269/1811, 269.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 271/1542, 271.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 279/1271, 279.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 252/992, 252.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 230/740, 230.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 186/510, 186.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 134/324, 134.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 113/190, 113.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 50/77, 50.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 21/27, 21.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 0/6, 0.0 false (nan vs 0.1)
# Could not filter
# Linear filter...
# Filtered out 877/8977, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/8100, 0.0 false (nan vs 0.1)
# Could not filter
# ransacN 4488
# Linear filter...
# Filtered out 880/8980, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/8100, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/8100, 0.0 false (nan vs 0.1)
# condition 8100 8100
# Could not filter
# Linear filter...
# Filtered out 969/8980, 89.0 false (0.09 vs 0.1)
# Linear filter...
# Filtered out 195/8011, 195.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 214/7816, 214.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 165/7602, 165.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 193/7437, 193.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 196/7244, 196.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 204/7048, 204.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 219/6844, 219.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 215/6625, 215.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 256/6410, 256.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 220/6154, 220.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 223/5934, 223.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 219/5711, 219.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 239/5492, 239.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 244/5253, 244.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 203/5009, 203.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 218/4806, 218.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 229/4588, 229.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 256/4359, 256.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 231/4103, 231.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 246/3872, 246.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 263/3626, 263.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 259/3363, 259.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 283/3104, 283.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 257/2821, 257.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 287/2564, 287.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 286/2277, 286.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 276/1991, 276.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 293/1715, 293.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 280/1422, 280.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 253/1142, 253.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 240/889, 240.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 191/649, 191.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 185/458, 185.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 127/273, 127.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 85/146, 85.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 41/61, 41.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 15/20, 15.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 3/5, 3.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Could not filter
# Linear filter...
# Filtered out 880/8980, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/8100, 0.0 false (nan vs 0.1)
# Could not filter
# ransacN 4490
# Linear filter...
# Filtered out 876/8976, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/8100, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/8100, 0.0 false (nan vs 0.1)
# condition 8100 8100
# Could not filter
# Linear filter...
# Filtered out 985/8976, 109.0 false (0.11 vs 0.1)
# Linear filter...
# Filtered out 159/7991, 159.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 165/7832, 165.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 199/7667, 199.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 194/7468, 194.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 216/7274, 216.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 201/7058, 201.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 236/6857, 236.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 199/6621, 199.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 166/6422, 166.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 252/6256, 252.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 207/6004, 207.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 235/5797, 235.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 244/5562, 244.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 198/5318, 198.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 231/5120, 231.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 253/4889, 253.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 208/4636, 208.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 257/4428, 257.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 250/4171, 250.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 266/3921, 266.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 271/3655, 271.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 275/3384, 275.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 249/3109, 249.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 266/2860, 266.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 299/2594, 299.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 273/2295, 273.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 304/2022, 304.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 284/1718, 284.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 257/1434, 257.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 288/1177, 288.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 230/889, 230.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 217/659, 217.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 178/442, 178.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 134/264, 134.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 76/130, 76.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 32/54, 32.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 17/22, 17.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 4/5, 4.0 false (1.00 vs 0.1)
# 1 point remaining.
# Linear filter...
# Filtered out 876/8976, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/8100, 0.0 false (nan vs 0.1)
# Could not filter
# ransacN 4488
# Linear filter...
# Filtered out 881/8981, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/8100, 0.0 false (nan vs 0.1)
# Quadratic filter...
# ...
# Linear filter...
# Filtered out 198/7602, 198.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 139/7404, 139.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 212/7265, 212.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 203/7053, 203.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 177/6850, 177.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 204/6673, 204.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 221/6469, 221.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 228/6248, 228.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 190/6020, 190.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 210/5830, 210.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 202/5620, 202.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 218/5418, 218.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 238/5200, 238.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 241/4962, 241.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 228/4721, 228.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 225/4493, 225.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 261/4268, 261.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 233/4007, 233.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 245/3774, 245.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 263/3529, 263.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 255/3266, 255.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 250/3011, 250.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 275/2761, 275.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 284/2486, 284.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 274/2202, 274.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 280/1928, 280.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 253/1648, 253.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 284/1395, 284.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 249/1111, 249.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 218/862, 218.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 221/644, 221.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 158/423, 158.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 125/265, 125.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 87/140, 87.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 34/53, 34.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 16/19, 16.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 2/3, 2.0 false (1.00 vs 0.1)
# 1 point remaining.
# Linear filter...
# Filtered out 879/8979, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/8100, 0.0 false (nan vs 0.1)
# Could not filter
# ransacN 4489
# Linear filter...
# Filtered out 887/8987, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/8100, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/8100, 0.0 false (nan vs 0.1)
# condition 8100 8100
# Could not filter
# Linear filter...
# Filtered out 989/8987, 102.0 false (0.10 vs 0.1)
# Linear filter...
# Filtered out 147/7998, 147.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 219/7851, 219.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 186/7632, 186.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 226/7446, 226.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 207/7220, 207.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 259/7013, 259.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 207/6754, 207.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 192/6547, 192.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 177/6355, 177.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 200/6178, 200.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 236/5978, 236.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 195/5742, 195.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 229/5547, 229.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 181/5318, 181.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 170/5137, 170.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 196/4967, 196.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 227/4771, 227.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 208/4544, 208.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 227/4336, 227.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 218/4109, 218.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 218/3891, 218.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 264/3673, 264.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 273/3409, 273.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 248/3136, 248.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 255/2888, 255.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 280/2633, 280.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 295/2353, 295.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 261/2058, 261.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 265/1797, 265.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 289/1532, 289.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 283/1243, 283.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 256/960, 256.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 218/704, 218.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 181/486, 181.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 145/305, 145.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 86/160, 86.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 51/74, 51.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 19/23, 19.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 2/4, 2.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Could not filter
# Linear filter...
# Filtered out 887/8987, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/8100, 0.0 false (nan vs 0.1)
# Could not filter
# ransacN 4493
# Linear filter...
# Filtered out 872/8972, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/8100, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/8100, 0.0 false (nan vs 0.1)
# condition 8100 8100
# Could not filter
# Linear filter...
# Filtered out 961/8972, 89.0 false (0.09 vs 0.1)
# Linear filter...
# Filtered out 216/8011, 216.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 209/7795, 209.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 209/7586, 209.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 152/7377, 152.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 205/7225, 205.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 168/7020, 168.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 189/6852, 189.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 186/6663, 186.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 221/6477, 221.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 215/6256, 215.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 166/6041, 166.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 208/5875, 208.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 209/5667, 209.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 173/5458, 173.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 231/5285, 231.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 184/5054, 184.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 206/4870, 206.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 224/4664, 224.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 256/4440, 256.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 231/4184, 231.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 217/3953, 217.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 256/3736, 256.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 283/3480, 283.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 277/3197, 277.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 292/2920, 292.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 273/2628, 273.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 266/2355, 266.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 253/2089, 253.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 298/1836, 298.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 278/1538, 278.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 233/1260, 233.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 238/1027, 238.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 245/789, 245.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 177/544, 177.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 156/367, 156.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 106/211, 106.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 69/105, 69.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 31/36, 31.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 4/5, 4.0 false (1.00 vs 0.1)
# 1 point remaining.
# Linear filter...
# Filtered out 872/8972, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/8100, 0.0 false (nan vs 0.1)
# Could not filter
# ransacN 4486
# Linear filter...
# Filtered out 875/8975, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/8100, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/8100, 0.0 false (nan vs 0.1)
# condition 8100 8100
# Could not filter
# Linear filter...
# Filtered out 976/8975, 101.0 false (0.10 vs 0.1)
# Linear filter...
# Filtered out 246/7999, 246.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 209/7753, 209.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 196/7544, 196.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 231/7348, 231.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 229/7117, 229.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 190/6888, 190.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 215/6698, 215.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 216/6483, 216.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 184/6267, 184.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 160/6083, 160.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 182/5923, 182.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 194/5741, 194.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 188/5547, 188.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 230/5359, 230.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 185/5129, 185.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 204/4944, 204.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 221/4740, 221.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 257/4519, 257.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 227/4262, 227.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 224/4035, 224.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 252/3811, 252.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 276/3559, 276.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 294/3283, 294.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 274/2989, 274.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 283/2715, 283.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 270/2432, 270.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 290/2162, 290.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 263/1872, 263.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 274/1609, 274.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 267/1335, 267.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 270/1068, 270.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 239/798, 239.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 235/559, 235.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 151/324, 151.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 96/173, 96.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 51/77, 51.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 22/26, 22.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 0/4, 0.0 false (nan vs 0.1)
# Could not filter
# Linear filter...
# Filtered out 875/8975, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/8100, 0.0 false (nan vs 0.1)
# Could not filter
# ransacN 4487
# Linear filter...
# Filtered out 877/8977, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/8100, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/8100, 0.0 false (nan vs 0.1)
# condition 8100 8100
# Could not filter
# Linear filter...
# Filtered out 970/8977, 93.0 false (0.10 vs 0.1)
# Linear filter...
# Filtered out 216/8007, 216.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 214/7791, 214.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 199/7577, 199.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 176/7378, 176.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 179/7202, 179.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 173/7023, 173.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 212/6850, 212.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 185/6638, 185.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 199/6453, 199.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 200/6254, 200.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 203/6054, 203.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 182/5851, 182.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 227/5669, 227.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 236/5442, 236.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 225/5206, 225.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 228/4981, 228.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 235/4753, 235.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 211/4518, 211.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 209/4307, 209.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 226/4098, 226.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 259/3872, 259.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 259/3613, 259.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 259/3354, 259.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 237/3095, 237.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 272/2858, 272.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 260/2586, 260.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 237/2326, 237.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 269/2089, 269.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 281/1820, 281.0 false (1.00 vs 0.1)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-cc375a820d9d> in <module>
#      16
#      17 plot_m_loss = rl.plot(model, model_params, err, keys)
# ---> 18 plot_m_loss.setdata('k', k_bounds, trials, ylims)
#
# ~/GitHub/robust_sparse_mean_estimation/robustlib.py in setdata(self, xvar_name, bounds, trials, ylims, y_is_m, mrange)
#     481     def setdata(self, xvar_name, bounds, trials, ylims, y_is_m = False, mrange = []):
#     482         Runs_l_samples = RunCollection(self.get_dataxy, (xvar_name, bounds, y_is_m, mrange))
# --> 483         Runs_l_samples.run(trials)
#     484         self.Run = Runs_l_samples
#     485
#
# ~/GitHub/robust_sparse_mean_estimation/robustlib.py in run(self, trials)
#      16     def run(self, trials):
#      17         for i in range(trials):
# ---> 18             self.runs.append(self.func(*self.inp))
#      19
#      20
#
# ~/GitHub/robust_sparse_mean_estimation/robustlib.py in get_dataxy(self, xvar_name, bounds, y_is_m, mrange)
#     424                     func = f(inp_copy)
#     425
# --> 426                     results.setdefault(f.__name__, []).append(self.loss(func.alg(S_copy, indicator_copy), tm))
#     427
#     428                 results.setdefault('oracle', []).append(O)
#
# ~/GitHub/robust_sparse_mean_estimation/robustlib.py in alg(self, S, indicator)
#     294                     v = v.reshape(len(v),)
#     295                 else:
# --> 296                     ev, v = scipy.linalg.eigh(cov_e, eigvals=(d-1,d-1))
#     297                     if ev <  1+eps*np.log(1/eps):
#     298                         print("RME exited properly")
#
# ~/anaconda2/envs/p36workshop/lib/python3.6/site-packages/scipy/linalg/decomp.py in eigh(a, b, lower, eigvals_only, overwrite_a, overwrite_b, turbo, eigvals, type, check_finite)
#     434             (lo, hi) = eigvals
#     435             w_tot, v, info = evr(a1, uplo=uplo, jobz=_job, range="I",
# --> 436                                  il=lo, iu=hi, overwrite_a=overwrite_a)
#     437             w = w_tot[0:hi-lo+1]
#     438
#
# KeyboardInterrupt:

# %%
plot_m_loss.plotxy('k', k_bounds, (0,0.4))

# %%
"<<<< ALL RELEVANT PLOTS SHOULD BE ABOVE >>>>"

# %%
d = 100
k = 70
eps = 0.1
tau = 0.02 # Failure prob
# sample_size = int(4*((k**2)*np.log(d) + np.log(1/tau))*(1/eps**2))
m = 9000

true_mean = np.append(np.ones(k), np.zeros(d-k))
false_mean = np.append(np.zeros(d-k), np.ones(k))

tm = np.append(np.ones(k), np.zeros(d-k))
fm = np.append(np.zeros(d-k), np.ones(k))

cov = 2*np.identity(d) - np.diag(tm)

G = np.random.randn(m, d) + tm/LA.norm(tm)
G2 = np.random.multivariate_normal(np.zeros(d), cov, (m,))
G1 = np.random.multivariate_normal(np.zeros(d), cov, (m,))

# G1 = np.random.multivariate_normal(np.zeros(d), cov, (sample_size,))



print(G.shape)
S = G.copy()

indicator = np.zeros(len(S))
L = int(m*(1-eps))
M = int((L + m)/2)

S[L:M] = G1[L:M]
S[M:] = G2[M:]

# S[int(sample_size*(1-eps)):] += false_mean - true_mean
# S[int(sample_size*(1-eps)):] = true_mean + 4.1
indicator[:L] = 1
# print(sum(indicator))
# print(len(indicator))
# print(indicator)
# print(len(S))

params = S, indicator, k, eps, tau
# params =  (G.copy(), S.copy(), indicator, m, d, eps, tau)

# %%
il.reload(rl)
# print("Dense mean estimation:", LA.norm(true_mean - rl.RME(params, plot=1)))
# print("Linear only:", LA.norm(true_mean - rl.RME_sp_L(params, plotl=1, plotc=0)))
# ans = rl.RME_sp_L(params, plotl=0, plotc=0)
print("Quadratic:", LA.norm(tm/LA.norm(tm) - rl.RME_sp(params, plotl=0, plotc=1, fdr=0.3)))
ans = rl.RME_sp(params, plotl=0, plotc=1, fdr=0.9)
print("fraction of zeros", len(ans[ans==0])/len(ans))
# print(tm)
# print("Ransac", LA.norm(true_mean - rl.ransacGaussianMean(params)))

# %%
plt.close()

# %%
il.reload(rl)

s = 10
m = 100
params = (3, m, 0.2, 0.02)
bounds = (5, 10, 10)
Runs = [rl.sparse_eps(params, bounds) for i in range(s)]

# %%
# fig1, ax1 = plt.subplots()
cols = {'RME_sp':'b', 'RME_sp_L':'g', 'RME':'r'}
for key in ['RME_sp', 'RME_sp_L']:#,'rl.ransacGaussianMean']:
#     for d in bounds[2]*np.arange(bounds[0], bounds[1]):

#         ax1.boxplot(np.array([res[key+str(eps)] for res in Runs]).transpose(), showfliers=False, whis = 0)
    A = np.array([res[key] for res in Runs])
    plt.plot(bounds[2]*np.arange(bounds[0], bounds[1]), np.array(np.median(A,axis = 0)), label=key, color = cols[key])
    mins = [np.sort(x)[int(s*0.25)] for x in A.T]
    maxs = [np.sort(x)[int(s*0.75)] for x in A.T]
    plt.fill_between(bounds[2]*np.arange(bounds[0], bounds[1]), mins, maxs, color=cols[key], alpha=0.2)
plt.title('k={}, naive filter algorithm'.format(params[0]))
plt.xlabel('dimension')
plt.ylabel('L2 - loss, scaled by eps')
plt.legend()

# for key in ['RME_sp', 'oracle', 'NP_sp']:
    
#     x = []
#     for d in  bounds[2]*np.arange(bounds[0], bounds[1]):
#         x.append(res[key+str(d)])
#     plt.plot(bounds[2]*np.arange(bounds[0], bounds[1]), x, label=key)

# #plt.plot(bounds[2]*np.arange(bounds[0], bounds[1]),np.sqrt(bounds[2]*np.arange(bounds[0], bounds[1])), label='sqrt')
# plt.title('k={}, naive filter algorithm'.format(params[0]))
# plt.xlabel('dimension')
# plt.ylabel('L2 - loss, scaled by eps')
# plt.legend()

# %%
il.reload(rl)
d = 100
k = 10
eps = 0.1
m = 100
s = 10

params = (d, k, m, eps, 0.02)
bounds = (0, 0.9, 0.1)
Runs = [rl.sparse_eps_dist(params, bounds) for i in range(s)]

# %%
cols = {'RME_sp':'b', 'RME_sp_L':'g', 'RME':'r'}
for key in ['RME_sp', 'RME_sp_L']:#,'rl.ransacGaussianMean']:
#     for d in bounds[2]*np.arange(bounds[0], bounds[1]):

#         ax1.boxplot(np.array([res[key+str(eps)] for res in Runs]).transpose(), showfliers=False, whis = 0)
    A = np.array([res[key] for res in Runs])
    plt.plot(np.arange(bounds[0], bounds[1], bounds[2]), np.array(np.median(A,axis = 0)), label=key, color = cols[key])
    mins = [np.sort(x)[int(s*0.25)] for x in A.T]
    maxs = [np.sort(x)[int(s*0.75)] for x in A.T]
    plt.fill_between(np.arange(bounds[0], bounds[1], bounds[2]), mins, maxs, color=cols[key], alpha=0.2)
plt.title('d = {}, k = {}, m = {}, eps = {}'.format(params[0], params[1], params[2], params[3]))
plt.xlabel('distance')
plt.ylabel('(loss)/eps')
plt.legend()



# for key in ['rl.RME_sp','rl.NP_sp', 'rl.ransacGaussianMean']:
#     x = []
#     for d in np.arange(bounds[0], bounds[1], bounds[2]):
#         x.append(np.array(res[key+str(d)]) - np.array(res['oracle'+str(d)]))
#     plt.plot(np.arange(bounds[0], bounds[1], bounds[2]), x, label=key)

# plt.title('d = {}, k = {}, m = {}, eps = {}'.format(params[0], params[1], params[2], params[3]))
# plt.xlabel('distance')
# plt.ylabel('(loss-(oracle loss))/eps')
# plt.legend()

# %%
def sparse_eps_eta(params, step): 
    (d, k, m, dist, tau) = params
    
    results = {}

    for eps in np.arange(step, 0.5, step):
        
        true_mean = np.append(np.ones(k),np.zeros(d-k))
#        true_mean = 0
        G = np.random.randn(m, d) + true_mean

        true_mean = np.append(np.ones(k),np.zeros(d-k))
        false_mean = np.append(np.zeros(d-k), np.ones(k))
#        true_mean = 0
        G = np.random.randn(m, d) + true_mean

        S = G.copy()
#        S[int(m*(1-eps)):] = true_mean + dist
        S[int(m*(1-eps)):] += dist*false_mean + true_mean
        indicator = np.ones(len(S))
        indicator[int(m*(1-eps)):] = 0

        params = (S.copy(), indicator, k, eps, tau)

        mu_o = np.mean(S[:int(m*(1-eps))], axis=0)
        u2 = np.argpartition(mu_o, -k)[-k:]
        z = np.zeros(len(mu_o))
        z[u2] = mu_o[u2]

        O = LA.norm(true_mean - z)

        # for func in [RME_sp, NP_sp]:
        # ... func(params)
        # Option 1: set RME_sp.name = 'RME_sp' somewhere, use func.name
        # Option 2: func.__name__
        
        for key in ['rl.RME_sp_L', 'rl.NP_sp', 'rl.ransacGaussianMean']:
            results.setdefault(key, []).append(LA.norm(true_mean - eval(key+'(params)')))

        results.setdefault('oracle', []).append(O)
        results.setdefault('eps', []).append(eps)
    
    return results

# %%
d = 10
k = 5
tau = 0.02
m = int(4*((k**2)*np.log(d) + np.log(1/tau))*(1/eps**2))
dist = 2
params = (d, k, m, dist, tau)
step = 0.01
res = sparse_eps_eta(params, step)

# %%
for key in ['rl.RME_sp_L', 'rl.NP_sp', 'rl.ransacGaussianMean']:
#     x = []
#     for d in np.arange(step, 0.5, step):
#         x.append(res[key+str(d)])
    plt.plot(np.arange(step, 0.5, step), (np.array(res[key])-np.array(res['oracle'])), label=key)

plt.title('d = {}, k = {}, m = {}, dist = {}'.format(params[0], params[1], params[2], params[3]))
plt.xlabel('eps')
plt.ylabel('(loss-(oracle loss))')
plt.legend()

# %%
def sparse_icml2017(params, bounds, toggle=0):
    (k, eps, tau) = params
    (Low, Up, step) = bounds
    
    results = {}

    for d in np.arange(Low, Up, step):
        
        m = int(4*((k**2)*np.log(d) + np.log(1/tau))*(1/eps**2))
        G, S = rl.ICML2017Noise_sp(d, k, m, eps,toggle)
        true_mean = np.append(np.ones(k), np.zeros(d-k))
        params = (S.copy(), eps, k, m, d, tau)
        
        mu_o = np.mean(S[:int(m*(1-eps))], axis=0)
        u2 = np.argpartition(mu_o, -k)[-k:]
        z = np.zeros(len(mu_o))
        z[u2] = mu_o[u2]

        O = LA.norm(true_mean - z)
        
        for key in ['RME_sp', 'NP_sp']:
            results.setdefault(key+str(d), []).append(LA.norm(true_mean - eval(key+'(params)'))/eps)

        results.setdefault('oracle'+str(d), []).append(O/eps)
        results.setdefault('eps'+str(d), []).append(1)
    
    return results

# %%
params = (3, 0.2, 0.02)
bounds = (10,4000,500)
res = sparse_icml2017(params, bounds, toggle=0)

# %%
for key in ['RME_sp', 'NP_sp', 'oracle']:
    x = []
    for d in np.arange(bounds[0], bounds[1], bounds[2]):
        x.append(res[key+str(d)])
    plt.plot(np.arange(bounds[0], bounds[1], bounds[2]), x, label=key)

plt.title('k={} naive filter algorithm on ICML2017 data'.format(params[0]))
plt.xlabel('dimension')
plt.ylabel('L2 - loss, scaled by eps')
plt.legend()

# %%
d = 2000
k = 3
eps = 0.2
m = int(4*((k**2)*np.log(d) + np.log(1/tau))*(1/eps**2))
G, S = rl.ICML2017Noise_sp(d, k, m, eps,toggle=0)
true_mean = np.append(np.ones(k), np.zeros(d-k))
params = (S.copy(), eps, k, m, d, tau)
