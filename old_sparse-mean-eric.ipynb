# %%
import numpy as np
import scipy
import robustlib as rl
import importlib as il
from scipy import special
from numpy import linalg as LA
import matplotlib.pyplot as plt
# %matplotlib inline
import mpld3
mpld3.enable_notebook()

# %%
""" Testing stuff """

il.reload(rl)

d, k, eps = 1000, 100, 0.1
m = 10000
params = rl.Params(d=d, k=k, eps=eps, m = m)


# model = rl.DenseNoiseModel(-2)
model = rl.BimodalModel()

print(f"Running on d={d}, k={k}, eps={eps}, m={m}")
inp, S, indicator, tm = model.generate(params)

A = rl.RME_sp_L(inp)
A.do_plot_linear = True
ans = A.alg(S, indicator)
print(LA.norm(tm - ans))

# err = rl.get_error(f, inp, tm=tm)
# print(f'Error for {f.__name__}: {err}')


# for f in [rl.RME_sp]:
#     err = rl.get_error(f, *inp)
#     print(f'Error for {f.__name__}: {err}')
# Out:
# Running on d=1000, k=100, eps=0.1, m=10000
# Linear filter...
# Filtered out 78/9991, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/9913, 0.0 false (nan vs 0.1)
# Could not filter
# 0.424530648918685
# /Users/sushrutk/GitHub/robust_sparse_mean_estimation/robustlib.py:223: RuntimeWarning: invalid value encountered in double_scalars
#   bad_filtered = np.sum(indicator) - np.sum(indicator[idx])

# %%
"sample complexity vs loss"

il.reload(rl)

trials = 10
d, k, eps = 100, 40, 0.1
m_bounds = (100, 1000, 100)
# model = rl.DenseNoiseModel(-100)

model = rl.BimodalModel()
# model = rl.DenseNoiseModel(-2)
keys = [rl.RME_sp, rl.RME_sp_L, rl.RME, rl.Oracle] #, rl.NP_sp, rl.RME_sp_L, rl.ransacGaussianMean]
model_params = rl.Params(d=d, k=k, eps=eps)
ylims = (0, 1)

def err(a,b): return LA.norm(a-b)

plot_m_loss = rl.plot(model, model_params, err, keys)
plot_m_loss.setdata('m', m_bounds, trials, ylims)




# Runs_l_samples = rl.RunCollection(rl.sparse_samp_loss, model, model_params, m_bounds, keys)
# Runs_l_samples.run(s)
# Out:
# Linear filter...
# Filtered out 2/99, 2.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 3/97, 3.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 0/94, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/94, 0.0 false (nan vs 0.1)
# condition 94 94
# Could not filter
# Linear filter...
# Filtered out 2/99, 2.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 3/97, 3.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 0/94, 0.0 false (nan vs 0.1)
# Could not filter
# Linear filter...
# Filtered out 18/99, 10.0 false (0.56 vs 0.1)
# Linear filter...
# Filtered out 29/81, 28.0 false (0.97 vs 0.1)
# Linear filter...
# Filtered out 20/52, 20.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 14/32, 14.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 0/18, 0.0 false (nan vs 0.1)
# Could not filter
# Linear filter...
# Filtered out 3/199, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/196, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/196, 0.0 false (nan vs 0.1)
# condition 196 196
# Could not filter
# Linear filter...
# Filtered out 3/199, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/196, 0.0 false (nan vs 0.1)
# Could not filter
# Linear filter...
# Filtered out 22/199, 12.0 false (0.55 vs 0.1)
# Linear filter...
# Filtered out 22/177, 20.0 false (0.91 vs 0.1)
# Linear filter...
# Filtered out 28/155, 23.0 false (0.82 vs 0.1)
# Linear filter...
# Filtered out 26/127, 24.0 false (0.92 vs 0.1)
# Linear filter...
# Filtered out 24/101, 24.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 22/77, 22.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 18/55, 18.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 12/37, 12.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 8/25, 8.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 8/17, 8.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 4/9, 4.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 3/5, 3.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Could not filter
# Linear filter...
# Filtered out 10/300, 1.0 false (0.10 vs 0.1)
# Linear filter...
# Filtered out 0/290, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/290, 0.0 false (nan vs 0.1)
# condition 290 290
# Could not filter
# Linear filter...
# Filtered out 10/300, 1.0 false (0.10 vs 0.1)
# Linear filter...
# Filtered out 0/290, 0.0 false (nan vs 0.1)
# Could not filter
# Linear filter...
# Filtered out 27/300, 9.0 false (0.33 vs 0.1)
# Linear filter...
# Filtered out 44/273, 38.0 false (0.86 vs 0.1)
# Linear filter...
# Filtered out 20/229, 18.0 false (0.90 vs 0.1)
# Linear filter...
# Filtered out 21/209, 21.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 28/188, 27.0 false (0.96 vs 0.1)
# Linear filter...
# Filtered out 18/160, 17.0 false (0.94 vs 0.1)
# Linear filter...
# Filtered out 24/142, 23.0 false (0.96 vs 0.1)
# Linear filter...
# Filtered out 16/118, 15.0 false (0.94 vs 0.1)
# Linear filter...
# Filtered out 19/102, 19.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 14/83, 14.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 20/69, 20.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 15/49, 15.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 15/34, 15.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 8/19, 8.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 0/11, 0.0 false (nan vs 0.1)
# Could not filter
# Linear filter...
# Filtered out 16/400, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/384, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/384, 0.0 false (nan vs 0.1)
# condition 384 384
# Could not filter
# Linear filter...
# Filtered out 16/400, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/384, 0.0 false (nan vs 0.1)
# Could not filter
# Linear filter...
# Filtered out 24/400, 4.0 false (0.17 vs 0.1)
# Linear filter...
# Filtered out 19/376, 14.0 false (0.74 vs 0.1)
# Linear filter...
# Filtered out 29/357, 26.0 false (0.90 vs 0.1)
# Linear filter...
# Filtered out 16/328, 12.0 false (0.75 vs 0.1)
# Linear filter...
# Filtered out 15/312, 14.0 false (0.93 vs 0.1)
# Linear filter...
# Filtered out 27/297, 25.0 false (0.93 vs 0.1)
# Linear filter...
# Filtered out 22/270, 20.0 false (0.91 vs 0.1)
# Linear filter...
# Filtered out 21/248, 19.0 false (0.90 vs 0.1)
# Linear filter...
# Filtered out 21/227, 20.0 false (0.95 vs 0.1)
# Linear filter...
# Filtered out 24/206, 24.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 25/182, 25.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 21/157, 21.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 20/136, 20.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 18/116, 18.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 19/98, 19.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 13/79, 13.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 22/66, 22.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 16/44, 16.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 9/28, 9.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 0/19, 0.0 false (nan vs 0.1)
# Could not filter
# Linear filter...
# Filtered out 7/498, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/491, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/491, 0.0 false (nan vs 0.1)
# condition 491 491
# Could not filter
# Linear filter...
# Filtered out 7/498, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/491, 0.0 false (nan vs 0.1)
# Could not filter
# Linear filter...
# Filtered out 32/498, 7.0 false (0.22 vs 0.1)
# Linear filter...
# Filtered out 22/466, 16.0 false (0.73 vs 0.1)
# Linear filter...
# Filtered out 22/444, 20.0 false (0.91 vs 0.1)
# Linear filter...
# Filtered out 34/422, 31.0 false (0.91 vs 0.1)
# Linear filter...
# Filtered out 24/388, 20.0 false (0.83 vs 0.1)
# Linear filter...
# Filtered out 14/364, 13.0 false (0.93 vs 0.1)
# Linear filter...
# Filtered out 16/350, 15.0 false (0.94 vs 0.1)
# Linear filter...
# Filtered out 12/334, 11.0 false (0.92 vs 0.1)
# Linear filter...
# Filtered out 12/322, 12.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 18/310, 17.0 false (0.94 vs 0.1)
# Linear filter...
# Filtered out 6/292, 6.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 13/286, 13.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 21/273, 21.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 11/252, 9.0 false (0.82 vs 0.1)
# Linear filter...
# Filtered out 12/241, 12.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 18/229, 17.0 false (0.94 vs 0.1)
# Linear filter...
# Filtered out 16/211, 16.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 15/195, 15.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 11/180, 11.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 16/169, 16.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 18/153, 18.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 13/135, 13.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 20/122, 20.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 22/102, 22.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 19/80, 18.0 false (0.95 vs 0.1)
# Linear filter...
# Filtered out 17/61, 17.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 18/44, 18.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 15/26, 15.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 0/11, 0.0 false (nan vs 0.1)
# Could not filter
# Linear filter...
# Filtered out 20/599, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/579, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/579, 0.0 false (nan vs 0.1)
# condition 579 579
# Could not filter
# Linear filter...
# Filtered out 20/599, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/579, 0.0 false (nan vs 0.1)
# Could not filter
# Linear filter...
# Filtered out 36/599, 7.0 false (0.19 vs 0.1)
# Linear filter...
# Filtered out 15/563, 10.0 false (0.67 vs 0.1)
# Linear filter...
# Filtered out 15/548, 11.0 false (0.73 vs 0.1)
# Linear filter...
# Filtered out 27/533, 24.0 false (0.89 vs 0.1)
# Linear filter...
# Filtered out 25/506, 22.0 false (0.88 vs 0.1)
# Linear filter...
# Filtered out 26/481, 22.0 false (0.85 vs 0.1)
# Linear filter...
# Filtered out 21/455, 18.0 false (0.86 vs 0.1)
# Linear filter...
# Filtered out 15/434, 12.0 false (0.80 vs 0.1)
# Linear filter...
# Filtered out 17/419, 14.0 false (0.82 vs 0.1)
# Linear filter...
# Filtered out 3/402, 2.0 false (0.67 vs 0.1)
# Linear filter...
# Filtered out 11/399, 11.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 10/388, 10.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 12/378, 12.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 0/366, 0.0 false (nan vs 0.1)
# Could not filter
# Linear filter...
# Filtered out 20/700, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/680, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/680, 0.0 false (nan vs 0.1)
# condition 680 680
# Could not filter
# Linear filter...
# Filtered out 20/700, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/680, 0.0 false (nan vs 0.1)
# Could not filter
# Linear filter...
# Filtered out 43/700, 5.0 false (0.12 vs 0.1)
# Linear filter...
# Filtered out 30/657, 22.0 false (0.73 vs 0.1)
# Linear filter...
# Filtered out 31/627, 28.0 false (0.90 vs 0.1)
# Linear filter...
# Filtered out 20/596, 17.0 false (0.85 vs 0.1)
# Linear filter...
# Filtered out 20/576, 17.0 false (0.85 vs 0.1)
# Linear filter...
# Filtered out 22/556, 20.0 false (0.91 vs 0.1)
# Linear filter...
# Filtered out 33/534, 32.0 false (0.97 vs 0.1)
# Linear filter...
# Filtered out 19/501, 17.0 false (0.89 vs 0.1)
# Linear filter...
# Filtered out 23/482, 23.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 14/459, 11.0 false (0.79 vs 0.1)
# Linear filter...
# Filtered out 18/445, 18.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 10/427, 10.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 16/417, 16.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 15/401, 14.0 false (0.93 vs 0.1)
# Linear filter...
# Filtered out 0/386, 0.0 false (nan vs 0.1)
# Could not filter
# Linear filter...
# Filtered out 23/800, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/777, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/777, 0.0 false (nan vs 0.1)
# condition 777 777
# Could not filter
# Linear filter...
# Filtered out 23/800, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/777, 0.0 false (nan vs 0.1)
# Could not filter
# Linear filter...
# Filtered out 45/800, 5.0 false (0.11 vs 0.1)
# Linear filter...
# Filtered out 24/755, 18.0 false (0.75 vs 0.1)
# Linear filter...
# Filtered out 16/731, 12.0 false (0.75 vs 0.1)
# Linear filter...
# Filtered out 25/715, 20.0 false (0.80 vs 0.1)
# Linear filter...
# Filtered out 18/690, 15.0 false (0.83 vs 0.1)
# Linear filter...
# Filtered out 15/672, 11.0 false (0.73 vs 0.1)
# Linear filter...
# Filtered out 17/657, 16.0 false (0.94 vs 0.1)
# Linear filter...
# Filtered out 15/640, 11.0 false (0.73 vs 0.1)
# Linear filter...
# Filtered out 19/625, 16.0 false (0.84 vs 0.1)
# Linear filter...
# Filtered out 21/606, 20.0 false (0.95 vs 0.1)
# Linear filter...
# Filtered out 6/585, 5.0 false (0.83 vs 0.1)
# Linear filter...
# Filtered out 8/579, 8.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 7/571, 6.0 false (0.86 vs 0.1)
# Linear filter...
# Filtered out 10/564, 8.0 false (0.80 vs 0.1)
# Linear filter...
# Filtered out 16/554, 15.0 false (0.94 vs 0.1)
# Linear filter...
# Filtered out 5/538, 5.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 4/533, 4.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 10/529, 10.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 5/519, 5.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 2/514, 1.0 false (0.50 vs 0.1)
# Linear filter...
# Filtered out 0/512, 0.0 false (nan vs 0.1)
# Could not filter
# Linear filter...
# Filtered out 20/897, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/877, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/877, 0.0 false (nan vs 0.1)
# condition 877 877
# Could not filter
# Linear filter...
# Filtered out 20/897, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/877, 0.0 false (nan vs 0.1)
# Could not filter
# Linear filter...
# Filtered out 58/897, 12.0 false (0.21 vs 0.1)
# Linear filter...
# Filtered out 17/839, 11.0 false (0.65 vs 0.1)
# Linear filter...
# Filtered out 21/822, 15.0 false (0.71 vs 0.1)
# Linear filter...
# Filtered out 19/801, 11.0 false (0.58 vs 0.1)
# Linear filter...
# Filtered out 8/782, 8.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 11/774, 9.0 false (0.82 vs 0.1)
# Linear filter...
# Filtered out 12/763, 10.0 false (0.83 vs 0.1)
# Linear filter...
# Filtered out 5/751, 5.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 12/746, 10.0 false (0.83 vs 0.1)
# Linear filter...
# Filtered out 0/734, 0.0 false (nan vs 0.1)
# Could not filter
# Linear filter...
# Filtered out 3/98, 1.0 false (0.33 vs 0.1)
# Linear filter...
# Filtered out 4/95, 3.0 false (0.75 vs 0.1)
# Linear filter...
# Filtered out 2/91, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/89, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/89, 0.0 false (nan vs 0.1)
# condition 89 89
# Could not filter
# Linear filter...
# Filtered out 3/98, 1.0 false (0.33 vs 0.1)
# Linear filter...
# Filtered out 4/95, 3.0 false (0.75 vs 0.1)
# Linear filter...
# Filtered out 2/91, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/89, 0.0 false (nan vs 0.1)
# Could not filter
# Linear filter...
# Filtered out 15/98, 10.0 false (0.67 vs 0.1)
# Linear filter...
# Filtered out 20/83, 17.0 false (0.85 vs 0.1)
# Linear filter...
# Filtered out 24/63, 24.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 17/39, 17.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 11/22, 11.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 0/11, 0.0 false (nan vs 0.1)
# Could not filter
# Linear filter...
# Filtered out 7/199, 4.0 false (0.57 vs 0.1)
# Linear filter...
# Filtered out 6/192, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 3/186, 2.0 false (0.67 vs 0.1)
# Linear filter...
# Filtered out 0/183, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/183, 0.0 false (nan vs 0.1)
# condition 183 183
# Could not filter
# Linear filter...
# Filtered out 7/199, 4.0 false (0.57 vs 0.1)
# Linear filter...
# Filtered out 6/192, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 3/186, 2.0 false (0.67 vs 0.1)
# Linear filter...
# Filtered out 0/183, 0.0 false (nan vs 0.1)
# Could not filter
# Linear filter...
# Filtered out 19/199, 7.0 false (0.37 vs 0.1)
# Linear filter...
# Filtered out 31/180, 28.0 false (0.90 vs 0.1)
# Linear filter...
# Filtered out 37/149, 36.0 false (0.97 vs 0.1)
# Linear filter...
# Filtered out 19/112, 18.0 false (0.95 vs 0.1)
# Linear filter...
# Filtered out 19/93, 19.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 22/74, 21.0 false (0.95 vs 0.1)
# Linear filter...
# Filtered out 20/52, 19.0 false (0.95 vs 0.1)
# Linear filter...
# Filtered out 8/32, 8.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 10/24, 10.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 7/14, 7.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 4/7, 4.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 0/3, 0.0 false (nan vs 0.1)
# Could not filter
# Linear filter...
# Filtered out 5/299, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/294, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/294, 0.0 false (nan vs 0.1)
# condition 294 294
# Could not filter
# Linear filter...
# Filtered out 5/299, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/294, 0.0 false (nan vs 0.1)
# Could not filter
# Linear filter...
# Filtered out 18/299, 3.0 false (0.17 vs 0.1)
# Linear filter...
# Filtered out 31/281, 23.0 false (0.74 vs 0.1)
# Linear filter...
# Filtered out 29/250, 29.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 26/221, 23.0 false (0.88 vs 0.1)
# Linear filter...
# Filtered out 23/195, 23.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 14/172, 12.0 false (0.86 vs 0.1)
# Linear filter...
# Filtered out 24/158, 23.0 false (0.96 vs 0.1)
# Linear filter...
# Filtered out 23/134, 23.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 32/111, 32.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 22/79, 22.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 13/57, 13.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 13/44, 13.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 9/31, 9.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 11/22, 11.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 5/11, 5.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 0/6, 0.0 false (nan vs 0.1)
# Could not filter
# Linear filter...
# Filtered out 6/399, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/393, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/393, 0.0 false (nan vs 0.1)
# condition 393 393
# Could not filter
# Linear filter...
# Filtered out 6/399, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/393, 0.0 false (nan vs 0.1)
# Could not filter
# Linear filter...
# Filtered out 24/399, 3.0 false (0.12 vs 0.1)
# Linear filter...
# Filtered out 35/375, 30.0 false (0.86 vs 0.1)
# Linear filter...
# Filtered out 37/340, 34.0 false (0.92 vs 0.1)
# Linear filter...
# Filtered out 28/303, 26.0 false (0.93 vs 0.1)
# Linear filter...
# Filtered out 21/275, 18.0 false (0.86 vs 0.1)
# Linear filter...
# Filtered out 25/254, 23.0 false (0.92 vs 0.1)
# Linear filter...
# Filtered out 25/229, 24.0 false (0.96 vs 0.1)
# Linear filter...
# Filtered out 21/204, 21.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 19/183, 17.0 false (0.89 vs 0.1)
# Linear filter...
# Filtered out 22/164, 22.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 21/142, 21.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 12/121, 12.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 22/109, 22.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 17/87, 17.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 15/70, 15.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 8/55, 8.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 13/47, 13.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 15/34, 15.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 10/19, 10.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 5/9, 5.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 2/4, 2.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Could not filter
# Linear filter...
# Filtered out 18/499, 1.0 false (0.06 vs 0.1)
# Linear filter...
# Filtered out 0/481, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/481, 0.0 false (nan vs 0.1)
# condition 481 481
# Could not filter
# Linear filter...
# Filtered out 18/499, 1.0 false (0.06 vs 0.1)
# Linear filter...
# Filtered out 0/481, 0.0 false (nan vs 0.1)
# Could not filter
# Linear filter...
# Filtered out 37/499, 11.0 false (0.30 vs 0.1)
# Linear filter...
# Filtered out 31/462, 22.0 false (0.71 vs 0.1)
# Linear filter...
# Filtered out 25/431, 22.0 false (0.88 vs 0.1)
# Linear filter...
# Filtered out 20/406, 18.0 false (0.90 vs 0.1)
# Linear filter...
# Filtered out 13/386, 11.0 false (0.85 vs 0.1)
# Linear filter...
# Filtered out 18/373, 16.0 false (0.89 vs 0.1)
# Linear filter...
# Filtered out 12/355, 11.0 false (0.92 vs 0.1)
# Linear filter...
# Filtered out 23/343, 22.0 false (0.96 vs 0.1)
# Linear filter...
# Filtered out 16/320, 16.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 17/304, 17.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 19/287, 19.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 22/268, 21.0 false (0.95 vs 0.1)
# Linear filter...
# Filtered out 14/246, 13.0 false (0.93 vs 0.1)
# Linear filter...
# Filtered out 16/232, 16.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 21/216, 21.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 18/195, 18.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 19/177, 18.0 false (0.95 vs 0.1)
# Linear filter...
# Filtered out 15/158, 15.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 22/143, 22.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 21/121, 21.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 19/100, 19.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 18/81, 18.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 21/63, 21.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 14/42, 14.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 10/28, 10.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 6/18, 6.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 7/12, 7.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 2/5, 2.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 0/3, 0.0 false (nan vs 0.1)
# Could not filter
# Linear filter...
# Filtered out 2/598, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/596, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/596, 0.0 false (nan vs 0.1)
# condition 596 596
# Could not filter
# Linear filter...
# Filtered out 2/598, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/596, 0.0 false (nan vs 0.1)
# Could not filter
# Linear filter...
# Filtered out 33/598, 2.0 false (0.06 vs 0.1)
# Linear filter...
# Filtered out 22/565, 16.0 false (0.73 vs 0.1)
# Linear filter...
# Filtered out 13/543, 11.0 false (0.85 vs 0.1)
# Linear filter...
# Filtered out 14/530, 14.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 27/516, 24.0 false (0.89 vs 0.1)
# Linear filter...
# Filtered out 23/489, 22.0 false (0.96 vs 0.1)
# Linear filter...
# Filtered out 15/466, 11.0 false (0.73 vs 0.1)
# Linear filter...
# Filtered out 13/451, 13.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 10/438, 9.0 false (0.90 vs 0.1)
# Linear filter...
# Filtered out 11/428, 10.0 false (0.91 vs 0.1)
# Linear filter...
# Filtered out 10/417, 8.0 false (0.80 vs 0.1)
# Linear filter...
# Filtered out 14/407, 13.0 false (0.93 vs 0.1)
# Linear filter...
# Filtered out 7/393, 7.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 4/386, 3.0 false (0.75 vs 0.1)
# Linear filter...
# Filtered out 2/382, 2.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 15/380, 13.0 false (0.87 vs 0.1)
# Linear filter...
# Filtered out 0/365, 0.0 false (nan vs 0.1)
# Could not filter
# Linear filter...
# Filtered out 21/699, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/678, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/678, 0.0 false (nan vs 0.1)
# condition 678 678
# Could not filter
# Linear filter...
# Filtered out 21/699, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/678, 0.0 false (nan vs 0.1)
# Could not filter
# Linear filter...
# Filtered out 41/699, 6.0 false (0.15 vs 0.1)
# Linear filter...
# Filtered out 15/658, 11.0 false (0.73 vs 0.1)
# Linear filter...
# Filtered out 13/643, 11.0 false (0.85 vs 0.1)
# Linear filter...
# Filtered out 32/630, 27.0 false (0.84 vs 0.1)
# Linear filter...
# Filtered out 24/598, 21.0 false (0.88 vs 0.1)
# Linear filter...
# Filtered out 16/574, 11.0 false (0.69 vs 0.1)
# Linear filter...
# Filtered out 11/558, 10.0 false (0.91 vs 0.1)
# Linear filter...
# Filtered out 9/547, 6.0 false (0.67 vs 0.1)
# Linear filter...
# Filtered out 21/538, 21.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 15/517, 15.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 9/502, 7.0 false (0.78 vs 0.1)
# Linear filter...
# Filtered out 15/493, 15.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 2/478, 1.0 false (0.50 vs 0.1)
# Linear filter...
# Filtered out 10/476, 9.0 false (0.90 vs 0.1)
# Linear filter...
# Filtered out 12/466, 12.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 0/454, 0.0 false (nan vs 0.1)
# Could not filter
# Linear filter...
# Filtered out 18/798, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/780, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/780, 0.0 false (nan vs 0.1)
# condition 780 780
# Could not filter
# Linear filter...
# Filtered out 18/798, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/780, 0.0 false (nan vs 0.1)
# Could not filter
# Linear filter...
# Filtered out 51/798, 10.0 false (0.20 vs 0.1)
# Linear filter...
# Filtered out 16/747, 13.0 false (0.81 vs 0.1)
# Linear filter...
# Filtered out 28/731, 20.0 false (0.71 vs 0.1)
# Linear filter...
# Filtered out 17/703, 15.0 false (0.88 vs 0.1)
# Linear filter...
# Filtered out 25/686, 20.0 false (0.80 vs 0.1)
# Linear filter...
# Filtered out 12/661, 9.0 false (0.75 vs 0.1)
# Linear filter...
# Filtered out 17/649, 14.0 false (0.82 vs 0.1)
# Linear filter...
# Filtered out 16/632, 12.0 false (0.75 vs 0.1)
# Linear filter...
# Filtered out 8/616, 8.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 16/608, 16.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 14/592, 13.0 false (0.93 vs 0.1)
# Linear filter...
# Filtered out 7/578, 7.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 0/571, 0.0 false (nan vs 0.1)
# Could not filter
# Linear filter...
# Filtered out 18/899, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/881, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/881, 0.0 false (nan vs 0.1)
# condition 881 881
# Could not filter
# Linear filter...
# Filtered out 18/899, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/881, 0.0 false (nan vs 0.1)
# Could not filter
# Linear filter...
# Filtered out 58/899, 13.0 false (0.22 vs 0.1)
# Linear filter...
# Filtered out 18/841, 14.0 false (0.78 vs 0.1)
# Linear filter...
# Filtered out 5/823, 3.0 false (0.60 vs 0.1)
# Linear filter...
# Filtered out 12/818, 6.0 false (0.50 vs 0.1)
# Linear filter...
# Filtered out 8/806, 8.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 6/798, 4.0 false (0.67 vs 0.1)
# Linear filter...
# Filtered out 14/792, 11.0 false (0.79 vs 0.1)
# Linear filter...
# Filtered out 16/778, 11.0 false (0.69 vs 0.1)
# Linear filter...
# Filtered out 10/762, 9.0 false (0.90 vs 0.1)
# Linear filter...
# Filtered out 22/752, 20.0 false (0.91 vs 0.1)
# Linear filter...
# Filtered out 15/730, 14.0 false (0.93 vs 0.1)
# Linear filter...
# Filtered out 14/715, 14.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 10/701, 8.0 false (0.80 vs 0.1)
# Linear filter...
# Filtered out 5/691, 5.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 0/686, 0.0 false (nan vs 0.1)
# Could not filter
# Linear filter...
# Filtered out 3/99, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/96, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/96, 0.0 false (nan vs 0.1)
# condition 96 96
# Could not filter
# Linear filter...
# Filtered out 3/99, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/96, 0.0 false (nan vs 0.1)
# Could not filter
# Linear filter...
# Filtered out 17/99, 10.0 false (0.59 vs 0.1)
# Linear filter...
# Filtered out 25/82, 23.0 false (0.92 vs 0.1)
# Linear filter...
# Filtered out 21/57, 21.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 15/36, 15.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 8/21, 8.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 0/13, 0.0 false (nan vs 0.1)
# Could not filter
# Linear filter...
# Filtered out 4/200, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 3/196, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/193, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/193, 0.0 false (nan vs 0.1)
# condition 193 193
# Could not filter
# Linear filter...
# Filtered out 4/200, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 3/196, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/193, 0.0 false (nan vs 0.1)
# Could not filter
# Linear filter...
# Filtered out 15/200, 5.0 false (0.33 vs 0.1)
# Linear filter...
# Filtered out 31/185, 26.0 false (0.84 vs 0.1)
# Linear filter...
# Filtered out 28/154, 27.0 false (0.96 vs 0.1)
# Linear filter...
# Filtered out 13/126, 10.0 false (0.77 vs 0.1)
# Linear filter...
# Filtered out 24/113, 23.0 false (0.96 vs 0.1)
# Linear filter...
# Filtered out 26/89, 26.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 25/63, 25.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 16/38, 16.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 10/22, 10.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 6/12, 6.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 0/6, 0.0 false (nan vs 0.1)
# Could not filter
# Linear filter...
# Filtered out 14/299, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/285, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/285, 0.0 false (nan vs 0.1)
# condition 285 285
# Could not filter
# Linear filter...
# Filtered out 14/299, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/285, 0.0 false (nan vs 0.1)
# Could not filter
# Linear filter...
# Filtered out 17/299, 2.0 false (0.12 vs 0.1)
# Linear filter...
# Filtered out 46/282, 41.0 false (0.89 vs 0.1)
# Linear filter...
# Filtered out 29/236, 26.0 false (0.90 vs 0.1)
# Linear filter...
# Filtered out 15/207, 13.0 false (0.87 vs 0.1)
# Linear filter...
# Filtered out 27/192, 25.0 false (0.93 vs 0.1)
# Linear filter...
# Filtered out 25/165, 24.0 false (0.96 vs 0.1)
# Linear filter...
# Filtered out 28/140, 28.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 21/112, 21.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 21/91, 20.0 false (0.95 vs 0.1)
# Linear filter...
# Filtered out 17/70, 17.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 16/53, 16.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 13/37, 13.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 10/24, 10.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 0/14, 0.0 false (nan vs 0.1)
# Could not filter
# Linear filter...
# Filtered out 5/400, 2.0 false (0.40 vs 0.1)
# Linear filter...
# Filtered out 0/395, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/395, 0.0 false (nan vs 0.1)
# condition 395 395
# Could not filter
# Linear filter...
# Filtered out 5/400, 2.0 false (0.40 vs 0.1)
# Linear filter...
# Filtered out 0/395, 0.0 false (nan vs 0.1)
# Could not filter
# Linear filter...
# Filtered out 33/400, 12.0 false (0.36 vs 0.1)
# Linear filter...
# Filtered out 40/367, 32.0 false (0.80 vs 0.1)
# Linear filter...
# Filtered out 38/327, 34.0 false (0.89 vs 0.1)
# Linear filter...
# Filtered out 27/289, 26.0 false (0.96 vs 0.1)
# Linear filter...
# Filtered out 20/262, 16.0 false (0.80 vs 0.1)
# Linear filter...
# Filtered out 15/242, 13.0 false (0.87 vs 0.1)
# Linear filter...
# Filtered out 26/227, 26.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 17/201, 17.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 17/184, 17.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 24/167, 24.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 10/143, 10.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 20/133, 20.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 18/113, 18.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 19/95, 19.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 24/76, 24.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 18/52, 18.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 9/34, 9.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 12/25, 12.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 6/13, 6.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 4/7, 4.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 0/3, 0.0 false (nan vs 0.1)
# Could not filter
# Linear filter...
# Filtered out 19/500, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/481, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/481, 0.0 false (nan vs 0.1)
# condition 481 481
# Could not filter
# Linear filter...
# Filtered out 19/500, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/481, 0.0 false (nan vs 0.1)
# Could not filter
# Linear filter...
# Filtered out 33/500, 7.0 false (0.21 vs 0.1)
# Linear filter...
# Filtered out 41/467, 34.0 false (0.83 vs 0.1)
# Linear filter...
# Filtered out 28/426, 24.0 false (0.86 vs 0.1)
# Linear filter...
# Filtered out 17/398, 13.0 false (0.76 vs 0.1)
# Linear filter...
# Filtered out 26/381, 22.0 false (0.85 vs 0.1)
# Linear filter...
# Filtered out 16/355, 16.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 6/339, 5.0 false (0.83 vs 0.1)
# Linear filter...
# Filtered out 30/333, 28.0 false (0.93 vs 0.1)
# Linear filter...
# Filtered out 14/303, 13.0 false (0.93 vs 0.1)
# Linear filter...
# Filtered out 11/289, 11.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 14/278, 14.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 15/264, 15.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 20/249, 19.0 false (0.95 vs 0.1)
# Linear filter...
# Filtered out 18/229, 18.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 20/211, 20.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 17/191, 17.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 9/174, 9.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 10/165, 10.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 19/155, 19.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 20/136, 20.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 13/116, 13.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 19/103, 19.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 20/84, 20.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 15/64, 15.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 13/49, 13.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 12/36, 12.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 8/24, 8.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 8/16, 8.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 4/8, 4.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 0/4, 0.0 false (nan vs 0.1)
# Could not filter
# Linear filter...
# Filtered out 15/599, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/584, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/584, 0.0 false (nan vs 0.1)
# condition 584 584
# Could not filter
# Linear filter...
# Filtered out 15/599, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/584, 0.0 false (nan vs 0.1)
# Could not filter
# Linear filter...
# Filtered out 34/599, 3.0 false (0.09 vs 0.1)
# Linear filter...
# Filtered out 26/565, 21.0 false (0.81 vs 0.1)
# Linear filter...
# Filtered out 26/539, 16.0 false (0.62 vs 0.1)
# Linear filter...
# Filtered out 15/513, 13.0 false (0.87 vs 0.1)
# Linear filter...
# Filtered out 18/498, 17.0 false (0.94 vs 0.1)
# Linear filter...
# Filtered out 4/480, 3.0 false (0.75 vs 0.1)
# Linear filter...
# Filtered out 24/476, 23.0 false (0.96 vs 0.1)
# Linear filter...
# Filtered out 21/452, 17.0 false (0.81 vs 0.1)
# Linear filter...
# Filtered out 12/431, 11.0 false (0.92 vs 0.1)
# Linear filter...
# Filtered out 13/419, 13.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 11/406, 11.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 11/395, 10.0 false (0.91 vs 0.1)
# Linear filter...
# Filtered out 8/384, 7.0 false (0.88 vs 0.1)
# Linear filter...
# Filtered out 14/376, 14.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 13/362, 13.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 7/349, 7.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 11/342, 11.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 13/331, 13.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 14/318, 14.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 11/304, 11.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 12/293, 12.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 10/281, 10.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 4/271, 4.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 7/267, 6.0 false (0.86 vs 0.1)
# Linear filter...
# Filtered out 22/260, 22.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 18/238, 18.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 11/220, 11.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 16/209, 16.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 13/193, 13.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 8/180, 8.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 20/172, 20.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 17/152, 17.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 11/135, 11.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 13/124, 13.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 13/111, 13.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 15/98, 15.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 15/83, 15.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 19/68, 19.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 20/49, 20.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 12/29, 12.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 5/17, 5.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 5/12, 5.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 0/7, 0.0 false (nan vs 0.1)
# Could not filter
# Linear filter...
# Filtered out 30/700, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/670, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/670, 0.0 false (nan vs 0.1)
# condition 670 670
# Could not filter
# Linear filter...
# Filtered out 30/700, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/670, 0.0 false (nan vs 0.1)
# Could not filter
# Linear filter...
# Filtered out 42/700, 7.0 false (0.17 vs 0.1)
# Linear filter...
# Filtered out 21/658, 13.0 false (0.62 vs 0.1)
# Linear filter...
# Filtered out 46/637, 40.0 false (0.87 vs 0.1)
# Linear filter...
# Filtered out 7/591, 5.0 false (0.71 vs 0.1)
# Linear filter...
# Filtered out 13/584, 10.0 false (0.77 vs 0.1)
# Linear filter...
# Filtered out 24/571, 22.0 false (0.92 vs 0.1)
# Linear filter...
# Filtered out 21/547, 18.0 false (0.86 vs 0.1)
# Linear filter...
# Filtered out 9/526, 8.0 false (0.89 vs 0.1)
# Linear filter...
# Filtered out 18/517, 15.0 false (0.83 vs 0.1)
# Linear filter...
# Filtered out 11/499, 9.0 false (0.82 vs 0.1)
# Linear filter...
# Filtered out 13/488, 13.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 20/475, 20.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 12/455, 11.0 false (0.92 vs 0.1)
# Linear filter...
# Filtered out 11/443, 10.0 false (0.91 vs 0.1)
# Linear filter...
# Filtered out 8/432, 7.0 false (0.88 vs 0.1)
# Linear filter...
# Filtered out 5/424, 5.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 17/419, 17.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 15/402, 15.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 10/387, 9.0 false (0.90 vs 0.1)
# Linear filter...
# Filtered out 5/377, 5.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 11/372, 11.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 3/361, 3.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 16/358, 16.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 3/342, 2.0 false (0.67 vs 0.1)
# Linear filter...
# Filtered out 2/339, 2.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 0/337, 0.0 false (nan vs 0.1)
# Could not filter
# Linear filter...
# Filtered out 16/800, 1.0 false (0.06 vs 0.1)
# Linear filter...
# Filtered out 0/784, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/784, 0.0 false (nan vs 0.1)
# condition 784 784
# Could not filter
# Linear filter...
# Filtered out 16/800, 1.0 false (0.06 vs 0.1)
# Linear filter...
# Filtered out 0/784, 0.0 false (nan vs 0.1)
# Could not filter
# Linear filter...
# Filtered out 51/800, 10.0 false (0.20 vs 0.1)
# Linear filter...
# Filtered out 21/749, 16.0 false (0.76 vs 0.1)
# Linear filter...
# Filtered out 31/728, 28.0 false (0.90 vs 0.1)
# Linear filter...
# Filtered out 3/697, 3.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 5/694, 3.0 false (0.60 vs 0.1)
# Linear filter...
# Filtered out 20/689, 17.0 false (0.85 vs 0.1)
# Linear filter...
# Filtered out 22/669, 19.0 false (0.86 vs 0.1)
# Linear filter...
# Filtered out 9/647, 8.0 false (0.89 vs 0.1)
# Linear filter...
# Filtered out 20/638, 18.0 false (0.90 vs 0.1)
# Linear filter...
# Filtered out 27/618, 23.0 false (0.85 vs 0.1)
# Linear filter...
# Filtered out 4/591, 4.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 11/587, 10.0 false (0.91 vs 0.1)
# Linear filter...
# Filtered out 11/576, 9.0 false (0.82 vs 0.1)
# Linear filter...
# Filtered out 12/565, 12.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 20/553, 17.0 false (0.85 vs 0.1)
# Linear filter...
# Filtered out 6/533, 6.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 9/527, 9.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 12/518, 12.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 3/506, 3.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 8/503, 8.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 14/495, 12.0 false (0.86 vs 0.1)
# Linear filter...
# Filtered out 4/481, 4.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 7/477, 7.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 7/470, 6.0 false (0.86 vs 0.1)
# Linear filter...
# Filtered out 7/463, 6.0 false (0.86 vs 0.1)
# Linear filter...
# Filtered out 10/456, 9.0 false (0.90 vs 0.1)
# Linear filter...
# Filtered out 5/446, 5.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 4/441, 4.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 13/437, 13.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 7/424, 7.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 2/417, 2.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 13/415, 12.0 false (0.92 vs 0.1)
# Linear filter...
# Filtered out 6/402, 6.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 4/396, 4.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 4/392, 4.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 0/388, 0.0 false (nan vs 0.1)
# Could not filter
# Linear filter...
# Filtered out 25/899, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/874, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/874, 0.0 false (nan vs 0.1)
# condition 874 874
# Could not filter
# Linear filter...
# Filtered out 25/899, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/874, 0.0 false (nan vs 0.1)
# Could not filter
# Linear filter...
# Filtered out 48/899, 2.0 false (0.04 vs 0.1)
# Linear filter...
# Filtered out 26/851, 19.0 false (0.73 vs 0.1)
# Linear filter...
# Filtered out 16/825, 13.0 false (0.81 vs 0.1)
# Linear filter...
# Filtered out 9/809, 7.0 false (0.78 vs 0.1)
# Linear filter...
# Filtered out 18/800, 12.0 false (0.67 vs 0.1)
# Linear filter...
# Filtered out 26/782, 20.0 false (0.77 vs 0.1)
# Linear filter...
# Filtered out 25/756, 21.0 false (0.84 vs 0.1)
# Linear filter...
# Filtered out 11/731, 9.0 false (0.82 vs 0.1)
# Linear filter...
# Filtered out 0/720, 0.0 false (nan vs 0.1)
# Could not filter
# Linear filter...
# Filtered out 0/100, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/100, 0.0 false (nan vs 0.1)
# condition 100 100
# Could not filter
# Linear filter...
# Filtered out 0/100, 0.0 false (nan vs 0.1)
# Could not filter
# Linear filter...
# Filtered out 25/100, 17.0 false (0.68 vs 0.1)
# Linear filter...
# Filtered out 22/75, 21.0 false (0.95 vs 0.1)
# Linear filter...
# Filtered out 22/53, 21.0 false (0.95 vs 0.1)
# Linear filter...
# Filtered out 16/31, 16.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 7/15, 7.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 3/8, 3.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 0/5, 0.0 false (nan vs 0.1)
# Could not filter
# Linear filter...
# Filtered out 3/200, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/197, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/197, 0.0 false (nan vs 0.1)
# condition 197 197
# Could not filter
# Linear filter...
# Filtered out 3/200, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/197, 0.0 false (nan vs 0.1)
# Could not filter
# Linear filter...
# Filtered out 14/200, 4.0 false (0.29 vs 0.1)
# Linear filter...
# Filtered out 30/186, 25.0 false (0.83 vs 0.1)
# Linear filter...
# Filtered out 32/156, 30.0 false (0.94 vs 0.1)
# Linear filter...
# Filtered out 21/124, 19.0 false (0.90 vs 0.1)
# Linear filter...
# Filtered out 24/103, 24.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 26/79, 26.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 6/53, 5.0 false (0.83 vs 0.1)
# Linear filter...
# Filtered out 16/47, 16.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 9/31, 9.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 10/22, 10.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 5/12, 5.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 3/7, 3.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 2/4, 2.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Could not filter
# Linear filter...
# Filtered out 8/298, 1.0 false (0.12 vs 0.1)
# Linear filter...
# Filtered out 0/290, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/290, 0.0 false (nan vs 0.1)
# condition 290 290
# Could not filter
# Linear filter...
# Filtered out 8/298, 1.0 false (0.12 vs 0.1)
# Linear filter...
# Filtered out 0/290, 0.0 false (nan vs 0.1)
# Could not filter
# Linear filter...
# Filtered out 23/298, 8.0 false (0.35 vs 0.1)
# Linear filter...
# Filtered out 34/275, 31.0 false (0.91 vs 0.1)
# Linear filter...
# Filtered out 27/241, 23.0 false (0.85 vs 0.1)
# Linear filter...
# Filtered out 29/214, 27.0 false (0.93 vs 0.1)
# Linear filter...
# Filtered out 20/185, 19.0 false (0.95 vs 0.1)
# Linear filter...
# Filtered out 23/165, 22.0 false (0.96 vs 0.1)
# Linear filter...
# Filtered out 21/142, 20.0 false (0.95 vs 0.1)
# Linear filter...
# Filtered out 19/121, 18.0 false (0.95 vs 0.1)
# Linear filter...
# Filtered out 27/102, 27.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 23/75, 23.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 21/52, 21.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 14/31, 14.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 5/17, 5.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 6/12, 6.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 3/6, 3.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 0/3, 0.0 false (nan vs 0.1)
# Could not filter
# Linear filter...
# Filtered out 5/398, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/393, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 2/393, 0.0 false (0.00 vs 0.1)
# condition 391 393
# Linear filter...
# Filtered out 0/391, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/391, 0.0 false (nan vs 0.1)
# condition 391 391
# Could not filter
# Linear filter...
# Filtered out 5/398, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/393, 0.0 false (nan vs 0.1)
# Could not filter
# Linear filter...
# Filtered out 24/398, 3.0 false (0.12 vs 0.1)
# Linear filter...
# Filtered out 35/374, 31.0 false (0.89 vs 0.1)
# Linear filter...
# Filtered out 19/339, 16.0 false (0.84 vs 0.1)
# Linear filter...
# Filtered out 22/320, 19.0 false (0.86 vs 0.1)
# Linear filter...
# Filtered out 20/298, 17.0 false (0.85 vs 0.1)
# Linear filter...
# Filtered out 23/278, 20.0 false (0.87 vs 0.1)
# Linear filter...
# Filtered out 14/255, 14.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 19/241, 19.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 18/222, 17.0 false (0.94 vs 0.1)
# Linear filter...
# Filtered out 14/204, 14.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 20/190, 20.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 19/170, 19.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 16/151, 15.0 false (0.94 vs 0.1)
# Linear filter...
# Filtered out 27/135, 27.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 20/108, 20.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 15/88, 15.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 20/73, 20.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 17/53, 17.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 16/36, 16.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 8/20, 8.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 6/12, 6.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 3/6, 3.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 0/3, 0.0 false (nan vs 0.1)
# Could not filter
# Linear filter...
# Filtered out 11/499, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/488, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/488, 0.0 false (nan vs 0.1)
# condition 488 488
# Could not filter
# Linear filter...
# Filtered out 11/499, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/488, 0.0 false (nan vs 0.1)
# Could not filter
# Linear filter...
# Filtered out 35/499, 10.0 false (0.29 vs 0.1)
# Linear filter...
# Filtered out 31/464, 25.0 false (0.81 vs 0.1)
# Linear filter...
# Filtered out 18/433, 17.0 false (0.94 vs 0.1)
# Linear filter...
# Filtered out 23/415, 18.0 false (0.78 vs 0.1)
# Linear filter...
# Filtered out 16/392, 14.0 false (0.88 vs 0.1)
# Linear filter...
# Filtered out 36/376, 33.0 false (0.92 vs 0.1)
# Linear filter...
# Filtered out 22/340, 22.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 17/318, 15.0 false (0.88 vs 0.1)
# Linear filter...
# Filtered out 23/301, 22.0 false (0.96 vs 0.1)
# Linear filter...
# Filtered out 14/278, 13.0 false (0.93 vs 0.1)
# Linear filter...
# Filtered out 13/264, 12.0 false (0.92 vs 0.1)
# Linear filter...
# Filtered out 20/251, 20.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 15/231, 15.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 16/216, 15.0 false (0.94 vs 0.1)
# Linear filter...
# Filtered out 17/200, 16.0 false (0.94 vs 0.1)
# Linear filter...
# Filtered out 14/183, 14.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 16/169, 16.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 13/153, 13.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 19/140, 19.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 21/121, 21.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 19/100, 19.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 14/81, 14.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 14/67, 14.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 19/53, 19.0 false (1.00 vs 0.1)
# ...
# Filtered out 6/607, 5.0 false (0.83 vs 0.1)
# Linear filter...
# Filtered out 3/601, 2.0 false (0.67 vs 0.1)
# Linear filter...
# Filtered out 7/598, 6.0 false (0.86 vs 0.1)
# Linear filter...
# Filtered out 0/591, 0.0 false (nan vs 0.1)
# Could not filter
# Linear filter...
# Filtered out 30/899, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/869, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/869, 0.0 false (nan vs 0.1)
# condition 869 869
# Could not filter
# Linear filter...
# Filtered out 30/899, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/869, 0.0 false (nan vs 0.1)
# Could not filter
# Linear filter...
# Filtered out 53/899, 8.0 false (0.15 vs 0.1)
# Linear filter...
# Filtered out 24/846, 14.0 false (0.58 vs 0.1)
# Linear filter...
# Filtered out 29/822, 23.0 false (0.79 vs 0.1)
# Linear filter...
# Filtered out 14/793, 10.0 false (0.71 vs 0.1)
# Linear filter...
# Filtered out 14/779, 13.0 false (0.93 vs 0.1)
# Linear filter...
# Filtered out 8/765, 5.0 false (0.62 vs 0.1)
# Linear filter...
# Filtered out 19/757, 16.0 false (0.84 vs 0.1)
# Linear filter...
# Filtered out 10/738, 9.0 false (0.90 vs 0.1)
# Linear filter...
# Filtered out 7/728, 6.0 false (0.86 vs 0.1)
# Linear filter...
# Filtered out 22/721, 22.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 3/699, 2.0 false (0.67 vs 0.1)
# Linear filter...
# Filtered out 14/696, 13.0 false (0.93 vs 0.1)
# Linear filter...
# Filtered out 6/682, 5.0 false (0.83 vs 0.1)
# Linear filter...
# Filtered out 7/676, 7.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 10/669, 9.0 false (0.90 vs 0.1)
# Linear filter...
# Filtered out 8/659, 7.0 false (0.88 vs 0.1)
# Linear filter...
# Filtered out 21/651, 21.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 2/630, 2.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 10/628, 9.0 false (0.90 vs 0.1)
# Linear filter...
# Filtered out 9/618, 9.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 6/609, 4.0 false (0.67 vs 0.1)
# Linear filter...
# Filtered out 0/603, 0.0 false (nan vs 0.1)
# Could not filter
# Linear filter...
# Filtered out 0/100, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/100, 0.0 false (nan vs 0.1)
# condition 100 100
# Could not filter
# Linear filter...
# Filtered out 0/100, 0.0 false (nan vs 0.1)
# Could not filter
# Linear filter...
# Filtered out 20/100, 13.0 false (0.65 vs 0.1)
# Linear filter...
# Filtered out 24/80, 22.0 false (0.92 vs 0.1)
# Linear filter...
# Filtered out 14/56, 14.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 17/42, 16.0 false (0.94 vs 0.1)
# Linear filter...
# Filtered out 7/25, 7.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 0/18, 0.0 false (nan vs 0.1)
# Could not filter
# Linear filter...
# Filtered out 8/200, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/192, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/192, 0.0 false (nan vs 0.1)
# condition 192 192
# Could not filter
# Linear filter...
# Filtered out 8/200, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/192, 0.0 false (nan vs 0.1)
# Could not filter
# Linear filter...
# Filtered out 20/200, 9.0 false (0.45 vs 0.1)
# Linear filter...
# Filtered out 33/180, 28.0 false (0.85 vs 0.1)
# Linear filter...
# Filtered out 23/147, 22.0 false (0.96 vs 0.1)
# Linear filter...
# Filtered out 27/124, 24.0 false (0.89 vs 0.1)
# Linear filter...
# Filtered out 24/97, 24.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 16/73, 16.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 14/57, 14.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 16/43, 16.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 14/27, 14.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 0/13, 0.0 false (nan vs 0.1)
# Could not filter
# Linear filter...
# Filtered out 11/300, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/289, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/289, 0.0 false (nan vs 0.1)
# condition 289 289
# Could not filter
# Linear filter...
# Filtered out 11/300, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/289, 0.0 false (nan vs 0.1)
# Could not filter
# Linear filter...
# Filtered out 22/300, 7.0 false (0.32 vs 0.1)
# Linear filter...
# Filtered out 35/278, 31.0 false (0.89 vs 0.1)
# Linear filter...
# Filtered out 26/243, 25.0 false (0.96 vs 0.1)
# Linear filter...
# Filtered out 29/217, 22.0 false (0.76 vs 0.1)
# Linear filter...
# Filtered out 16/188, 16.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 21/172, 19.0 false (0.90 vs 0.1)
# Linear filter...
# Filtered out 18/151, 18.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 34/133, 34.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 18/99, 18.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 21/81, 20.0 false (0.95 vs 0.1)
# Linear filter...
# Filtered out 17/60, 17.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 11/43, 11.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 10/32, 10.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 8/22, 8.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 7/14, 7.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 0/7, 0.0 false (nan vs 0.1)
# Could not filter
# Linear filter...
# Filtered out 5/400, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/395, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/395, 0.0 false (nan vs 0.1)
# condition 395 395
# Could not filter
# Linear filter...
# Filtered out 5/400, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/395, 0.0 false (nan vs 0.1)
# Could not filter
# Linear filter...
# Filtered out 31/400, 9.0 false (0.29 vs 0.1)
# Linear filter...
# Filtered out 25/369, 19.0 false (0.76 vs 0.1)
# Linear filter...
# Filtered out 22/344, 22.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 26/322, 24.0 false (0.92 vs 0.1)
# Linear filter...
# Filtered out 20/296, 16.0 false (0.80 vs 0.1)
# Linear filter...
# Filtered out 20/276, 18.0 false (0.90 vs 0.1)
# Linear filter...
# Filtered out 28/256, 26.0 false (0.93 vs 0.1)
# Linear filter...
# Filtered out 14/228, 13.0 false (0.93 vs 0.1)
# Linear filter...
# Filtered out 17/214, 16.0 false (0.94 vs 0.1)
# Linear filter...
# Filtered out 20/197, 20.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 21/177, 21.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 23/156, 23.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 15/133, 15.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 22/118, 22.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 19/96, 19.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 17/77, 17.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 18/60, 18.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 13/42, 13.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 14/29, 14.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 6/15, 6.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 0/9, 0.0 false (nan vs 0.1)
# Could not filter
# Linear filter...
# Filtered out 17/500, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/483, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/483, 0.0 false (nan vs 0.1)
# condition 483 483
# Could not filter
# Linear filter...
# Filtered out 17/500, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/483, 0.0 false (nan vs 0.1)
# Could not filter
# Linear filter...
# Filtered out 32/500, 6.0 false (0.19 vs 0.1)
# Linear filter...
# Filtered out 30/468, 24.0 false (0.80 vs 0.1)
# Linear filter...
# Filtered out 30/438, 25.0 false (0.83 vs 0.1)
# Linear filter...
# Filtered out 14/408, 11.0 false (0.79 vs 0.1)
# Linear filter...
# Filtered out 20/394, 17.0 false (0.85 vs 0.1)
# Linear filter...
# Filtered out 11/374, 9.0 false (0.82 vs 0.1)
# Linear filter...
# Filtered out 27/363, 26.0 false (0.96 vs 0.1)
# Linear filter...
# Filtered out 29/336, 28.0 false (0.97 vs 0.1)
# Linear filter...
# Filtered out 23/307, 23.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 26/284, 26.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 17/258, 17.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 16/241, 14.0 false (0.88 vs 0.1)
# Linear filter...
# Filtered out 18/225, 17.0 false (0.94 vs 0.1)
# Linear filter...
# Filtered out 12/207, 12.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 5/195, 5.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 20/190, 20.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 22/170, 22.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 17/148, 17.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 10/131, 10.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 13/121, 13.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 8/108, 8.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 13/100, 13.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 17/87, 17.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 11/70, 11.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 13/59, 13.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 7/46, 7.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 10/39, 10.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 12/29, 12.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 10/17, 10.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 4/7, 4.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 0/3, 0.0 false (nan vs 0.1)
# Could not filter
# Linear filter...
# Filtered out 9/599, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/590, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/590, 0.0 false (nan vs 0.1)
# condition 590 590
# Could not filter
# Linear filter...
# Filtered out 9/599, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/590, 0.0 false (nan vs 0.1)
# Could not filter
# Linear filter...
# Filtered out 34/599, 4.0 false (0.12 vs 0.1)
# Linear filter...
# Filtered out 25/565, 19.0 false (0.76 vs 0.1)
# Linear filter...
# Filtered out 17/540, 14.0 false (0.82 vs 0.1)
# Linear filter...
# Filtered out 13/523, 10.0 false (0.77 vs 0.1)
# Linear filter...
# Filtered out 18/510, 15.0 false (0.83 vs 0.1)
# Linear filter...
# Filtered out 15/492, 15.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 8/477, 3.0 false (0.38 vs 0.1)
# Linear filter...
# Filtered out 9/469, 8.0 false (0.89 vs 0.1)
# Linear filter...
# Filtered out 17/460, 16.0 false (0.94 vs 0.1)
# Linear filter...
# Filtered out 19/443, 18.0 false (0.95 vs 0.1)
# Linear filter...
# Filtered out 25/424, 22.0 false (0.88 vs 0.1)
# Linear filter...
# Filtered out 4/399, 2.0 false (0.50 vs 0.1)
# Linear filter...
# Filtered out 12/395, 11.0 false (0.92 vs 0.1)
# Linear filter...
# Filtered out 6/383, 6.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 11/377, 11.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 17/366, 17.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 21/349, 21.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 20/328, 20.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 2/308, 2.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 16/306, 16.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 13/290, 13.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 7/277, 7.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 14/270, 14.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 13/256, 13.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 13/243, 13.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 10/230, 10.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 13/220, 13.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 10/207, 10.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 17/197, 17.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 9/180, 9.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 16/171, 16.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 13/155, 13.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 20/142, 20.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 11/122, 11.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 16/111, 16.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 17/95, 17.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 15/78, 15.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 12/63, 12.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 11/51, 11.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 10/40, 10.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 12/30, 12.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 0/18, 0.0 false (nan vs 0.1)
# Could not filter
# Linear filter...
# Filtered out 30/700, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/670, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/670, 0.0 false (nan vs 0.1)
# condition 670 670
# Could not filter
# Linear filter...
# Filtered out 30/700, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/670, 0.0 false (nan vs 0.1)
# Could not filter
# Linear filter...
# Filtered out 44/700, 8.0 false (0.18 vs 0.1)
# Linear filter...
# Filtered out 25/656, 19.0 false (0.76 vs 0.1)
# Linear filter...
# Filtered out 36/631, 30.0 false (0.83 vs 0.1)
# Linear filter...
# Filtered out 17/595, 13.0 false (0.76 vs 0.1)
# Linear filter...
# Filtered out 28/578, 24.0 false (0.86 vs 0.1)
# Linear filter...
# Filtered out 19/550, 18.0 false (0.95 vs 0.1)
# Linear filter...
# Filtered out 12/531, 11.0 false (0.92 vs 0.1)
# Linear filter...
# Filtered out 10/519, 9.0 false (0.90 vs 0.1)
# Linear filter...
# Filtered out 2/509, 2.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 17/507, 14.0 false (0.82 vs 0.1)
# Linear filter...
# Filtered out 11/490, 8.0 false (0.73 vs 0.1)
# Linear filter...
# Filtered out 4/479, 3.0 false (0.75 vs 0.1)
# Linear filter...
# Filtered out 17/475, 16.0 false (0.94 vs 0.1)
# Linear filter...
# Filtered out 12/458, 12.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 11/446, 11.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 14/435, 13.0 false (0.93 vs 0.1)
# Linear filter...
# Filtered out 7/421, 7.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 0/414, 0.0 false (nan vs 0.1)
# Could not filter
# Linear filter...
# Filtered out 13/799, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/786, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/786, 0.0 false (nan vs 0.1)
# condition 786 786
# Could not filter
# Linear filter...
# Filtered out 13/799, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/786, 0.0 false (nan vs 0.1)
# Could not filter
# Linear filter...
# Filtered out 52/799, 12.0 false (0.23 vs 0.1)
# Linear filter...
# Filtered out 27/747, 21.0 false (0.78 vs 0.1)
# Linear filter...
# Filtered out 24/720, 19.0 false (0.79 vs 0.1)
# Linear filter...
# Filtered out 23/696, 16.0 false (0.70 vs 0.1)
# Linear filter...
# Filtered out 9/673, 8.0 false (0.89 vs 0.1)
# Linear filter...
# Filtered out 23/664, 19.0 false (0.83 vs 0.1)
# Linear filter...
# Filtered out 11/641, 10.0 false (0.91 vs 0.1)
# Linear filter...
# Filtered out 10/630, 9.0 false (0.90 vs 0.1)
# Linear filter...
# Filtered out 14/620, 10.0 false (0.71 vs 0.1)
# Linear filter...
# Filtered out 13/606, 11.0 false (0.85 vs 0.1)
# Linear filter...
# Filtered out 12/593, 12.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 4/581, 4.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 2/577, 2.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 13/575, 11.0 false (0.85 vs 0.1)
# Linear filter...
# Filtered out 8/562, 8.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 7/554, 7.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 18/547, 17.0 false (0.94 vs 0.1)
# Linear filter...
# Filtered out 4/529, 4.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 19/525, 19.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 9/506, 8.0 false (0.89 vs 0.1)
# Linear filter...
# Filtered out 0/497, 0.0 false (nan vs 0.1)
# Could not filter
# Linear filter...
# Filtered out 35/900, 1.0 false (0.03 vs 0.1)
# Linear filter...
# Filtered out 0/865, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/865, 0.0 false (nan vs 0.1)
# condition 865 865
# Could not filter
# Linear filter...
# Filtered out 35/900, 1.0 false (0.03 vs 0.1)
# Linear filter...
# Filtered out 0/865, 0.0 false (nan vs 0.1)
# Could not filter
# Linear filter...
# Filtered out 49/900, 4.0 false (0.08 vs 0.1)
# Linear filter...
# Filtered out 20/851, 14.0 false (0.70 vs 0.1)
# Linear filter...
# Filtered out 16/831, 10.0 false (0.62 vs 0.1)
# Linear filter...
# Filtered out 19/815, 16.0 false (0.84 vs 0.1)
# Linear filter...
# Filtered out 26/796, 22.0 false (0.85 vs 0.1)
# Linear filter...
# Filtered out 6/770, 5.0 false (0.83 vs 0.1)
# Linear filter...
# Filtered out 3/764, 2.0 false (0.67 vs 0.1)
# Linear filter...
# Filtered out 0/761, 0.0 false (nan vs 0.1)
# Could not filter

# %%
il.reload(rl)

plot_m_loss.plotxy('m', m_bounds, (0, 1))
# Out:
# <style>
#
# </style>
#
# <div id="fig_el56517348044115847006952876"></div>
# <script>
# function mpld3_load_lib(url, callback){
#   var s = document.createElement('script');
#   s.src = url;
#   s.async = true;
#   s.onreadystatechange = s.onload = callback;
#   s.onerror = function(){console.warn("failed to load library " + url);};
#   document.getElementsByTagName("head")[0].appendChild(s);
# }
#
# if(typeof(mpld3) !== "undefined" && mpld3._mpld3IsLoaded){
#    // already loaded: just create the figure
#    !function(mpld3){
#
#        mpld3.draw_figure("fig_el56517348044115847006952876", {"width": 432.0, "height": 288.0, "axes": [], "data": {}, "id": "el5651734804411584", "plugins": [{"type": "reset"}, {"type": "zoom", "button": true, "enabled": false}, {"type": "boxzoom", "button": true, "enabled": false}]});
#    }(mpld3);
# }else if(typeof define === "function" && define.amd){
#    // require.js is available: use it to load d3/mpld3
#    require.config({paths: {d3: "https://mpld3.github.io/js/d3.v3.min"}});
#    require(["d3"], function(d3){
#       window.d3 = d3;
#       mpld3_load_lib("https://mpld3.github.io/js/mpld3.v0.3.1.dev1.js", function(){
#
#          mpld3.draw_figure("fig_el56517348044115847006952876", {"width": 432.0, "height": 288.0, "axes": [], "data": {}, "id": "el5651734804411584", "plugins": [{"type": "reset"}, {"type": "zoom", "button": true, "enabled": false}, {"type": "boxzoom", "button": true, "enabled": false}]});
#       });
#     });
# }else{
#     // require.js not available: dynamically load d3 & mpld3
#     mpld3_load_lib("https://mpld3.github.io/js/d3.v3.min.js", function(){
#          mpld3_load_lib("https://mpld3.github.io/js/mpld3.v0.3.1.dev1.js", function(){
#
#                  mpld3.draw_figure("fig_el56517348044115847006952876", {"width": 432.0, "height": 288.0, "axes": [], "data": {}, "id": "el5651734804411584", "plugins": [{"type": "reset"}, {"type": "zoom", "button": true, "enabled": false}, {"type": "boxzoom", "button": true, "enabled": false}]});
#             })
#          });
# }
# </script>

# %%
"sparsity vs sample complexity for RME_sp"

il.reload(rl)

d, eps = 1000, 0.1
params = rl.Params(d=d, eps=eps)
trials = 5

model = rl.BimodalModel()

print(f"Running on d={d}, eps={eps}, m={m}")
inp, S, indicator, tm = model.generate(params)

keys = [rl.RME_sp]
ylims = (0, 100)
k_bounds = (1, 60, 1)

plot_m_loss = rl.plot(model, params, err, keys)
plot_m_loss.setdata('k', k_bounds, trials, ylims, y_is_m = True, mrange = (2,200))
# Out:
# Running on d=1000, eps=0.1, m=2000
# Linear filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# condition 2 2
# Could not filter
# VNEW  3.320193928663116 m  2 xvar  1 count 0
# Linear filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# condition 2 2
# Could not filter
# VNEW  2.9145374371589656 m  2 xvar  1 count 0
# Linear filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# condition 2 2
# Could not filter
# VNEW  2.7683339070673707 m  2 xvar  1 count 0
# Linear filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# condition 2 2
# Could not filter
# VNEW  2.9413074387666547 m  2 xvar  1 count 0
# Linear filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# condition 2 2
# Could not filter
# VNEW  2.725961641664678 m  2 xvar  1 count 0
# Linear filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# condition 2 2
# Could not filter
# VNEW  2.658561418093557 m  2 xvar  1 count 0
# Linear filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# condition 2 2
# Could not filter
# VNEW  2.994882744441532 m  2 xvar  1 count 0
# Linear filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# condition 2 2
# Could not filter
# VNEW  2.7793310593475518 m  2 xvar  1 count 0
# Linear filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# condition 2 2
# Could not filter
# VNEW  2.5453472552622096 m  2 xvar  1 count 0
# Linear filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# condition 2 2
# Could not filter
# VNEW  2.4839764504563124 m  2 xvar  1 count 0
# Linear filter...
# Filtered out 0/201, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/201, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/201, 0.0 false (nan vs 0.1)
# condition 201 201
# Could not filter
# VNEW  0.2468380612966934 m  202 xvar  1 count 0
# Linear filter...
# Filtered out 0/201, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/201, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/201, 0.0 false (nan vs 0.1)
# condition 201 201
# Could not filter
# VNEW  0.2284420295162129 m  202 xvar  1 count 1
# Linear filter...
# Filtered out 0/200, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/200, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/200, 0.0 false (nan vs 0.1)
# condition 200 200
# Could not filter
# VNEW  0.24250582393248757 m  202 xvar  1 count 2
# Linear filter...
# Filtered out 0/201, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/201, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/201, 0.0 false (nan vs 0.1)
# condition 201 201
# Could not filter
# VNEW  0.2777040772934539 m  202 xvar  1 count 3
# Linear filter...
# Filtered out 0/199, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/199, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/199, 0.0 false (nan vs 0.1)
# condition 199 199
# Could not filter
# VNEW  0.2828349128929193 m  202 xvar  1 count 4
# Linear filter...
# Filtered out 0/200, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/200, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/200, 0.0 false (nan vs 0.1)
# condition 200 200
# Could not filter
# VNEW  0.2531322010628522 m  202 xvar  1 count 5
# Linear filter...
# Filtered out 0/201, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/201, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/201, 0.0 false (nan vs 0.1)
# condition 201 201
# Could not filter
# VNEW  0.21884023965611513 m  202 xvar  1 count 6
# Linear filter...
# Filtered out 0/198, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/198, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/198, 0.0 false (nan vs 0.1)
# condition 198 198
# Could not filter
# VNEW  0.23365563380122187 m  202 xvar  1 count 7
# Linear filter...
# Filtered out 0/200, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/200, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/200, 0.0 false (nan vs 0.1)
# condition 200 200
# Could not filter
# VNEW  0.24855137957200524 m  202 xvar  1 count 8
# Linear filter...
# Filtered out 0/199, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/199, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/199, 0.0 false (nan vs 0.1)
# condition 199 199
# Could not filter
# VNEW  0.23078353717027272 m  202 xvar  1 count 9
# Linear filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# condition 2 2
# Could not filter
# VNEW  3.538217637616084 m  2 xvar  2 count 0
# Linear filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# condition 2 2
# Could not filter
# VNEW  4.214426977631233 m  2 xvar  2 count 0
# Linear filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# condition 2 2
# Could not filter
# VNEW  4.339068980688312 m  2 xvar  2 count 0
# Linear filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# condition 2 2
# Could not filter
# VNEW  3.6712902066275013 m  2 xvar  2 count 0
# Linear filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# condition 2 2
# Could not filter
# VNEW  3.930673596604686 m  2 xvar  2 count 0
# Linear filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# condition 2 2
# Could not filter
# VNEW  3.7891357746492536 m  2 xvar  2 count 0
# Linear filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# condition 2 2
# Could not filter
# VNEW  4.12720481374968 m  2 xvar  2 count 0
# Linear filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# condition 2 2
# Could not filter
# VNEW  4.829408726165081 m  2 xvar  2 count 0
# Linear filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# condition 2 2
# Could not filter
# VNEW  3.926960626297616 m  2 xvar  2 count 0
# Linear filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# condition 2 2
# Could not filter
# VNEW  4.1791728871760805 m  2 xvar  2 count 0
# Linear filter...
# Filtered out 0/200, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/200, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/200, 0.0 false (nan vs 0.1)
# condition 200 200
# Could not filter
# VNEW  0.3123844190609931 m  202 xvar  2 count 0
# Linear filter...
# Filtered out 0/200, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/200, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/200, 0.0 false (nan vs 0.1)
# condition 200 200
# Could not filter
# VNEW  0.2949605436121836 m  202 xvar  2 count 1
# Linear filter...
# Filtered out 0/202, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/202, 0.0 false (nan vs 0.1)
# condition 202 202
# Could not filter
# VNEW  0.33910072844789807 m  202 xvar  2 count 2
# Linear filter...
# Filtered out 0/200, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/200, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/200, 0.0 false (nan vs 0.1)
# condition 200 200
# Could not filter
# VNEW  0.3058018046444204 m  202 xvar  2 count 3
# Linear filter...
# Filtered out 0/202, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/202, 0.0 false (nan vs 0.1)
# condition 202 202
# Could not filter
# VNEW  0.3439999173319624 m  202 xvar  2 count 4
# Linear filter...
# Filtered out 0/197, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/197, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/197, 0.0 false (nan vs 0.1)
# condition 197 197
# Could not filter
# VNEW  0.336862822849113 m  202 xvar  2 count 5
# Linear filter...
# Filtered out 0/200, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/200, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/200, 0.0 false (nan vs 0.1)
# condition 200 200
# Could not filter
# VNEW  0.32687230517899507 m  202 xvar  2 count 6
# Linear filter...
# Filtered out 0/200, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/200, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/200, 0.0 false (nan vs 0.1)
# condition 200 200
# Could not filter
# VNEW  0.35124244684203937 m  202 xvar  2 count 7
# Linear filter...
# Filtered out 0/201, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/201, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/201, 0.0 false (nan vs 0.1)
# condition 201 201
# Could not filter
# VNEW  0.30601177503939586 m  202 xvar  2 count 8
# Linear filter...
# Filtered out 0/201, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/201, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/201, 0.0 false (nan vs 0.1)
# condition 201 201
# Could not filter
# VNEW  0.3223786010000207 m  202 xvar  2 count 9
# Linear filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# condition 2 2
# Could not filter
# VNEW  4.774181861939681 m  2 xvar  3 count 0
# Linear filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# condition 2 2
# Could not filter
# VNEW  4.872083732406152 m  2 xvar  3 count 0
# Linear filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# condition 2 2
# Could not filter
# VNEW  4.477771341820875 m  2 xvar  3 count 0
# Linear filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# condition 2 2
# Could not filter
# VNEW  4.374748294356587 m  2 xvar  3 count 0
# Linear filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# condition 2 2
# Could not filter
# VNEW  5.392494076089014 m  2 xvar  3 count 0
# Linear filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# condition 2 2
# Could not filter
# VNEW  4.247333034852508 m  2 xvar  3 count 0
# Linear filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# condition 2 2
# Could not filter
# VNEW  4.281785340142664 m  2 xvar  3 count 0
# Linear filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# condition 2 2
# Could not filter
# VNEW  5.297941737935501 m  2 xvar  3 count 0
# Linear filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# condition 2 2
# Could not filter
# VNEW  4.587887309633734 m  2 xvar  3 count 0
# Linear filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# condition 2 2
# Could not filter
# VNEW  4.609628304417552 m  2 xvar  3 count 0
# Linear filter...
# Filtered out 0/202, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/202, 0.0 false (nan vs 0.1)
# condition 202 202
# Could not filter
# VNEW  0.42341260856721064 m  202 xvar  3 count 0
# Linear filter...
# Filtered out 0/200, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/200, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/200, 0.0 false (nan vs 0.1)
# condition 200 200
# Could not filter
# VNEW  0.3795351037294454 m  202 xvar  3 count 1
# Linear filter...
# Filtered out 0/199, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/199, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/199, 0.0 false (nan vs 0.1)
# condition 199 199
# Could not filter
# VNEW  0.41659445278756774 m  202 xvar  3 count 2
# Linear filter...
# Filtered out 0/200, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/200, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/200, 0.0 false (nan vs 0.1)
# condition 200 200
# Could not filter
# VNEW  0.4530405446116097 m  202 xvar  3 count 3
# Linear filter...
# Filtered out 0/200, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/200, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/200, 0.0 false (nan vs 0.1)
# condition 200 200
# Could not filter
# VNEW  0.4622942085874991 m  202 xvar  3 count 4
# Linear filter...
# Filtered out 0/199, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/199, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/199, 0.0 false (nan vs 0.1)
# condition 199 199
# Could not filter
# VNEW  0.37971584867449126 m  202 xvar  3 count 5
# Linear filter...
# Filtered out 0/197, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/197, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/197, 0.0 false (nan vs 0.1)
# condition 197 197
# Could not filter
# VNEW  0.3844565007689569 m  202 xvar  3 count 6
# Linear filter...
# Filtered out 0/200, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/200, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/200, 0.0 false (nan vs 0.1)
# condition 200 200
# Could not filter
# VNEW  0.40535059246739186 m  202 xvar  3 count 7
# Linear filter...
# Filtered out 0/200, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/200, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/200, 0.0 false (nan vs 0.1)
# condition 200 200
# Could not filter
# VNEW  0.3887713731104141 m  202 xvar  3 count 8
# Linear filter...
# Filtered out 0/201, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/201, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/201, 0.0 false (nan vs 0.1)
# condition 201 201
# Could not filter
# VNEW  0.37451773498400187 m  202 xvar  3 count 9
# Linear filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# condition 2 2
# Could not filter
# VNEW  5.261363208924172 m  2 xvar  4 count 0
# Linear filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# condition 2 2
# Could not filter
# VNEW  5.185548642553721 m  2 xvar  4 count 0
# Linear filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# condition 2 2
# Could not filter
# VNEW  5.337857491577175 m  2 xvar  4 count 0
# Linear filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# condition 2 2
# Could not filter
# VNEW  5.649488025328958 m  2 xvar  4 count 0
# Linear filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# condition 2 2
# Could not filter
# VNEW  5.134685326707499 m  2 xvar  4 count 0
# Linear filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# condition 2 2
# Could not filter
# VNEW  5.724794006090073 m  2 xvar  4 count 0
# Linear filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# condition 2 2
# Could not filter
# VNEW  5.35199847395644 m  2 xvar  4 count 0
# Linear filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# condition 2 2
# Could not filter
# VNEW  5.734850019946061 m  2 xvar  4 count 0
# Linear filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# condition 2 2
# Could not filter
# VNEW  5.406538882342572 m  2 xvar  4 count 0
# Linear filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# condition 2 2
# Could not filter
# VNEW  5.47818884947573 m  2 xvar  4 count 0
# Linear filter...
# Filtered out 0/201, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/201, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/201, 0.0 false (nan vs 0.1)
# condition 201 201
# Could not filter
# VNEW  0.449773686584598 m  202 xvar  4 count 0
# Linear filter...
# Filtered out 0/200, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/200, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/200, 0.0 false (nan vs 0.1)
# condition 200 200
# Could not filter
# VNEW  0.4620831142850394 m  202 xvar  4 count 1
# Linear filter...
# Filtered out 3/201, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/198, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/198, 0.0 false (nan vs 0.1)
# condition 198 198
# Could not filter
# VNEW  0.45499447881380445 m  202 xvar  4 count 2
# Linear filter...
# Filtered out 0/202, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/202, 0.0 false (nan vs 0.1)
# condition 202 202
# Could not filter
# VNEW  0.4918696776938986 m  202 xvar  4 count 3
# Linear filter...
# Filtered out 0/198, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/198, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/198, 0.0 false (nan vs 0.1)
# condition 198 198
# Could not filter
# VNEW  0.5172506534273484 m  202 xvar  4 count 4
# Linear filter...
# Filtered out 0/200, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/200, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/200, 0.0 false (nan vs 0.1)
# condition 200 200
# Could not filter
# VNEW  0.45218584018899916 m  202 xvar  4 count 5
# Linear filter...
# Filtered out 0/199, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/199, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/199, 0.0 false (nan vs 0.1)
# condition 199 199
# Could not filter
# VNEW  0.47223328159452976 m  202 xvar  4 count 6
# Linear filter...
# Filtered out 0/200, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/200, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/200, 0.0 false (nan vs 0.1)
# condition 200 200
# Could not filter
# VNEW  0.42515714016886164 m  202 xvar  4 count 7
# Linear filter...
# Filtered out 0/200, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/200, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/200, 0.0 false (nan vs 0.1)
# condition 200 200
# Could not filter
# VNEW  0.440676788783411 m  202 xvar  4 count 8
# Linear filter...
# Filtered out 0/200, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/200, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/200, 0.0 false (nan vs 0.1)
# condition 200 200
# Could not filter
# VNEW  0.4519041748202695 m  202 xvar  4 count 9
# Linear filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# condition 2 2
# Could not filter
# VNEW  6.233133898541684 m  2 xvar  5 count 0
# Linear filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# condition 2 2
# Could not filter
# VNEW  6.366706270733716 m  2 xvar  5 count 0
# Linear filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# condition 2 2
# Could not filter
# VNEW  5.926319308033855 m  2 xvar  5 count 0
# Linear filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# condition 2 2
# Could not filter
# VNEW  5.833027172761789 m  2 xvar  5 count 0
# Linear filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# condition 2 2
# Could not filter
# VNEW  5.75629102196322 m  2 xvar  5 count 0
# Linear filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# condition 2 2
# Could not filter
# VNEW  5.757519525453744 m  2 xvar  5 count 0
# Linear filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# condition 2 2
# Could not filter
# VNEW  5.962006437022237 m  2 xvar  5 count 0
# Linear filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# condition 2 2
# Could not filter
# VNEW  5.5311481166882235 m  2 xvar  5 count 0
# Linear filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# condition 2 2
# Could not filter
# VNEW  5.727046005371237 m  2 xvar  5 count 0
# Linear filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# condition 2 2
# Could not filter
# VNEW  6.396550333906042 m  2 xvar  5 count 0
# Linear filter...
# Filtered out 0/200, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/200, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/200, 0.0 false (nan vs 0.1)
# condition 200 200
# Could not filter
# VNEW  0.5246696890802138 m  202 xvar  5 count 0
# Linear filter...
# Filtered out 0/201, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/201, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/201, 0.0 false (nan vs 0.1)
# condition 201 201
# Could not filter
# VNEW  0.46613452140245526 m  202 xvar  5 count 1
# Linear filter...
# Filtered out 0/199, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/199, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/199, 0.0 false (nan vs 0.1)
# condition 199 199
# Could not filter
# VNEW  0.4258489963728679 m  202 xvar  5 count 2
# Linear filter...
# Filtered out 0/200, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/200, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/200, 0.0 false (nan vs 0.1)
# condition 200 200
# Could not filter
# VNEW  0.5190599436794493 m  202 xvar  5 count 3
# Linear filter...
# Filtered out 0/202, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/202, 0.0 false (nan vs 0.1)
# condition 202 202
# Could not filter
# VNEW  0.47976403496750175 m  202 xvar  5 count 4
# Linear filter...
# Filtered out 0/201, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/201, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/201, 0.0 false (nan vs 0.1)
# condition 201 201
# Could not filter
# VNEW  0.5208159454905822 m  202 xvar  5 count 5
# Linear filter...
# Filtered out 0/202, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/202, 0.0 false (nan vs 0.1)
# condition 202 202
# Could not filter
# VNEW  0.5601128989593848 m  202 xvar  5 count 6
# Linear filter...
# Filtered out 0/201, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/201, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/201, 0.0 false (nan vs 0.1)
# condition 201 201
# Could not filter
# VNEW  0.5064451472883817 m  202 xvar  5 count 7
# Linear filter...
# Filtered out 0/199, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/199, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/199, 0.0 false (nan vs 0.1)
# condition 199 199
# Could not filter
# VNEW  0.49928274702311215 m  202 xvar  5 count 8
# Linear filter...
# Filtered out 0/201, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/201, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/201, 0.0 false (nan vs 0.1)
# condition 201 201
# Could not filter
# VNEW  0.4939701348904251 m  202 xvar  5 count 9
# Linear filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# condition 2 2
# Could not filter
# VNEW  5.949780647125221 m  2 xvar  6 count 0
# Linear filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# condition 2 2
# Could not filter
# VNEW  6.131249105658518 m  2 xvar  6 count 0
# Linear filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# condition 2 2
# Could not filter
# VNEW  6.365375475728527 m  2 xvar  6 count 0
# Linear filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# condition 2 2
# Could not filter
# VNEW  5.944227897301731 m  2 xvar  6 count 0
# Linear filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# condition 2 2
# Could not filter
# VNEW  6.5059565621498505 m  2 xvar  6 count 0
# Linear filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# condition 2 2
# Could not filter
# VNEW  6.2506585136170845 m  2 xvar  6 count 0
# Linear filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# condition 2 2
# Could not filter
# VNEW  6.752287700366239 m  2 xvar  6 count 0
# Linear filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# condition 2 2
# Could not filter
# VNEW  6.113986861318212 m  2 xvar  6 count 0
# Linear filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# condition 2 2
# Could not filter
# VNEW  7.233367258618524 m  2 xvar  6 count 0
# Linear filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# condition 2 2
# Could not filter
# VNEW  6.219063464040884 m  2 xvar  6 count 0
# Linear filter...
# Filtered out 2/200, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/198, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/198, 0.0 false (nan vs 0.1)
# condition 198 198
# Could not filter
# VNEW  0.5391873262252599 m  202 xvar  6 count 0
# Linear filter...
# Filtered out 0/200, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/200, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/200, 0.0 false (nan vs 0.1)
# condition 200 200
# Could not filter
# VNEW  0.533773010382704 m  202 xvar  6 count 1
# Linear filter...
# Filtered out 0/198, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/198, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/198, 0.0 false (nan vs 0.1)
# condition 198 198
# Could not filter
# VNEW  0.46873223848348594 m  202 xvar  6 count 2
# Linear filter...
# Filtered out 0/200, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/200, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/200, 0.0 false (nan vs 0.1)
# condition 200 200
# Could not filter
# VNEW  0.5273318836999128 m  202 xvar  6 count 3
# Linear filter...
# Filtered out 0/202, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/202, 0.0 false (nan vs 0.1)
# condition 202 202
# Could not filter
# VNEW  0.5320526183776109 m  202 xvar  6 count 4
# Linear filter...
# Filtered out 0/201, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/201, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/201, 0.0 false (nan vs 0.1)
# condition 201 201
# Could not filter
# VNEW  0.5581775876531493 m  202 xvar  6 count 5
# Linear filter...
# Filtered out 0/200, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/200, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/200, 0.0 false (nan vs 0.1)
# condition 200 200
# Could not filter
# VNEW  0.5573404960991681 m  202 xvar  6 count 6
# Linear filter...
# Filtered out 0/200, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/200, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/200, 0.0 false (nan vs 0.1)
# condition 200 200
# Could not filter
# VNEW  0.5494234523964558 m  202 xvar  6 count 7
# Linear filter...
# Filtered out 0/198, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/198, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/198, 0.0 false (nan vs 0.1)
# condition 198 198
# Could not filter
# VNEW  0.5178147019867007 m  202 xvar  6 count 8
# Linear filter...
# Filtered out 0/201, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/201, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/201, 0.0 false (nan vs 0.1)
# condition 201 201
# Could not filter
# VNEW  0.5815237956707465 m  202 xvar  6 count 9
# Linear filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# condition 2 2
# Could not filter
# VNEW  6.832351099623019 m  2 xvar  7 count 0
# Linear filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# condition 2 2
# Could not filter
# VNEW  7.628700838915721 m  2 xvar  7 count 0
# Linear filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# condition 2 2
# Could not filter
# VNEW  6.460936241294517 m  2 xvar  7 count 0
# Linear filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# condition 2 2
# Could not filter
# VNEW  6.6961156907363275 m  2 xvar  7 count 0
# Linear filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# condition 2 2
# Could not filter
# VNEW  6.529935319505788 m  2 xvar  7 count 0
# Linear filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# condition 2 2
# Could not filter
# VNEW  7.047787413387115 m  2 xvar  7 count 0
# Linear filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# condition 2 2
# Could not filter
# VNEW  6.194230948786412 m  2 xvar  7 count 0
# Linear filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# condition 2 2
# Could not filter
# VNEW  6.9784976990242065 m  2 xvar  7 count 0
# Linear filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# condition 2 2
# Could not filter
# VNEW  6.830568502640231 m  2 xvar  7 count 0
# Linear filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# condition 2 2
# Could not filter
# VNEW  6.571567222893105 m  2 xvar  7 count 0
# Linear filter...
# Filtered out 0/199, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/199, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/199, 0.0 false (nan vs 0.1)
# condition 199 199
# Could not filter
# VNEW  0.5720506201843312 m  202 xvar  7 count 0
# Linear filter...
# Filtered out 0/198, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/198, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/198, 0.0 false (nan vs 0.1)
# condition 198 198
# Could not filter
# VNEW  0.5857205436282921 m  202 xvar  7 count 1
# Linear filter...
# Filtered out 0/202, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/202, 0.0 false (nan vs 0.1)
# condition 202 202
# Could not filter
# VNEW  0.568169425760986 m  202 xvar  7 count 2
# Linear filter...
# Filtered out 0/199, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/199, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/199, 0.0 false (nan vs 0.1)
# condition 199 199
# Could not filter
# VNEW  0.5224197000286138 m  202 xvar  7 count 3
# Linear filter...
# Filtered out 0/199, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/199, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/199, 0.0 false (nan vs 0.1)
# condition 199 199
# Could not filter
# VNEW  0.588487621888878 m  202 xvar  7 count 4
# Linear filter...
# Filtered out 0/201, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/201, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/201, 0.0 false (nan vs 0.1)
# condition 201 201
# Could not filter
# VNEW  0.5633246338596727 m  202 xvar  7 count 5
# Linear filter...
# Filtered out 0/201, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/201, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/201, 0.0 false (nan vs 0.1)
# condition 201 201
# Could not filter
# VNEW  0.5740376140417185 m  202 xvar  7 count 6
# Linear filter...
# Filtered out 5/198, 1.0 false (0.20 vs 0.1)
# Linear filter...
# Filtered out 0/193, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/193, 0.0 false (nan vs 0.1)
# condition 193 193
# Could not filter
# VNEW  0.5450351138808438 m  202 xvar  7 count 7
# Linear filter...
# Filtered out 0/200, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/200, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/200, 0.0 false (nan vs 0.1)
# condition 200 200
# Could not filter
# VNEW  0.5623077034022904 m  202 xvar  7 count 8
# Linear filter...
# Filtered out 2/201, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/199, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/199, 0.0 false (nan vs 0.1)
# condition 199 199
# Could not filter
# VNEW  0.5614790876277551 m  202 xvar  7 count 9
# Linear filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# condition 2 2
# Could not filter
# VNEW  7.1614957755680555 m  2 xvar  8 count 0
# Linear filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# condition 2 2
# Could not filter
# VNEW  7.4461213805770585 m  2 xvar  8 count 0
# Linear filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# condition 2 2
# Could not filter
# VNEW  7.9350268813383735 m  2 xvar  8 count 0
# Linear filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# condition 2 2
# Could not filter
# VNEW  7.830622321211389 m  2 xvar  8 count 0
# Linear filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# condition 2 2
# Could not filter
# VNEW  7.149239566152949 m  2 xvar  8 count 0
# Linear filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# condition 2 2
# Could not filter
# VNEW  6.607380844184233 m  2 xvar  8 count 0
# Linear filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# condition 2 2
# Could not filter
# VNEW  7.57899707093594 m  2 xvar  8 count 0
# Linear filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# condition 2 2
# Could not filter
# VNEW  6.86322430364965 m  2 xvar  8 count 0
# Linear filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# condition 2 2
# Could not filter
# VNEW  7.6627964014713825 m  2 xvar  8 count 0
# Linear filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# condition 2 2
# Could not filter
# VNEW  6.878820879124683 m  2 xvar  8 count 0
# Linear filter...
# Filtered out 0/202, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/202, 0.0 false (nan vs 0.1)
# condition 202 202
# Could not filter
# VNEW  0.6441251525105888 m  202 xvar  8 count 0
# Linear filter...
# Filtered out 0/202, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/202, 0.0 false (nan vs 0.1)
# condition 202 202
# Could not filter
# VNEW  0.6302644117281062 m  202 xvar  8 count 1
# Linear filter...
# Filtered out 0/201, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/201, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/201, 0.0 false (nan vs 0.1)
# condition 201 201
# Could not filter
# VNEW  0.616421465074685 m  202 xvar  8 count 2
# Linear filter...
# Filtered out 0/199, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/199, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/199, 0.0 false (nan vs 0.1)
# condition 199 199
# Could not filter
# VNEW  0.6545663896102534 m  202 xvar  8 count 3
# Linear filter...
# Filtered out 0/200, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/200, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/200, 0.0 false (nan vs 0.1)
# condition 200 200
# Could not filter
# VNEW  0.5884676558316663 m  202 xvar  8 count 4
# Linear filter...
# Filtered out 0/201, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/201, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/201, 0.0 false (nan vs 0.1)
# condition 201 201
# Could not filter
# VNEW  0.643358474008507 m  202 xvar  8 count 5
# Linear filter...
# Filtered out 2/201, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/199, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/199, 0.0 false (nan vs 0.1)
# condition 199 199
# Could not filter
# VNEW  0.5651115275038399 m  202 xvar  8 count 6
# Linear filter...
# Filtered out 2/201, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/199, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/199, 0.0 false (nan vs 0.1)
# condition 199 199
# Could not filter
# VNEW  0.6098177661915086 m  202 xvar  8 count 7
# Linear filter...
# Filtered out 0/200, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/200, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/200, 0.0 false (nan vs 0.1)
# condition 200 200
# Could not filter
# VNEW  0.611906686657089 m  202 xvar  8 count 8
# Linear filter...
# Filtered out 0/198, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/198, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/198, 0.0 false (nan vs 0.1)
# condition 198 198
# Could not filter
# VNEW  0.6147016099082006 m  202 xvar  8 count 9
# Linear filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# condition 2 2
# Could not filter
# VNEW  7.328060499772057 m  2 xvar  9 count 0
# Linear filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# condition 2 2
# Could not filter
# VNEW  7.2343160950936864 m  2 xvar  9 count 0
# Linear filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# condition 2 2
# Could not filter
# VNEW  7.372408733886922 m  2 xvar  9 count 0
# Linear filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# condition 2 2
# Could not filter
# VNEW  7.267457650242051 m  2 xvar  9 count 0
# Linear filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# condition 2 2
# Could not filter
# VNEW  7.551239515345602 m  2 xvar  9 count 0
# Linear filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# condition 2 2
# Could not filter
# VNEW  7.822961701165422 m  2 xvar  9 count 0
# Linear filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# condition 2 2
# Could not filter
# VNEW  8.252860860531381 m  2 xvar  9 count 0
# Linear filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# condition 2 2
# Could not filter
# VNEW  8.609168464344018 m  2 xvar  9 count 0
# Linear filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# condition 2 2
# Could not filter
# VNEW  8.409485071471666 m  2 xvar  9 count 0
# Linear filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# condition 2 2
# Could not filter
# VNEW  7.478988476092081 m  2 xvar  9 count 0
# Linear filter...
# Filtered out 0/201, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/201, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/201, 0.0 false (nan vs 0.1)
# condition 201 201
# Could not filter
# VNEW  0.6205953998662969 m  202 xvar  9 count 0
# Linear filter...
# Filtered out 2/199, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/197, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/197, 0.0 false (nan vs 0.1)
# condition 197 197
# Could not filter
# VNEW  0.6634082831699467 m  202 xvar  9 count 1
# Linear filter...
# Filtered out 0/199, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/199, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/199, 0.0 false (nan vs 0.1)
# condition 199 199
# Could not filter
# VNEW  0.6076580022859654 m  202 xvar  9 count 2
# Linear filter...
# Filtered out 0/202, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/202, 0.0 false (nan vs 0.1)
# condition 202 202
# Could not filter
# VNEW  0.6208171996354 m  202 xvar  9 count 3
# Linear filter...
# Filtered out 0/201, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/201, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/201, 0.0 false (nan vs 0.1)
# condition 201 201
# Could not filter
# VNEW  0.6537191721197391 m  202 xvar  9 count 4
# Linear filter...
# Filtered out 2/202, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/200, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/200, 0.0 false (nan vs 0.1)
# condition 200 200
# Could not filter
# VNEW  0.6740502300949481 m  202 xvar  9 count 5
# Linear filter...
# Filtered out 0/200, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/200, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/200, 0.0 false (nan vs 0.1)
# condition 200 200
# Could not filter
# VNEW  0.6658508905110002 m  202 xvar  9 count 6
# Linear filter...
# Filtered out 0/200, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/200, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/200, 0.0 false (nan vs 0.1)
# condition 200 200
# Could not filter
# VNEW  0.6437183596814651 m  202 xvar  9 count 7
# Linear filter...
# Filtered out 0/200, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/200, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/200, 0.0 false (nan vs 0.1)
# condition 200 200
# Could not filter
# VNEW  0.6145503675201482 m  202 xvar  9 count 8
# Linear filter...
# Filtered out 0/202, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/202, 0.0 false (nan vs 0.1)
# condition 202 202
# Could not filter
# VNEW  0.6180315599112659 m  202 xvar  9 count 9
# Linear filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# condition 2 2
# Could not filter
# VNEW  8.412996657028547 m  2 xvar  10 count 0
# Linear filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# condition 2 2
# Could not filter
# VNEW  7.901127453032029 m  2 xvar  10 count 0
# Linear filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# condition 2 2
# Could not filter
# VNEW  7.740886641147625 m  2 xvar  10 count 0
# Linear filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# condition 2 2
# Could not filter
# VNEW  7.863540158783379 m  2 xvar  10 count 0
# Linear filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# condition 2 2
# Could not filter
# VNEW  7.986983910889603 m  2 xvar  10 count 0
# Linear filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# condition 2 2
# Could not filter
# VNEW  8.156561102016957 m  2 xvar  10 count 0
# Linear filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# condition 2 2
# Could not filter
# VNEW  7.801624457540288 m  2 xvar  10 count 0
# Linear filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# condition 2 2
# Could not filter
# VNEW  7.652487954889767 m  2 xvar  10 count 0
# Linear filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# condition 2 2
# Could not filter
# VNEW  7.545157064600107 m  2 xvar  10 count 0
# Linear filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# condition 2 2
# Could not filter
# VNEW  7.536773885541216 m  2 xvar  10 count 0
# Linear filter...
# Filtered out 0/197, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/197, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/197, 0.0 false (nan vs 0.1)
# condition 197 197
# Could not filter
# VNEW  0.7251637884176982 m  202 xvar  10 count 0
# Linear filter...
# Filtered out 0/199, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/199, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/199, 0.0 false (nan vs 0.1)
# condition 199 199
# Could not filter
# VNEW  0.6753416183109403 m  202 xvar  10 count 1
# Linear filter...
# Filtered out 0/200, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/200, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/200, 0.0 false (nan vs 0.1)
# condition 200 200
# Could not filter
# VNEW  0.6358459003615132 m  202 xvar  10 count 2
# Linear filter...
# Filtered out 0/201, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/201, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/201, 0.0 false (nan vs 0.1)
# condition 201 201
# Could not filter
# VNEW  0.6174423236213182 m  202 xvar  10 count 3
# Linear filter...
# Filtered out 0/202, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/202, 0.0 false (nan vs 0.1)
# condition 202 202
# Could not filter
# VNEW  0.7277656428725765 m  202 xvar  10 count 4
# Linear filter...
# Filtered out 0/200, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/200, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/200, 0.0 false (nan vs 0.1)
# condition 200 200
# Could not filter
# VNEW  0.632063339874808 m  202 xvar  10 count 5
# Linear filter...
# Filtered out 3/201, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/198, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/198, 0.0 false (nan vs 0.1)
# condition 198 198
# Could not filter
# VNEW  0.6759384772711529 m  202 xvar  10 count 6
# Linear filter...
# Filtered out 0/201, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/201, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/201, 0.0 false (nan vs 0.1)
# condition 201 201
# Could not filter
# VNEW  0.6611053291521739 m  202 xvar  10 count 7
# Linear filter...
# Filtered out 2/200, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/198, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/198, 0.0 false (nan vs 0.1)
# condition 198 198
# Could not filter
# VNEW  0.6832850032133659 m  202 xvar  10 count 8
# Linear filter...
# Filtered out 2/200, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/198, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/198, 0.0 false (nan vs 0.1)
# condition 198 198
# Could not filter
# VNEW  0.6730308986456488 m  202 xvar  10 count 9
# Linear filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# condition 2 2
# Could not filter
# VNEW  8.818495417975646 m  2 xvar  11 count 0
# Linear filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# condition 2 2
# Could not filter
# VNEW  8.419580440480907 m  2 xvar  11 count 0
# Linear filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# condition 2 2
# Could not filter
# VNEW  8.51520466538756 m  2 xvar  11 count 0
# Linear filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# condition 2 2
# Could not filter
# VNEW  8.396408903828837 m  2 xvar  11 count 0
# Linear filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# condition 2 2
# Could not filter
# VNEW  8.875326598307076 m  2 xvar  11 count 0
# Linear filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# condition 2 2
# Could not filter
# VNEW  8.299710261963384 m  2 xvar  11 count 0
# Linear filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# condition 2 2
# Could not filter
# VNEW  7.850079706108212 m  2 xvar  11 count 0
# Linear filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# condition 2 2
# Could not filter
# VNEW  8.08474508462138 m  2 xvar  11 count 0
# Linear filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# condition 2 2
# Could not filter
# VNEW  8.150802189624264 m  2 xvar  11 count 0
# Linear filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# condition 2 2
# Could not filter
# VNEW  8.493876951711677 m  2 xvar  11 count 0
# Linear filter...
# Filtered out 0/201, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/201, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/201, 0.0 false (nan vs 0.1)
# condition 201 201
# Could not filter
# VNEW  0.7466489640875825 m  202 xvar  11 count 0
# Linear filter...
# Filtered out 0/201, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/201, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/201, 0.0 false (nan vs 0.1)
# condition 201 201
# Could not filter
# VNEW  0.701071276293889 m  202 xvar  11 count 1
# Linear filter...
# Filtered out 0/198, 0.0 false (nan vs 0.1)
# Linear filter...
# ...
# condition 198 198
# Could not filter
# VNEW  0.3523210965189726 m  202 xvar  2 count 3
# Linear filter...
# Filtered out 0/201, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/201, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/201, 0.0 false (nan vs 0.1)
# condition 201 201
# Could not filter
# VNEW  0.3536618907811782 m  202 xvar  2 count 4
# Linear filter...
# Filtered out 0/199, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/199, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/199, 0.0 false (nan vs 0.1)
# condition 199 199
# Could not filter
# VNEW  0.35160971606306396 m  202 xvar  2 count 5
# Linear filter...
# Filtered out 0/201, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/201, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/201, 0.0 false (nan vs 0.1)
# condition 201 201
# Could not filter
# VNEW  0.3322912778378122 m  202 xvar  2 count 6
# Linear filter...
# Filtered out 0/200, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/200, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/200, 0.0 false (nan vs 0.1)
# condition 200 200
# Could not filter
# VNEW  0.33866849889957096 m  202 xvar  2 count 7
# Linear filter...
# Filtered out 0/199, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/199, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/199, 0.0 false (nan vs 0.1)
# condition 199 199
# Could not filter
# VNEW  0.3625016891428938 m  202 xvar  2 count 8
# Linear filter...
# Filtered out 0/199, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/199, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/199, 0.0 false (nan vs 0.1)
# condition 199 199
# Could not filter
# VNEW  0.3151251093718845 m  202 xvar  2 count 9
# Linear filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# condition 2 2
# Could not filter
# VNEW  4.557274338069319 m  2 xvar  3 count 0
# Linear filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# condition 2 2
# Could not filter
# VNEW  4.54254576779646 m  2 xvar  3 count 0
# Linear filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# condition 2 2
# Could not filter
# VNEW  4.811140336026186 m  2 xvar  3 count 0
# Linear filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# condition 2 2
# Could not filter
# VNEW  4.519319989175788 m  2 xvar  3 count 0
# Linear filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# condition 2 2
# Could not filter
# VNEW  4.62939181494359 m  2 xvar  3 count 0
# Linear filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# condition 2 2
# Could not filter
# VNEW  5.217540438342881 m  2 xvar  3 count 0
# Linear filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# condition 2 2
# Could not filter
# VNEW  5.32254278892828 m  2 xvar  3 count 0
# Linear filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# condition 2 2
# Could not filter
# VNEW  4.704169260931112 m  2 xvar  3 count 0
# Linear filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# condition 2 2
# Could not filter
# VNEW  4.752949790614011 m  2 xvar  3 count 0
# Linear filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# condition 2 2
# Could not filter
# VNEW  5.22017324381088 m  2 xvar  3 count 0
# Linear filter...
# Filtered out 2/199, 2.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 0/197, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/197, 0.0 false (nan vs 0.1)
# condition 197 197
# Could not filter
# VNEW  0.40001774054249417 m  202 xvar  3 count 0
# Linear filter...
# Filtered out 0/201, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/201, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/201, 0.0 false (nan vs 0.1)
# condition 201 201
# Could not filter
# VNEW  0.3881994243760956 m  202 xvar  3 count 1
# Linear filter...
# Filtered out 0/197, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/197, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/197, 0.0 false (nan vs 0.1)
# condition 197 197
# Could not filter
# VNEW  0.39924468314870615 m  202 xvar  3 count 2
# Linear filter...
# Filtered out 0/200, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/200, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/200, 0.0 false (nan vs 0.1)
# condition 200 200
# Could not filter
# VNEW  0.4109971510553091 m  202 xvar  3 count 3
# Linear filter...
# Filtered out 0/200, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/200, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/200, 0.0 false (nan vs 0.1)
# condition 200 200
# Could not filter
# VNEW  0.3566412835428817 m  202 xvar  3 count 4
# Linear filter...
# Filtered out 0/200, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/200, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/200, 0.0 false (nan vs 0.1)
# condition 200 200
# Could not filter
# VNEW  0.4186901004891197 m  202 xvar  3 count 5
# Linear filter...
# Filtered out 0/201, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/201, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/201, 0.0 false (nan vs 0.1)
# condition 201 201
# Could not filter
# VNEW  0.3915201573835983 m  202 xvar  3 count 6
# Linear filter...
# Filtered out 0/201, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/201, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/201, 0.0 false (nan vs 0.1)
# condition 201 201
# Could not filter
# VNEW  0.44697713691654384 m  202 xvar  3 count 7
# Linear filter...
# Filtered out 0/201, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/201, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/201, 0.0 false (nan vs 0.1)
# condition 201 201
# Could not filter
# VNEW  0.37682508984913626 m  202 xvar  3 count 8
# Linear filter...
# Filtered out 0/200, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/200, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/200, 0.0 false (nan vs 0.1)
# condition 200 200
# Could not filter
# VNEW  0.43936191813116077 m  202 xvar  3 count 9
# Linear filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# condition 2 2
# Could not filter
# VNEW  5.592503451423332 m  2 xvar  4 count 0
# Linear filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# condition 2 2
# Could not filter
# VNEW  5.262202732689727 m  2 xvar  4 count 0
# Linear filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# condition 2 2
# Could not filter
# VNEW  5.127855421555961 m  2 xvar  4 count 0
# Linear filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# condition 2 2
# Could not filter
# VNEW  5.774324467933705 m  2 xvar  4 count 0
# Linear filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# condition 2 2
# Could not filter
# VNEW  5.371456626567728 m  2 xvar  4 count 0
# Linear filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# condition 2 2
# Could not filter
# VNEW  5.900587106794186 m  2 xvar  4 count 0
# Linear filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# condition 2 2
# Could not filter
# VNEW  5.421802351421226 m  2 xvar  4 count 0
# Linear filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# condition 2 2
# Could not filter
# VNEW  5.643799682794119 m  2 xvar  4 count 0
# Linear filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# condition 2 2
# Could not filter
# VNEW  5.417507298280124 m  2 xvar  4 count 0
# Linear filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# condition 2 2
# Could not filter
# VNEW  5.53479742399086 m  2 xvar  4 count 0
# Linear filter...
# Filtered out 0/202, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/202, 0.0 false (nan vs 0.1)
# condition 202 202
# Could not filter
# VNEW  0.4476653750762018 m  202 xvar  4 count 0
# Linear filter...
# Filtered out 0/200, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/200, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/200, 0.0 false (nan vs 0.1)
# condition 200 200
# Could not filter
# VNEW  0.4537997477005863 m  202 xvar  4 count 1
# Linear filter...
# Filtered out 0/197, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/197, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/197, 0.0 false (nan vs 0.1)
# condition 197 197
# Could not filter
# VNEW  0.4967821657552988 m  202 xvar  4 count 2
# Linear filter...
# Filtered out 0/198, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/198, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/198, 0.0 false (nan vs 0.1)
# condition 198 198
# Could not filter
# VNEW  0.4560576058454536 m  202 xvar  4 count 3
# Linear filter...
# Filtered out 0/201, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/201, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/201, 0.0 false (nan vs 0.1)
# condition 201 201
# Could not filter
# VNEW  0.4431355530602643 m  202 xvar  4 count 4
# Linear filter...
# Filtered out 0/201, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/201, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/201, 0.0 false (nan vs 0.1)
# condition 201 201
# Could not filter
# VNEW  0.43438780519582654 m  202 xvar  4 count 5
# Linear filter...
# Filtered out 0/199, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/199, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/199, 0.0 false (nan vs 0.1)
# condition 199 199
# Could not filter
# VNEW  0.429855609271013 m  202 xvar  4 count 6
# Linear filter...
# Filtered out 0/202, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/202, 0.0 false (nan vs 0.1)
# condition 202 202
# Could not filter
# VNEW  0.4386625977284776 m  202 xvar  4 count 7
# Linear filter...
# Filtered out 0/200, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/200, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/200, 0.0 false (nan vs 0.1)
# condition 200 200
# Could not filter
# VNEW  0.4485628686199968 m  202 xvar  4 count 8
# Linear filter...
# Filtered out 0/200, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/200, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/200, 0.0 false (nan vs 0.1)
# condition 200 200
# Could not filter
# VNEW  0.44578877125316646 m  202 xvar  4 count 9
# Linear filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# condition 2 2
# Could not filter
# VNEW  5.866435437607546 m  2 xvar  5 count 0
# Linear filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# condition 2 2
# Could not filter
# VNEW  5.853459713045649 m  2 xvar  5 count 0
# Linear filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# condition 2 2
# Could not filter
# VNEW  6.078108273266166 m  2 xvar  5 count 0
# Linear filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# condition 2 2
# Could not filter
# VNEW  5.835599986761008 m  2 xvar  5 count 0
# Linear filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# condition 2 2
# Could not filter
# VNEW  5.703736307281765 m  2 xvar  5 count 0
# Linear filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# condition 2 2
# Could not filter
# VNEW  5.605107428384977 m  2 xvar  5 count 0
# Linear filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# condition 2 2
# Could not filter
# VNEW  6.231659452519332 m  2 xvar  5 count 0
# Linear filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# condition 2 2
# Could not filter
# VNEW  6.008865319074969 m  2 xvar  5 count 0
# Linear filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# condition 2 2
# Could not filter
# VNEW  5.749132840090542 m  2 xvar  5 count 0
# Linear filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# condition 2 2
# Could not filter
# VNEW  6.120179896157111 m  2 xvar  5 count 0
# Linear filter...
# Filtered out 0/200, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/200, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/200, 0.0 false (nan vs 0.1)
# condition 200 200
# Could not filter
# VNEW  0.4768857056577008 m  202 xvar  5 count 0
# Linear filter...
# Filtered out 0/201, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/201, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/201, 0.0 false (nan vs 0.1)
# condition 201 201
# Could not filter
# VNEW  0.540294107492084 m  202 xvar  5 count 1
# Linear filter...
# Filtered out 0/200, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/200, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/200, 0.0 false (nan vs 0.1)
# condition 200 200
# Could not filter
# VNEW  0.45261201707052023 m  202 xvar  5 count 2
# Linear filter...
# Filtered out 0/200, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/200, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/200, 0.0 false (nan vs 0.1)
# condition 200 200
# Could not filter
# VNEW  0.47236285799522787 m  202 xvar  5 count 3
# Linear filter...
# Filtered out 0/200, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/200, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/200, 0.0 false (nan vs 0.1)
# condition 200 200
# Could not filter
# VNEW  0.5106944241159156 m  202 xvar  5 count 4
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-87-c7aea927fc5d> in <module>
#      17
#      18 plot_m_loss = rl.plot(model, params, err, keys)
# ---> 19 plot_m_loss.setdata('k', k_bounds, trials, ylims, y_is_m = True, mrange = (2,200))
#
# ~/GitHub/robust_sparse_mean_estimation/robustlib.py in setdata(self, xvar_name, bounds, trials, ylims, y_is_m, mrange)
#     486     def setdata(self, xvar_name, bounds, trials, ylims, y_is_m = False, mrange = []):
#     487         Runs_l_samples = RunCollection(self.get_dataxy, (xvar_name, bounds, y_is_m, mrange))
# --> 488         Runs_l_samples.run(trials)
#     489         self.Run = Runs_l_samples
#     490
#
# ~/GitHub/robust_sparse_mean_estimation/robustlib.py in run(self, trials)
#      16     def run(self, trials):
#      17         for i in range(trials):
# ---> 18             self.runs.append(self.func(*self.inp))
#      19
#      20
#
# ~/GitHub/robust_sparse_mean_estimation/robustlib.py in get_dataxy(self, xvar_name, bounds, y_is_m, mrange)
#     450
#     451                             func = f(inp)
# --> 452                             vnew = self.loss(func.alg(S, indicator), tm)
#     453                             print("VNEW ",vnew,"m ",samp,"xvar ",xvar,"count",count)
#     454
#
# ~/GitHub/robust_sparse_mean_estimation/robustlib.py in alg(self, S, indicator)
#     276             cov_e = np.cov(S, rowvar=0)
#     277             M = cov_e - np.identity(d)
# --> 278             (mask, u) = indicat(M, k)
#     279             M_mask = mask*M
#     280
#
# ~/GitHub/robust_sparse_mean_estimation/robustlib.py in indicat(M, k)
#     521
#     522     idx = np.where(~np.eye(M.shape[0],dtype=bool)) # Change this too
# --> 523     val = np.partition(M[idx].flatten(), -k**2+k)[-k**2+k] # (k**2 - k)th largest off-diagonl element
#     524     idx2 = np.where(M > val)
#     525
#
# KeyboardInterrupt:

# %%
plot_m_loss.plotxy('k', k_bounds, (0,100))

# %%
"dimension vs sample complexity"
il.reload(rl)

k, eps = 3, 0.1
params = rl.Params(k=k, eps=eps)
trials = 5

model = rl.BimodalModel()

print(f"Running on k={k}, eps={eps}")

keys = [rl.RME_sp]
ylims = (0, 100)
def err(a,b): return LA.norm(a-b)

d_bounds = ((k+2), 60, 10)

plot_m_loss = rl.plot(model, params, err, keys)
plot_m_loss.setdata('d', d_bounds, trials, ylims, y_is_m = True, mrange = (2,2))
# Out:
# Running on k=3, eps=0.1
# Linear filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# condition 2 2
# Could not filter
# VNEW  2.459613409010488 m  2 xvar  5 count 0
# Linear filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# condition 2 2
# Could not filter
# VNEW  3.04516087545884 m  2 xvar  5 count 0
# Linear filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# condition 2 2
# Could not filter
# VNEW  2.5546142666022886 m  2 xvar  5 count 0
# Linear filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# condition 2 2
# Could not filter
# VNEW  2.475033919055724 m  2 xvar  5 count 0
# Linear filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# condition 2 2
# Could not filter
# VNEW  2.60952711905654 m  2 xvar  5 count 0
# Linear filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# condition 2 2
# Could not filter
# VNEW  1.155103815020727 m  2 xvar  5 count 0
# Linear filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# condition 2 2
# Could not filter
# VNEW  1.8792758241102716 m  2 xvar  5 count 1
# Linear filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# condition 2 2
# Could not filter
# VNEW  1.7354002251275171 m  2 xvar  5 count 1
# Linear filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# condition 2 2
# Could not filter
# VNEW  1.970011532206373 m  2 xvar  5 count 1
# Linear filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# condition 2 2
# Could not filter
# VNEW  2.40728207899672 m  2 xvar  5 count 1
# Linear filter...
# Filtered out 0/3, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/3, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/3, 0.0 false (nan vs 0.1)
# condition 3 3
# Could not filter
# VNEW  0.4975833864890925 m  4 xvar  5 count 0
# Linear filter...
# Filtered out 0/4, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/4, 0.0 false (nan vs 0.1)
# condition 4 4
# Could not filter
# VNEW  1.2076917944847736 m  4 xvar  5 count 1
# Linear filter...
# Filtered out 0/4, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/4, 0.0 false (nan vs 0.1)
# condition 4 4
# Could not filter
# VNEW  0.8330879687360022 m  4 xvar  5 count 1
# Linear filter...
# Filtered out 0/4, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/4, 0.0 false (nan vs 0.1)
# condition 4 4
# Could not filter
# VNEW  1.886057149621191 m  4 xvar  5 count 2
# Linear filter...
# Filtered out 0/4, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/4, 0.0 false (nan vs 0.1)
# condition 4 4
# Could not filter
# VNEW  1.1117710887996064 m  4 xvar  5 count 2
# Linear filter...
# Filtered out 0/4, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/4, 0.0 false (nan vs 0.1)
# condition 4 4
# Could not filter
# VNEW  0.8893456816934566 m  4 xvar  5 count 3
# Linear filter...
# Filtered out 0/4, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/4, 0.0 false (nan vs 0.1)
# condition 4 4
# Could not filter
# VNEW  1.2354267818832394 m  4 xvar  5 count 4
# Linear filter...
# Filtered out 0/4, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/4, 0.0 false (nan vs 0.1)
# condition 4 4
# Could not filter
# VNEW  1.522886341568144 m  4 xvar  5 count 4
# Linear filter...
# Filtered out 0/3, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/3, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/3, 0.0 false (nan vs 0.1)
# condition 3 3
# Could not filter
# VNEW  2.1090561321774555 m  4 xvar  5 count 4
# Linear filter...
# Filtered out 0/4, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/4, 0.0 false (nan vs 0.1)
# condition 4 4
# Could not filter
# VNEW  1.213971084049334 m  4 xvar  5 count 4
# Linear filter...
# Filtered out 0/5, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/5, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/5, 0.0 false (nan vs 0.1)
# condition 5 5
# Could not filter
# VNEW  0.23870970214179182 m  6 xvar  5 count 0
# Linear filter...
# Filtered out 0/6, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/6, 0.0 false (nan vs 0.1)
# condition 6 6
# Could not filter
# VNEW  1.2748569079406593 m  6 xvar  5 count 1
# Linear filter...
# Filtered out 0/6, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/6, 0.0 false (nan vs 0.1)
# condition 6 6
# Could not filter
# VNEW  1.279628292608573 m  6 xvar  5 count 1
# Linear filter...
# Filtered out 0/6, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/6, 0.0 false (nan vs 0.1)
# condition 6 6
# Could not filter
# VNEW  0.7402826739313463 m  6 xvar  5 count 1
# Linear filter...
# Filtered out 0/6, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/6, 0.0 false (nan vs 0.1)
# condition 6 6
# Could not filter
# VNEW  0.6100626796412602 m  6 xvar  5 count 2
# Linear filter...
# Filtered out 0/6, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/6, 0.0 false (nan vs 0.1)
# condition 6 6
# Could not filter
# VNEW  1.1793069967238838 m  6 xvar  5 count 3
# Linear filter...
# Filtered out 0/6, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/6, 0.0 false (nan vs 0.1)
# condition 6 6
# Could not filter
# VNEW  1.5948669343859512 m  6 xvar  5 count 4
# Linear filter...
# Filtered out 0/6, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/6, 0.0 false (nan vs 0.1)
# condition 6 6
# Could not filter
# VNEW  1.585117813858597 m  6 xvar  5 count 4
# Linear filter...
# Filtered out 0/6, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/6, 0.0 false (nan vs 0.1)
# condition 6 6
# Could not filter
# VNEW  1.0947834034411568 m  6 xvar  5 count 4
# Linear filter...
# Filtered out 0/6, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/6, 0.0 false (nan vs 0.1)
# condition 6 6
# Could not filter
# VNEW  0.12448394812172137 m  6 xvar  5 count 5
# Linear filter...
# Filtered out 0/8, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/8, 0.0 false (nan vs 0.1)
# condition 8 8
# Could not filter
# VNEW  0.7561360057204621 m  8 xvar  5 count 0
# Linear filter...
# Filtered out 0/8, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/8, 0.0 false (nan vs 0.1)
# condition 8 8
# Could not filter
# VNEW  0.5263153548441027 m  8 xvar  5 count 1
# Quadratic filter...
# Filtered out 0/8, 0.0 false (nan vs 0.1)
# condition 8 8
# Could not filter
# VNEW  0.9836316472261343 m  8 xvar  5 count 2
# Linear filter...
# Filtered out 0/7, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/7, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/7, 0.0 false (nan vs 0.1)
# condition 7 7
# Could not filter
# VNEW  1.3017247218154318 m  8 xvar  5 count 3
# Linear filter...
# Filtered out 0/8, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/8, 0.0 false (nan vs 0.1)
# condition 8 8
# Could not filter
# VNEW  1.3174957295188576 m  8 xvar  5 count 3
# Linear filter...
# Filtered out 0/8, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/8, 0.0 false (nan vs 0.1)
# condition 8 8
# Could not filter
# VNEW  0.2519775715734949 m  8 xvar  5 count 3
# Linear filter...
# Filtered out 0/8, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/8, 0.0 false (nan vs 0.1)
# condition 8 8
# Could not filter
# VNEW  1.1107461849750482 m  8 xvar  5 count 4
# Linear filter...
# Filtered out 0/8, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/8, 0.0 false (nan vs 0.1)
# condition 8 8
# Could not filter
# VNEW  0.20254078874688894 m  8 xvar  5 count 5
# Linear filter...
# Filtered out 0/7, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/7, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/7, 0.0 false (nan vs 0.1)
# condition 7 7
# Could not filter
# VNEW  0.5598843761694685 m  8 xvar  5 count 6
# Linear filter...
# Filtered out 0/8, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/8, 0.0 false (nan vs 0.1)
# condition 8 8
# Could not filter
# VNEW  0.34180943068933584 m  8 xvar  5 count 7
# Linear filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# condition 2 2
# Could not filter
# VNEW  1.5581896497370213 m  2 xvar  15 count 0
# Linear filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# condition 2 2
# Could not filter
# VNEW  2.6862729126048897 m  2 xvar  15 count 0
# Linear filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# condition 2 2
# Could not filter
# VNEW  2.9012331074619184 m  2 xvar  15 count 0
# Linear filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# condition 2 2
# Could not filter
# VNEW  3.2773409342958 m  2 xvar  15 count 0
# Linear filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# condition 2 2
# Could not filter
# VNEW  1.385771330227959 m  2 xvar  15 count 0
# Linear filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# condition 2 2
# Could not filter
# VNEW  2.1828447720715505 m  2 xvar  15 count 0
# Linear filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# condition 2 2
# Could not filter
# VNEW  3.0693682759033982 m  2 xvar  15 count 0
# Linear filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# condition 2 2
# Could not filter
# VNEW  2.733906061008088 m  2 xvar  15 count 0
# Linear filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# condition 2 2
# Could not filter
# VNEW  2.803091286489344 m  2 xvar  15 count 0
# Linear filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# condition 2 2
# Could not filter
# VNEW  2.6976293530444218 m  2 xvar  15 count 0
# Linear filter...
# Filtered out 0/4, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/4, 0.0 false (nan vs 0.1)
# condition 4 4
# Could not filter
# VNEW  1.761383587572567 m  4 xvar  15 count 0
# Linear filter...
# Filtered out 0/4, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/4, 0.0 false (nan vs 0.1)
# condition 4 4
# Could not filter
# VNEW  1.9991155027624303 m  4 xvar  15 count 0
# Linear filter...
# Filtered out 0/3, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/3, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/3, 0.0 false (nan vs 0.1)
# condition 3 3
# Could not filter
# VNEW  1.64453575071691 m  4 xvar  15 count 0
# Linear filter...
# Filtered out 0/4, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/4, 0.0 false (nan vs 0.1)
# condition 4 4
# Could not filter
# VNEW  2.1637508124717115 m  4 xvar  15 count 0
# Linear filter...
# Filtered out 0/4, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/4, 0.0 false (nan vs 0.1)
# condition 4 4
# Could not filter
# VNEW  1.774110454183508 m  4 xvar  15 count 0
# Linear filter...
# Filtered out 0/3, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/3, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/3, 0.0 false (nan vs 0.1)
# condition 3 3
# Could not filter
# VNEW  2.5836397480983897 m  4 xvar  15 count 0
# Linear filter...
# Filtered out 0/3, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/3, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/3, 0.0 false (nan vs 0.1)
# condition 3 3
# Could not filter
# VNEW  1.6012870328324618 m  4 xvar  15 count 0
# Linear filter...
# Filtered out 0/4, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/4, 0.0 false (nan vs 0.1)
# condition 4 4
# Could not filter
# VNEW  2.1550757556328373 m  4 xvar  15 count 0
# Linear filter...
# Filtered out 0/3, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/3, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/3, 0.0 false (nan vs 0.1)
# condition 3 3
# Could not filter
# VNEW  1.1162174387359831 m  4 xvar  15 count 0
# Linear filter...
# Filtered out 0/4, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/4, 0.0 false (nan vs 0.1)
# condition 4 4
# Could not filter
# VNEW  1.914561823326868 m  4 xvar  15 count 1
# Linear filter...
# Filtered out 0/4, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/4, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/4, 0.0 false (nan vs 0.1)
# condition 4 4
# Could not filter
# VNEW  1.946774585068867 m  6 xvar  15 count 0
# Linear filter...
# Filtered out 0/6, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/6, 0.0 false (nan vs 0.1)
# condition 6 6
# Could not filter
# VNEW  1.3762544761262931 m  6 xvar  15 count 0
# Linear filter...
# Filtered out 0/6, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/6, 0.0 false (nan vs 0.1)
# condition 6 6
# Could not filter
# VNEW  1.2805688343256199 m  6 xvar  15 count 0
# Linear filter...
# Filtered out 0/6, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/6, 0.0 false (nan vs 0.1)
# condition 6 6
# Could not filter
# VNEW  1.3158599542464768 m  6 xvar  15 count 0
# Linear filter...
# Filtered out 0/6, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/6, 0.0 false (nan vs 0.1)
# condition 6 6
# Could not filter
# VNEW  1.4806661237557346 m  6 xvar  15 count 0
# Linear filter...
# Filtered out 0/6, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/6, 0.0 false (nan vs 0.1)
# condition 6 6
# Could not filter
# VNEW  1.472012432951244 m  6 xvar  15 count 0
# Linear filter...
# Filtered out 0/6, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/6, 0.0 false (nan vs 0.1)
# condition 6 6
# Could not filter
# VNEW  1.3348123238207863 m  6 xvar  15 count 0
# Linear filter...
# Filtered out 0/6, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/6, 0.0 false (nan vs 0.1)
# condition 6 6
# Could not filter
# VNEW  0.20735077460312248 m  6 xvar  15 count 0
# Linear filter...
# Filtered out 0/5, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/5, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/5, 0.0 false (nan vs 0.1)
# condition 5 5
# Could not filter
# VNEW  1.3000188315044603 m  6 xvar  15 count 1
# Linear filter...
# Filtered out 0/6, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/6, 0.0 false (nan vs 0.1)
# condition 6 6
# Could not filter
# VNEW  1.8695332220406549 m  6 xvar  15 count 1
# Linear filter...
# Filtered out 0/8, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/8, 0.0 false (nan vs 0.1)
# condition 8 8
# Could not filter
# VNEW  1.3769271337061346 m  8 xvar  15 count 0
# Linear filter...
# Filtered out 0/7, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/7, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/7, 0.0 false (nan vs 0.1)
# condition 7 7
# Could not filter
# VNEW  1.2486298356175405 m  8 xvar  15 count 0
# Linear filter...
# Filtered out 0/8, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/8, 0.0 false (nan vs 0.1)
# condition 8 8
# Could not filter
# VNEW  1.5720421492217362 m  8 xvar  15 count 0
# Linear filter...
# Filtered out 0/8, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/8, 0.0 false (nan vs 0.1)
# condition 8 8
# Could not filter
# VNEW  1.1772780750352232 m  8 xvar  15 count 0
# Linear filter...
# Filtered out 0/8, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/8, 0.0 false (nan vs 0.1)
# condition 8 8
# Could not filter
# VNEW  0.9520775099608322 m  8 xvar  15 count 1
# Linear filter...
# Filtered out 0/7, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/7, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/7, 0.0 false (nan vs 0.1)
# condition 7 7
# Could not filter
# VNEW  0.4291152548385816 m  8 xvar  15 count 2
# Linear filter...
# Filtered out 0/8, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/8, 0.0 false (nan vs 0.1)
# condition 8 8
# Could not filter
# VNEW  1.3143764134160747 m  8 xvar  15 count 3
# Linear filter...
# Filtered out 0/8, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/8, 0.0 false (nan vs 0.1)
# condition 8 8
# Could not filter
# VNEW  0.6321379025882375 m  8 xvar  15 count 3
# Linear filter...
# Filtered out 0/8, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/8, 0.0 false (nan vs 0.1)
# condition 8 8
# Could not filter
# VNEW  1.246296411984654 m  8 xvar  15 count 4
# Linear filter...
# Filtered out 0/7, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/7, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/7, 0.0 false (nan vs 0.1)
# condition 7 7
# Could not filter
# VNEW  0.7902223762743631 m  8 xvar  15 count 4
# Linear filter...
# Filtered out 0/10, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/10, 0.0 false (nan vs 0.1)
# condition 10 10
# Could not filter
# VNEW  1.3599345996773267 m  10 xvar  15 count 0
# Linear filter...
# Filtered out 0/10, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/10, 0.0 false (nan vs 0.1)
# condition 10 10
# Could not filter
# VNEW  0.5570393421378483 m  10 xvar  15 count 0
# Linear filter...
# Filtered out 0/10, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/10, 0.0 false (nan vs 0.1)
# condition 10 10
# Could not filter
# VNEW  0.41598230949755444 m  10 xvar  15 count 1
# Linear filter...
# Filtered out 0/10, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/10, 0.0 false (nan vs 0.1)
# condition 10 10
# Could not filter
# VNEW  1.3447502850910933 m  10 xvar  15 count 2
# Linear filter...
# Filtered out 0/9, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/9, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/9, 0.0 false (nan vs 0.1)
# condition 9 9
# Could not filter
# VNEW  0.4588714543820471 m  10 xvar  15 count 2
# Linear filter...
# Filtered out 0/10, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/10, 0.0 false (nan vs 0.1)
# condition 10 10
# Could not filter
# VNEW  1.3297838780306672 m  10 xvar  15 count 3
# Linear filter...
# Filtered out 0/10, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/10, 0.0 false (nan vs 0.1)
# condition 10 10
# Could not filter
# VNEW  1.7344662781890487 m  10 xvar  15 count 3
# Linear filter...
# Filtered out 0/10, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/10, 0.0 false (nan vs 0.1)
# condition 10 10
# Could not filter
# VNEW  1.5059728976301217 m  10 xvar  15 count 3
# Linear filter...
# Filtered out 0/10, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/10, 0.0 false (nan vs 0.1)
# condition 10 10
# Could not filter
# VNEW  0.394747908175599 m  10 xvar  15 count 3
# Linear filter...
# Filtered out 0/9, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/9, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/9, 0.0 false (nan vs 0.1)
# condition 9 9
# Could not filter
# VNEW  1.1714592149501801 m  10 xvar  15 count 4
# Linear filter...
# Filtered out 0/12, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/12, 0.0 false (nan vs 0.1)
# condition 12 12
# Could not filter
# VNEW  1.2894222109232576 m  12 xvar  15 count 0
# Linear filter...
# Filtered out 0/12, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/12, 0.0 false (nan vs 0.1)
# condition 12 12
# Could not filter
# VNEW  0.401256628725542 m  12 xvar  15 count 0
# Linear filter...
# Filtered out 0/12, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/12, 0.0 false (nan vs 0.1)
# condition 12 12
# Could not filter
# VNEW  0.40574471732797757 m  12 xvar  15 count 1
# Linear filter...
# Filtered out 0/12, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/12, 0.0 false (nan vs 0.1)
# condition 12 12
# Could not filter
# VNEW  1.1162280039669368 m  12 xvar  15 count 2
# Linear filter...
# Filtered out 0/12, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/12, 0.0 false (nan vs 0.1)
# condition 12 12
# Could not filter
# VNEW  0.4737215130447336 m  12 xvar  15 count 3
# Linear filter...
# Filtered out 0/11, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/11, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/11, 0.0 false (nan vs 0.1)
# condition 11 11
# Could not filter
# VNEW  0.4571964586848138 m  12 xvar  15 count 4
# Linear filter...
# Filtered out 0/11, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/11, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/11, 0.0 false (nan vs 0.1)
# condition 11 11
# Could not filter
# VNEW  1.2644689797767892 m  12 xvar  15 count 5
# Linear filter...
# Filtered out 0/12, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/12, 0.0 false (nan vs 0.1)
# condition 12 12
# Could not filter
# VNEW  0.30826145484453316 m  12 xvar  15 count 5
# Linear filter...
# Filtered out 0/12, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/12, 0.0 false (nan vs 0.1)
# condition 12 12
# Could not filter
# VNEW  1.1851458853793118 m  12 xvar  15 count 6
# Linear filter...
# Filtered out 0/12, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/12, 0.0 false (nan vs 0.1)
# condition 12 12
# Could not filter
# VNEW  1.2698047718905159 m  12 xvar  15 count 7
# Linear filter...
# Filtered out 0/14, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/14, 0.0 false (nan vs 0.1)
# condition 14 14
# Could not filter
# VNEW  0.32353834345561056 m  14 xvar  15 count 0
# Linear filter...
# Filtered out 0/14, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/14, 0.0 false (nan vs 0.1)
# condition 14 14
# Could not filter
# VNEW  0.1963767487489246 m  14 xvar  15 count 1
# Linear filter...
# Filtered out 0/14, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/14, 0.0 false (nan vs 0.1)
# condition 14 14
# Could not filter
# VNEW  1.3687050278316917 m  14 xvar  15 count 2
# Linear filter...
# Filtered out 0/13, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/13, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/13, 0.0 false (nan vs 0.1)
# condition 13 13
# Could not filter
# VNEW  0.49930805433837805 m  14 xvar  15 count 2
# Linear filter...
# Filtered out 0/14, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/14, 0.0 false (nan vs 0.1)
# condition 14 14
# Could not filter
# VNEW  0.4929530051908731 m  14 xvar  15 count 3
# Linear filter...
# Filtered out 0/14, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/14, 0.0 false (nan vs 0.1)
# condition 14 14
# Could not filter
# VNEW  1.1423883049534964 m  14 xvar  15 count 4
# Linear filter...
# Filtered out 0/14, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/14, 0.0 false (nan vs 0.1)
# condition 14 14
# Could not filter
# VNEW  1.1069289125215243 m  14 xvar  15 count 5
# Linear filter...
# Filtered out 0/14, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/14, 0.0 false (nan vs 0.1)
# condition 14 14
# Could not filter
# VNEW  0.4556405916552404 m  14 xvar  15 count 6
# Linear filter...
# Filtered out 0/14, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/14, 0.0 false (nan vs 0.1)
# condition 14 14
# Could not filter
# VNEW  1.781525529010938 m  14 xvar  15 count 7
# Linear filter...
# Filtered out 0/14, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/14, 0.0 false (nan vs 0.1)
# condition 14 14
# Could not filter
# VNEW  0.44426283465814753 m  14 xvar  15 count 7
# Linear filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# condition 2 2
# Could not filter
# VNEW  2.627315417460265 m  2 xvar  25 count 0
# Linear filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# condition 2 2
# Could not filter
# VNEW  3.2826057382496545 m  2 xvar  25 count 0
# Linear filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# condition 2 2
# Could not filter
# VNEW  3.2667088482749507 m  2 xvar  25 count 0
# Linear filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# condition 2 2
# Could not filter
# VNEW  3.0527427091563237 m  2 xvar  25 count 0
# Linear filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# condition 2 2
# Could not filter
# VNEW  3.3414381952961683 m  2 xvar  25 count 0
# Linear filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# condition 2 2
# Could not filter
# VNEW  4.52704839472241 m  2 xvar  25 count 0
# Linear filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# condition 2 2
# Could not filter
# VNEW  5.2500668109152535 m  2 xvar  25 count 0
# Linear filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# condition 2 2
# Could not filter
# VNEW  3.8338660123880075 m  2 xvar  25 count 0
# Linear filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# condition 2 2
# Could not filter
# VNEW  2.4680744925691225 m  2 xvar  25 count 0
# Linear filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# condition 2 2
# Could not filter
# VNEW  2.872340191472582 m  2 xvar  25 count 0
# Linear filter...
# Filtered out 0/4, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/4, 0.0 false (nan vs 0.1)
# condition 4 4
# Could not filter
# VNEW  2.0200133641322875 m  4 xvar  25 count 0
# Linear filter...
# Filtered out 0/4, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/4, 0.0 false (nan vs 0.1)
# condition 4 4
# Could not filter
# VNEW  1.977119312226941 m  4 xvar  25 count 0
# Linear filter...
# Filtered out 0/3, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/3, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/3, 0.0 false (nan vs 0.1)
# condition 3 3
# Could not filter
# VNEW  1.759352515569108 m  4 xvar  25 count 0
# Linear filter...
# Filtered out 0/4, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/4, 0.0 false (nan vs 0.1)
# condition 4 4
# Could not filter
# VNEW  2.625903891809795 m  4 xvar  25 count 0
# Linear filter...
# Filtered out 0/3, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/3, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/3, 0.0 false (nan vs 0.1)
# condition 3 3
# Could not filter
# VNEW  2.1032175332078946 m  4 xvar  25 count 0
# Linear filter...
# Filtered out 0/4, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/4, 0.0 false (nan vs 0.1)
# condition 4 4
# Could not filter
# VNEW  2.3089010402368544 m  4 xvar  25 count 0
# Linear filter...
# Filtered out 0/4, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/4, 0.0 false (nan vs 0.1)
# condition 4 4
# Could not filter
# VNEW  2.3354369651775366 m  4 xvar  25 count 0
# Linear filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# condition 2 2
# Could not filter
# VNEW  3.0270660362019823 m  4 xvar  25 count 0
# Linear filter...
# Filtered out 0/3, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/3, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/3, 0.0 false (nan vs 0.1)
# condition 3 3
# Could not filter
# VNEW  1.6453869367038234 m  4 xvar  25 count 0
# Linear filter...
# Filtered out 0/3, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/3, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/3, 0.0 false (nan vs 0.1)
# condition 3 3
# Could not filter
# VNEW  2.2257392716511073 m  4 xvar  25 count 0
# Linear filter...
# Filtered out 0/6, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/6, 0.0 false (nan vs 0.1)
# condition 6 6
# Could not filter
# VNEW  1.9440808869947692 m  6 xvar  25 count 0
# Linear filter...
# Filtered out 0/6, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/6, 0.0 false (nan vs 0.1)
# condition 6 6
# Could not filter
# VNEW  2.1676214355414034 m  6 xvar  25 count 0
# Linear filter...
# Filtered out 0/6, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/6, 0.0 false (nan vs 0.1)
# condition 6 6
# Could not filter
# VNEW  1.6472112951315732 m  6 xvar  25 count 0
# Linear filter...
# Filtered out 0/6, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/6, 0.0 false (nan vs 0.1)
# condition 6 6
# Could not filter
# VNEW  1.5967089259829663 m  6 xvar  25 count 0
# Linear filter...
# Filtered out 0/5, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/5, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/5, 0.0 false (nan vs 0.1)
# condition 5 5
# Could not filter
# VNEW  0.6461270736713608 m  6 xvar  25 count 0
# Linear filter...
# Filtered out 0/6, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/6, 0.0 false (nan vs 0.1)
# condition 6 6
# Could not filter
# VNEW  0.17382382101456267 m  6 xvar  25 count 1
# Linear filter...
# Filtered out 0/6, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/6, 0.0 false (nan vs 0.1)
# condition 6 6
# Could not filter
# VNEW  1.3428039878833076 m  6 xvar  25 count 2
# Linear filter...
# Filtered out 0/6, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/6, 0.0 false (nan vs 0.1)
# condition 6 6
# Could not filter
# VNEW  2.33840350762251 m  6 xvar  25 count 2
# Linear filter...
# Filtered out 0/6, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/6, 0.0 false (nan vs 0.1)
# condition 6 6
# Could not filter
# VNEW  1.6211345667389925 m  6 xvar  25 count 2
# Linear filter...
# Filtered out 0/6, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/6, 0.0 false (nan vs 0.1)
# condition 6 6
# Could not filter
# VNEW  1.7535408108487585 m  6 xvar  25 count 2
# Linear filter...
# Filtered out 0/8, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/8, 0.0 false (nan vs 0.1)
# condition 8 8
# Could not filter
# VNEW  1.4382655357055034 m  8 xvar  25 count 0
# Linear filter...
# Filtered out 0/8, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/8, 0.0 false (nan vs 0.1)
# condition 8 8
# Could not filter
# VNEW  1.3140925191451258 m  8 xvar  25 count 0
# Linear filter...
# Filtered out 0/8, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/8, 0.0 false (nan vs 0.1)
# condition 8 8
# Could not filter
# VNEW  1.4249876255916132 m  8 xvar  25 count 0
# Linear filter...
# Filtered out 0/8, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/8, 0.0 false (nan vs 0.1)
# condition 8 8
# Could not filter
# VNEW  0.37175022840713323 m  8 xvar  25 count 0
# Linear filter...
# Filtered out 0/8, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/8, 0.0 false (nan vs 0.1)
# condition 8 8
# Could not filter
# VNEW  1.7885123718895741 m  8 xvar  25 count 1
# Linear filter...
# Filtered out 0/7, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/7, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/7, 0.0 false (nan vs 0.1)
# condition 7 7
# Could not filter
# VNEW  1.2769746592330409 m  8 xvar  25 count 1
# Linear filter...
# Filtered out 0/8, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/8, 0.0 false (nan vs 0.1)
# condition 8 8
# Could not filter
# VNEW  1.6485309228486142 m  8 xvar  25 count 1
# Linear filter...
# Filtered out 0/7, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/7, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/7, 0.0 false (nan vs 0.1)
# condition 7 7
# Could not filter
# VNEW  2.04589790460882 m  8 xvar  25 count 1
# Linear filter...
# Filtered out 0/7, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/7, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/7, 0.0 false (nan vs 0.1)
# condition 7 7
# Could not filter
# VNEW  0.5574087009537191 m  8 xvar  25 count 1
# Linear filter...
# Filtered out 0/8, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/8, 0.0 false (nan vs 0.1)
# condition 8 8
# Could not filter
# VNEW  1.310964216036984 m  8 xvar  25 count 2
# Linear filter...
# Filtered out 0/10, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/10, 0.0 false (nan vs 0.1)
# condition 10 10
# Could not filter
# VNEW  1.4401292620774298 m  10 xvar  25 count 0
# Linear filter...
# Filtered out 0/10, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/10, 0.0 false (nan vs 0.1)
# condition 10 10
# Could not filter
# VNEW  1.3257428487377108 m  10 xvar  25 count 0
# Linear filter...
# Filtered out 0/9, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/9, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/9, 0.0 false (nan vs 0.1)
# condition 9 9
# Could not filter
# VNEW  0.29308494060290174 m  10 xvar  25 count 0
# Linear filter...
# Filtered out 0/9, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/9, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/9, 0.0 false (nan vs 0.1)
# condition 9 9
# Could not filter
# VNEW  1.3300352455485982 m  10 xvar  25 count 1
# Linear filter...
# Filtered out 0/9, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/9, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/9, 0.0 false (nan vs 0.1)
# condition 9 9
# Could not filter
# VNEW  0.9104177688562745 m  10 xvar  25 count 1
# Linear filter...
# Filtered out 0/10, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/10, 0.0 false (nan vs 0.1)
# condition 10 10
# Could not filter
# VNEW  0.4527496840366412 m  10 xvar  25 count 2
# Linear filter...
# Filtered out 0/10, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/10, 0.0 false (nan vs 0.1)
# condition 10 10
# Could not filter
# VNEW  0.4222086435476144 m  10 xvar  25 count 3
# Linear filter...
# Filtered out 0/9, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/9, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/9, 0.0 false (nan vs 0.1)
# condition 9 9
# Could not filter
# VNEW  1.2166685880173194 m  10 xvar  25 count 4
# Linear filter...
# Filtered out 0/10, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/10, 0.0 false (nan vs 0.1)
# condition 10 10
# Could not filter
# VNEW  1.3123612281687556 m  10 xvar  25 count 4
# Linear filter...
# Filtered out 0/9, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/9, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/9, 0.0 false (nan vs 0.1)
# condition 9 9
# Could not filter
# VNEW  0.3462381977958004 m  10 xvar  25 count 4
# Linear filter...
# Filtered out 0/11, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/11, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/11, 0.0 false (nan vs 0.1)
# condition 11 11
# Could not filter
# VNEW  1.1963565535261578 m  12 xvar  25 count 0
# Linear filter...
# Filtered out 0/12, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/12, 0.0 false (nan vs 0.1)
# condition 12 12
# Could not filter
# VNEW  0.4577401353159372 m  12 xvar  25 count 1
# Linear filter...
# Filtered out 0/12, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/12, 0.0 false (nan vs 0.1)
# condition 12 12
# Could not filter
# VNEW  1.199386922169311 m  12 xvar  25 count 2
# Linear filter...
# Filtered out 0/12, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/12, 0.0 false (nan vs 0.1)
# condition 12 12
# Could not filter
# VNEW  0.04518421920836462 m  12 xvar  25 count 3
# Linear filter...
# Filtered out 0/12, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/12, 0.0 false (nan vs 0.1)
# condition 12 12
# Could not filter
# VNEW  0.7927498326778367 m  12 xvar  25 count 4
# Linear filter...
# Filtered out 0/12, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/12, 0.0 false (nan vs 0.1)
# condition 12 12
# Could not filter
# VNEW  1.3524757799260345 m  12 xvar  25 count 5
# Linear filter...
# Filtered out 0/11, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/11, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/11, 0.0 false (nan vs 0.1)
# condition 11 11
# Could not filter
# VNEW  1.4307299124019763 m  12 xvar  25 count 5
# Linear filter...
# Filtered out 0/12, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/12, 0.0 false (nan vs 0.1)
# condition 12 12
# Could not filter
# VNEW  1.278688173934319 m  12 xvar  25 count 5
# Linear filter...
# Filtered out 0/12, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/12, 0.0 false (nan vs 0.1)
# condition 12 12
# Could not filter
# VNEW  0.27248801852372306 m  12 xvar  25 count 5
# Linear filter...
# Filtered out 0/11, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/11, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/11, 0.0 false (nan vs 0.1)
# condition 11 11
# Could not filter
# VNEW  1.287617291041252 m  12 xvar  25 count 6
# Linear filter...
# Filtered out 0/14, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/14, 0.0 false (nan vs 0.1)
# condition 14 14
# Could not filter
# VNEW  0.38403742380842554 m  14 xvar  25 count 0
# Linear filter...
# Filtered out 0/14, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/14, 0.0 false (nan vs 0.1)
# condition 14 14
# Could not filter
# VNEW  0.38542073253258247 m  14 xvar  25 count 1
# Linear filter...
# Filtered out 0/14, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/14, 0.0 false (nan vs 0.1)
# condition 14 14
# Could not filter
# VNEW  0.17114799219474386 m  14 xvar  25 count 2
# Linear filter...
# Filtered out 0/14, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/14, 0.0 false (nan vs 0.1)
# condition 14 14
# Could not filter
# VNEW  1.211006585276946 m  14 xvar  25 count 3
# Linear filter...
# Filtered out 0/14, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/14, 0.0 false (nan vs 0.1)
# condition 14 14
# Could not filter
# VNEW  0.3249682202347346 m  14 xvar  25 count 3
# Linear filter...
# Filtered out 0/14, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/14, 0.0 false (nan vs 0.1)
# condition 14 14
# Could not filter
# VNEW  0.5578011926373025 m  14 xvar  25 count 4
# Linear filter...
# Filtered out 0/14, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/14, 0.0 false (nan vs 0.1)
# condition 14 14
# Could not filter
# VNEW  0.43315278362490445 m  14 xvar  25 count 5
# Linear filter...
# Filtered out 0/14, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/14, 0.0 false (nan vs 0.1)
# condition 14 14
# Could not filter
# VNEW  0.49915788865654226 m  14 xvar  25 count 6
# Linear filter...
# Filtered out 0/14, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/14, 0.0 false (nan vs 0.1)
# condition 14 14
# Could not filter
# VNEW  1.2390961250323775 m  14 xvar  25 count 7
# Linear filter...
# Filtered out 0/14, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/14, 0.0 false (nan vs 0.1)
# condition 14 14
# Could not filter
# VNEW  0.16534511587485778 m  14 xvar  25 count 7
# Linear filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# condition 2 2
# Could not filter
# VNEW  3.3496279629158274 m  2 xvar  35 count 0
# Linear filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# condition 2 2
# Could not filter
# VNEW  3.684738413649369 m  2 xvar  35 count 0
# Linear filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# condition 2 2
# Could not filter
# VNEW  4.522215051688591 m  2 xvar  35 count 0
# Linear filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# condition 2 2
# Could not filter
# VNEW  3.134296472624188 m  2 xvar  35 count 0
# Linear filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# condition 2 2
# Could not filter
# VNEW  2.87433109188795 m  2 xvar  35 count 0
# Linear filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# condition 2 2
# Could not filter
# VNEW  3.0045303114322723 m  2 xvar  35 count 0
# Linear filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# condition 2 2
# Could not filter
# VNEW  3.157202132140263 m  2 xvar  35 count 0
# Linear filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# condition 2 2
# Could not filter
# VNEW  3.3603550383933456 m  2 xvar  35 count 0
# Linear filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# condition 2 2
# Could not filter
# VNEW  3.128192782923992 m  2 xvar  35 count 0
# Linear filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# condition 2 2
# Could not filter
# VNEW  2.687371513687464 m  2 xvar  35 count 0
# Linear filter...
# Filtered out 0/4, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/4, 0.0 false (nan vs 0.1)
# condition 4 4
# Could not filter
# VNEW  1.8817557321360534 m  4 xvar  35 count 0
# Linear filter...
# Filtered out 0/3, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/3, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/3, 0.0 false (nan vs 0.1)
# condition 3 3
# Could not filter
# VNEW  2.8899632336068506 m  4 xvar  35 count 0
# Linear filter...
# Filtered out 0/3, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/3, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/3, 0.0 false (nan vs 0.1)
# condition 3 3
# Could not filter
# VNEW  2.1506679529625363 m  4 xvar  35 count 0
# Linear filter...
# Filtered out 0/3, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/3, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/3, 0.0 false (nan vs 0.1)
# condition 3 3
# Could not filter
# VNEW  2.806870380324239 m  4 xvar  35 count 0
# Linear filter...
# Filtered out 0/4, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/4, 0.0 false (nan vs 0.1)
# condition 4 4
# Could not filter
# VNEW  2.169179549513603 m  4 xvar  35 count 0
# Linear filter...
# Filtered out 0/4, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/4, 0.0 false (nan vs 0.1)
# condition 4 4
# Could not filter
# VNEW  3.0218318011861482 m  4 xvar  35 count 0
# Linear filter...
# Filtered out 0/3, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/3, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/3, 0.0 false (nan vs 0.1)
# condition 3 3
# Could not filter
# VNEW  2.7262758579268302 m  4 xvar  35 count 0
# Linear filter...
# Filtered out 0/4, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/4, 0.0 false (nan vs 0.1)
# condition 4 4
# Could not filter
# VNEW  2.4820476730675565 m  4 xvar  35 count 0
# Linear filter...
# Filtered out 0/3, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/3, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/3, 0.0 false (nan vs 0.1)
# condition 3 3
# Could not filter
# VNEW  2.5889382731955193 m  4 xvar  35 count 0
# Linear filter...
# Filtered out 0/3, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/3, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/3, 0.0 false (nan vs 0.1)
# condition 3 3
# Could not filter
# VNEW  2.3886518760065374 m  4 xvar  35 count 0
# Linear filter...
# Filtered out 0/5, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/5, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/5, 0.0 false (nan vs 0.1)
# condition 5 5
# Could not filter
# VNEW  1.512927523383017 m  6 xvar  35 count 0
# Linear filter...
# Filtered out 0/6, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/6, 0.0 false (nan vs 0.1)
# condition 6 6
# Could not filter
# VNEW  1.5689988086248774 m  6 xvar  35 count 0
# Linear filter...
# Filtered out 0/6, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/6, 0.0 false (nan vs 0.1)
# condition 6 6
# Could not filter
# VNEW  0.6244311679888742 m  6 xvar  35 count 0
# Linear filter...
# Filtered out 0/6, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/6, 0.0 false (nan vs 0.1)
# condition 6 6
# Could not filter
# VNEW  2.064799082344426 m  6 xvar  35 count 1
# Linear filter...
# Filtered out 0/6, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/6, 0.0 false (nan vs 0.1)
# condition 6 6
# Could not filter
# VNEW  2.0068182340825698 m  6 xvar  35 count 1
# Linear filter...
# Filtered out 0/6, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/6, 0.0 false (nan vs 0.1)
# condition 6 6
# Could not filter
# VNEW  1.613250439662682 m  6 xvar  35 count 1
# Linear filter...
# Filtered out 0/6, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/6, 0.0 false (nan vs 0.1)
# condition 6 6
# Could not filter
# VNEW  1.7866966160065265 m  6 xvar  35 count 1
# Linear filter...
# Filtered out 0/5, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/5, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/5, 0.0 false (nan vs 0.1)
# condition 5 5
# Could not filter
# VNEW  1.4818935007016456 m  6 xvar  35 count 1
# Linear filter...
# Filtered out 0/6, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/6, 0.0 false (nan vs 0.1)
# condition 6 6
# Could not filter
# VNEW  1.960916333690072 m  6 xvar  35 count 1
# Linear filter...
# Filtered out 0/6, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/6, 0.0 false (nan vs 0.1)
# condition 6 6
# Could not filter
# VNEW  1.4292407716577311 m  6 xvar  35 count 1
# Linear filter...
# Filtered out 0/8, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/8, 0.0 false (nan vs 0.1)
# condition 8 8
# Could not filter
# VNEW  1.323708807207495 m  8 xvar  35 count 0
# Linear filter...
# Filtered out 0/8, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/8, 0.0 false (nan vs 0.1)
# condition 8 8
# Could not filter
# VNEW  1.689707665108407 m  8 xvar  35 count 0
# Linear filter...
# Filtered out 0/6, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/6, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/6, 0.0 false (nan vs 0.1)
# condition 6 6
# Could not filter
# VNEW  0.8101274961348852 m  8 xvar  35 count 0
# Linear filter...
# Filtered out 0/8, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/8, 0.0 false (nan vs 0.1)
# condition 8 8
# Could not filter
# VNEW  0.31694808525721035 m  8 xvar  35 count 1
# Linear filter...
# Filtered out 0/8, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/8, 0.0 false (nan vs 0.1)
# condition 8 8
# Could not filter
# VNEW  1.262711775082513 m  8 xvar  35 count 2
# Linear filter...
# Filtered out 0/8, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/8, 0.0 false (nan vs 0.1)
# condition 8 8
# Could not filter
# VNEW  1.3014668236065023 m  8 xvar  35 count 2
# Linear filter...
# Filtered out 0/8, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/8, 0.0 false (nan vs 0.1)
# condition 8 8
# Could not filter
# VNEW  1.7991618074715188 m  8 xvar  35 count 2
# Linear filter...
# Filtered out 0/8, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/8, 0.0 false (nan vs 0.1)
# condition 8 8
# Could not filter
# VNEW  1.3283137639028773 m  8 xvar  35 count 2
# Linear filter...
# Filtered out 0/8, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/8, 0.0 false (nan vs 0.1)
# condition 8 8
# Could not filter
# VNEW  2.079440399069523 m  8 xvar  35 count 2
# Linear filter...
# Filtered out 0/8, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/8, 0.0 false (nan vs 0.1)
# condition 8 8
# Could not filter
# VNEW  1.2900818838183616 m  8 xvar  35 count 2
# Linear filter...
# Filtered out 0/10, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/10, 0.0 false (nan vs 0.1)
# condition 10 10
# Could not filter
# VNEW  0.3541855810944722 m  10 xvar  35 count 0
# Linear filter...
# Filtered out 0/10, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/10, 0.0 false (nan vs 0.1)
# condition 10 10
# Could not filter
# VNEW  1.4902775285455432 m  10 xvar  35 count 1
# Linear filter...
# Filtered out 0/9, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/9, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/9, 0.0 false (nan vs 0.1)
# condition 9 9
# Could not filter
# VNEW  0.6182332430224973 m  10 xvar  35 count 1
# Linear filter...
# Filtered out 0/10, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/10, 0.0 false (nan vs 0.1)
# condition 10 10
# Could not filter
# VNEW  0.5049870750021664 m  10 xvar  35 count 2
# Linear filter...
# Filtered out 0/10, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/10, 0.0 false (nan vs 0.1)
# condition 10 10
# Could not filter
# VNEW  1.3486883958788851 m  10 xvar  35 count 3
# Linear filter...
# Filtered out 0/10, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/10, 0.0 false (nan vs 0.1)
# condition 10 10
# Could not filter
# VNEW  1.2492027190273034 m  10 xvar  35 count 3
# Linear filter...
# Filtered out 0/9, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/9, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/9, 0.0 false (nan vs 0.1)
# condition 9 9
# Could not filter
# VNEW  1.2455083783707979 m  10 xvar  35 count 3
# Linear filter...
# Filtered out 0/10, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/10, 0.0 false (nan vs 0.1)
# condition 10 10
# Could not filter
# VNEW  1.7598581037393786 m  10 xvar  35 count 3
# Linear filter...
# Filtered out 0/10, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/10, 0.0 false (nan vs 0.1)
# condition 10 10
# Could not filter
# ...
# Filtered out 0/4, 0.0 false (nan vs 0.1)
# condition 4 4
# Could not filter
# VNEW  1.8249069565502605 m  4 xvar  5 count 0
# Linear filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# condition 2 2
# Could not filter
# VNEW  2.1880886571169933 m  4 xvar  5 count 0
# Linear filter...
# Filtered out 0/4, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/4, 0.0 false (nan vs 0.1)
# condition 4 4
# Could not filter
# VNEW  0.8023828923652548 m  4 xvar  5 count 0
# Linear filter...
# Filtered out 0/4, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/4, 0.0 false (nan vs 0.1)
# condition 4 4
# Could not filter
# VNEW  0.7313007247712711 m  4 xvar  5 count 1
# Linear filter...
# Filtered out 0/3, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/3, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/3, 0.0 false (nan vs 0.1)
# condition 3 3
# Could not filter
# VNEW  1.74334521355353 m  4 xvar  5 count 2
# Linear filter...
# Filtered out 0/4, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/4, 0.0 false (nan vs 0.1)
# condition 4 4
# Could not filter
# VNEW  1.1516055661887925 m  4 xvar  5 count 2
# Linear filter...
# Filtered out 0/6, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/6, 0.0 false (nan vs 0.1)
# condition 6 6
# Could not filter
# VNEW  0.5193405660308416 m  6 xvar  5 count 0
# Linear filter...
# Filtered out 0/6, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/6, 0.0 false (nan vs 0.1)
# condition 6 6
# Could not filter
# VNEW  0.33678425854523913 m  6 xvar  5 count 1
# Linear filter...
# Filtered out 0/6, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/6, 0.0 false (nan vs 0.1)
# condition 6 6
# Could not filter
# VNEW  1.1623205077810623 m  6 xvar  5 count 2
# Linear filter...
# Filtered out 0/6, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/6, 0.0 false (nan vs 0.1)
# condition 6 6
# Could not filter
# VNEW  0.753811185249648 m  6 xvar  5 count 3
# Linear filter...
# Filtered out 0/5, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/5, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/5, 0.0 false (nan vs 0.1)
# condition 5 5
# Could not filter
# VNEW  0.9820907105306186 m  6 xvar  5 count 4
# Linear filter...
# Filtered out 0/6, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/6, 0.0 false (nan vs 0.1)
# condition 6 6
# Could not filter
# VNEW  1.1792676074380717 m  6 xvar  5 count 5
# Linear filter...
# Filtered out 0/6, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/6, 0.0 false (nan vs 0.1)
# condition 6 6
# Could not filter
# VNEW  1.3532644718568696 m  6 xvar  5 count 6
# Linear filter...
# Filtered out 0/6, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/6, 0.0 false (nan vs 0.1)
# condition 6 6
# Could not filter
# VNEW  1.5129794400971772 m  6 xvar  5 count 6
# Linear filter...
# Filtered out 0/6, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/6, 0.0 false (nan vs 0.1)
# condition 6 6
# Could not filter
# VNEW  1.4080209157301127 m  6 xvar  5 count 6
# Linear filter...
# Filtered out 0/6, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/6, 0.0 false (nan vs 0.1)
# condition 6 6
# Could not filter
# VNEW  0.45850459533292387 m  6 xvar  5 count 6
# Linear filter...
# Filtered out 0/8, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/8, 0.0 false (nan vs 0.1)
# condition 8 8
# Could not filter
# VNEW  0.5731423161406394 m  8 xvar  5 count 0
# Linear filter...
# Filtered out 0/8, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/8, 0.0 false (nan vs 0.1)
# condition 8 8
# Could not filter
# VNEW  1.3939828317009402 m  8 xvar  5 count 1
# Linear filter...
# Filtered out 0/8, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/8, 0.0 false (nan vs 0.1)
# condition 8 8
# Could not filter
# VNEW  1.3436312549963663 m  8 xvar  5 count 1
# Linear filter...
# Filtered out 0/7, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/7, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/7, 0.0 false (nan vs 0.1)
# condition 7 7
# Could not filter
# VNEW  1.0119234212473984 m  8 xvar  5 count 1
# Linear filter...
# Filtered out 0/8, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/8, 0.0 false (nan vs 0.1)
# condition 8 8
# Could not filter
# VNEW  0.7165557218794962 m  8 xvar  5 count 2
# Linear filter...
# Filtered out 0/8, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/8, 0.0 false (nan vs 0.1)
# condition 8 8
# Could not filter
# VNEW  0.5091773197388026 m  8 xvar  5 count 3
# Linear filter...
# Filtered out 0/8, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/8, 0.0 false (nan vs 0.1)
# condition 8 8
# Could not filter
# VNEW  0.2844159561154442 m  8 xvar  5 count 4
# Linear filter...
# Filtered out 0/7, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/7, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/7, 0.0 false (nan vs 0.1)
# condition 7 7
# Could not filter
# VNEW  0.6000433796517309 m  8 xvar  5 count 5
# Linear filter...
# Filtered out 0/8, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/8, 0.0 false (nan vs 0.1)
# condition 8 8
# Could not filter
# VNEW  0.5297348003740797 m  8 xvar  5 count 6
# Linear filter...
# Filtered out 0/8, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/8, 0.0 false (nan vs 0.1)
# condition 8 8
# Could not filter
# VNEW  1.225221637135065 m  8 xvar  5 count 7
# Linear filter...
# Filtered out 0/10, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/10, 0.0 false (nan vs 0.1)
# condition 10 10
# Could not filter
# VNEW  1.2244624273178137 m  10 xvar  5 count 0
# Linear filter...
# Filtered out 0/10, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/10, 0.0 false (nan vs 0.1)
# condition 10 10
# Could not filter
# VNEW  0.4492047395687991 m  10 xvar  5 count 0
# Linear filter...
# Filtered out 0/10, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/10, 0.0 false (nan vs 0.1)
# condition 10 10
# Could not filter
# VNEW  0.45448082480945406 m  10 xvar  5 count 1
# Linear filter...
# Filtered out 0/9, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/9, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/9, 0.0 false (nan vs 0.1)
# condition 9 9
# Could not filter
# VNEW  0.33907095253648634 m  10 xvar  5 count 2
# Linear filter...
# Filtered out 0/10, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/10, 0.0 false (nan vs 0.1)
# condition 10 10
# Could not filter
# VNEW  0.6539087690520179 m  10 xvar  5 count 3
# Linear filter...
# Filtered out 0/10, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/10, 0.0 false (nan vs 0.1)
# condition 10 10
# Could not filter
# VNEW  0.3809796880060701 m  10 xvar  5 count 4
# Linear filter...
# Filtered out 0/10, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/10, 0.0 false (nan vs 0.1)
# condition 10 10
# Could not filter
# VNEW  0.2781655789342713 m  10 xvar  5 count 5
# Linear filter...
# Filtered out 0/10, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/10, 0.0 false (nan vs 0.1)
# condition 10 10
# Could not filter
# VNEW  0.3199048089684389 m  10 xvar  5 count 6
# Linear filter...
# Filtered out 0/10, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/10, 0.0 false (nan vs 0.1)
# condition 10 10
# Could not filter
# VNEW  0.44341269721688387 m  10 xvar  5 count 7
# Linear filter...
# Filtered out 0/9, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/9, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/9, 0.0 false (nan vs 0.1)
# condition 9 9
# Could not filter
# VNEW  0.4521344416392279 m  10 xvar  5 count 8
# Linear filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# condition 2 2
# Could not filter
# VNEW  2.4279096456026403 m  2 xvar  15 count 0
# Linear filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# condition 2 2
# Could not filter
# VNEW  2.1731898025948326 m  2 xvar  15 count 0
# Linear filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# condition 2 2
# Could not filter
# VNEW  3.2172586677803325 m  2 xvar  15 count 0
# Linear filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# condition 2 2
# Could not filter
# VNEW  3.169426181653611 m  2 xvar  15 count 0
# Linear filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# condition 2 2
# Could not filter
# VNEW  2.952300950016857 m  2 xvar  15 count 0
# Linear filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# condition 2 2
# Could not filter
# VNEW  2.9559230152090743 m  2 xvar  15 count 0
# Linear filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# condition 2 2
# Could not filter
# VNEW  2.913054447076637 m  2 xvar  15 count 0
# Linear filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# condition 2 2
# Could not filter
# VNEW  2.978152091529323 m  2 xvar  15 count 0
# Linear filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# condition 2 2
# Could not filter
# VNEW  3.4120711338082708 m  2 xvar  15 count 0
# Linear filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# condition 2 2
# Could not filter
# VNEW  2.88532467313131 m  2 xvar  15 count 0
# Linear filter...
# Filtered out 0/4, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/4, 0.0 false (nan vs 0.1)
# condition 4 4
# Could not filter
# VNEW  1.8050579504567061 m  4 xvar  15 count 0
# Linear filter...
# Filtered out 0/4, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/4, 0.0 false (nan vs 0.1)
# condition 4 4
# Could not filter
# VNEW  1.908783686742927 m  4 xvar  15 count 0
# Linear filter...
# Filtered out 0/4, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/4, 0.0 false (nan vs 0.1)
# condition 4 4
# Could not filter
# VNEW  2.015416274850532 m  4 xvar  15 count 0
# Linear filter...
# Filtered out 0/4, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/4, 0.0 false (nan vs 0.1)
# condition 4 4
# Could not filter
# VNEW  1.5603811918702988 m  4 xvar  15 count 0
# Linear filter...
# Filtered out 0/4, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/4, 0.0 false (nan vs 0.1)
# condition 4 4
# Could not filter
# VNEW  1.5595505813001356 m  4 xvar  15 count 0
# Linear filter...
# Filtered out 0/4, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/4, 0.0 false (nan vs 0.1)
# condition 4 4
# Could not filter
# VNEW  1.5666415970515624 m  4 xvar  15 count 0
# Linear filter...
# Filtered out 0/3, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/3, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/3, 0.0 false (nan vs 0.1)
# condition 3 3
# Could not filter
# VNEW  0.4357453611065337 m  4 xvar  15 count 0
# Linear filter...
# Filtered out 0/4, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/4, 0.0 false (nan vs 0.1)
# condition 4 4
# Could not filter
# VNEW  2.138661473230806 m  4 xvar  15 count 1
# Linear filter...
# Filtered out 0/4, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/4, 0.0 false (nan vs 0.1)
# condition 4 4
# Could not filter
# VNEW  1.7033208939945406 m  4 xvar  15 count 1
# Linear filter...
# Filtered out 0/4, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/4, 0.0 false (nan vs 0.1)
# condition 4 4
# Could not filter
# VNEW  1.8102275639431424 m  4 xvar  15 count 1
# Linear filter...
# Filtered out 0/6, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/6, 0.0 false (nan vs 0.1)
# condition 6 6
# Could not filter
# VNEW  1.379136316912025 m  6 xvar  15 count 0
# Linear filter...
# Filtered out 0/6, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/6, 0.0 false (nan vs 0.1)
# condition 6 6
# Could not filter
# VNEW  1.3554542095543012 m  6 xvar  15 count 0
# Linear filter...
# Filtered out 0/6, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/6, 0.0 false (nan vs 0.1)
# condition 6 6
# Could not filter
# VNEW  1.4848472659282688 m  6 xvar  15 count 0
# Linear filter...
# Filtered out 0/6, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/6, 0.0 false (nan vs 0.1)
# condition 6 6
# Could not filter
# VNEW  1.2930682516903556 m  6 xvar  15 count 0
# Linear filter...
# Filtered out 0/6, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/6, 0.0 false (nan vs 0.1)
# condition 6 6
# Could not filter
# VNEW  0.6280053091051261 m  6 xvar  15 count 0
# Linear filter...
# Filtered out 0/6, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/6, 0.0 false (nan vs 0.1)
# condition 6 6
# Could not filter
# VNEW  1.4508737172651351 m  6 xvar  15 count 1
# Linear filter...
# Filtered out 0/5, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/5, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/5, 0.0 false (nan vs 0.1)
# condition 5 5
# Could not filter
# VNEW  1.3542113607417383 m  6 xvar  15 count 1
# Linear filter...
# Filtered out 0/6, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/6, 0.0 false (nan vs 0.1)
# condition 6 6
# Could not filter
# VNEW  1.57536518657067 m  6 xvar  15 count 1
# Linear filter...
# Filtered out 0/6, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/6, 0.0 false (nan vs 0.1)
# condition 6 6
# Could not filter
# VNEW  1.2194653600743706 m  6 xvar  15 count 1
# Linear filter...
# Filtered out 0/6, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/6, 0.0 false (nan vs 0.1)
# condition 6 6
# Could not filter
# VNEW  1.772804662756164 m  6 xvar  15 count 1
# Linear filter...
# Filtered out 0/8, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/8, 0.0 false (nan vs 0.1)
# condition 8 8
# Could not filter
# VNEW  0.6452661542677689 m  8 xvar  15 count 0
# Linear filter...
# Filtered out 0/7, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/7, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/7, 0.0 false (nan vs 0.1)
# condition 7 7
# Could not filter
# VNEW  1.411569769689697 m  8 xvar  15 count 1
# Linear filter...
# Filtered out 0/7, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/7, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/7, 0.0 false (nan vs 0.1)
# condition 7 7
# Could not filter
# VNEW  1.503222341277773 m  8 xvar  15 count 1
# Linear filter...
# Filtered out 0/8, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/8, 0.0 false (nan vs 0.1)
# condition 8 8
# Could not filter
# VNEW  1.452506605386165 m  8 xvar  15 count 1
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-14-9cd12dba6cab> in <module>
#      17
#      18 plot_m_loss = rl.plot(model, params, err, keys)
# ---> 19 plot_m_loss.setdata('d', d_bounds, trials, ylims, y_is_m = True, mrange = (2,2))
#
# ~/GitHub/robust_sparse_mean_estimation/robustlib.py in setdata(self, xvar_name, bounds, trials, ylims, y_is_m, mrange)
#     487     def setdata(self, xvar_name, bounds, trials, ylims, y_is_m = False, mrange = []):
#     488         Runs_l_samples = RunCollection(self.get_dataxy, (xvar_name, bounds, y_is_m, mrange))
# --> 489         Runs_l_samples.run(trials)
#     490         self.Run = Runs_l_samples
#     491
#
# ~/GitHub/robust_sparse_mean_estimation/robustlib.py in run(self, trials)
#      16     def run(self, trials):
#      17         for i in range(trials):
# ---> 18             self.runs.append(self.func(*self.inp))
#      19
#      20
#
# ~/GitHub/robust_sparse_mean_estimation/robustlib.py in get_dataxy(self, xvar_name, bounds, y_is_m, mrange)
#     448
#     449                             self.params.m = samp
# --> 450                             inp, S, indicator, tm = self.model.generate(self.params)
#     451
#     452                             func = f(inp)
#
# ~/GitHub/robust_sparse_mean_estimation/robustlib.py in generate(self, params)
#      70         cov = 2*np.identity(d) - np.diag(tm)
#      71
# ---> 72         G = np.random.randn(m, d) + tm
#      73         G2 = np.random.multivariate_normal(np.zeros(d), cov, (m,))
#      74         G1 = np.random.randn(m, d) + fm
#
# KeyboardInterrupt:

# %%
plot_m_loss.plotxy('d', d_bounds, (0,100))
# Out:
# <style>
#
# </style>
#
# <div id="fig_el53223348089055688487287476"></div>
# <script>
# function mpld3_load_lib(url, callback){
#   var s = document.createElement('script');
#   s.src = url;
#   s.async = true;
#   s.onreadystatechange = s.onload = callback;
#   s.onerror = function(){console.warn("failed to load library " + url);};
#   document.getElementsByTagName("head")[0].appendChild(s);
# }
#
# if(typeof(mpld3) !== "undefined" && mpld3._mpld3IsLoaded){
#    // already loaded: just create the figure
#    !function(mpld3){
#
#        mpld3.draw_figure("fig_el53223348089055688487287476", {"width": 432.0, "height": 288.0, "axes": [], "data": {}, "id": "el5322334808905568", "plugins": [{"type": "reset"}, {"type": "zoom", "button": true, "enabled": false}, {"type": "boxzoom", "button": true, "enabled": false}]});
#    }(mpld3);
# }else if(typeof define === "function" && define.amd){
#    // require.js is available: use it to load d3/mpld3
#    require.config({paths: {d3: "https://mpld3.github.io/js/d3.v3.min"}});
#    require(["d3"], function(d3){
#       window.d3 = d3;
#       mpld3_load_lib("https://mpld3.github.io/js/mpld3.v0.3.1.dev1.js", function(){
#
#          mpld3.draw_figure("fig_el53223348089055688487287476", {"width": 432.0, "height": 288.0, "axes": [], "data": {}, "id": "el5322334808905568", "plugins": [{"type": "reset"}, {"type": "zoom", "button": true, "enabled": false}, {"type": "boxzoom", "button": true, "enabled": false}]});
#       });
#     });
# }else{
#     // require.js not available: dynamically load d3 & mpld3
#     mpld3_load_lib("https://mpld3.github.io/js/d3.v3.min.js", function(){
#          mpld3_load_lib("https://mpld3.github.io/js/mpld3.v0.3.1.dev1.js", function(){
#
#                  mpld3.draw_figure("fig_el53223348089055688487287476", {"width": 432.0, "height": 288.0, "axes": [], "data": {}, "id": "el5322334808905568", "plugins": [{"type": "reset"}, {"type": "zoom", "button": true, "enabled": false}, {"type": "boxzoom", "button": true, "enabled": false}]});
#             })
#          });
# }
# </script>

# %%
"Loss vs eps"

il.reload(rl)

trials = 10
d, k, m = 100, 1, 1000
eps_bounds = (0, 0.5, 0.01)
# model = rl.DenseNoiseModel(-100)

model = rl.TailFilpModel()
keys = [rl.Oracle]
model_params = rl.Params(d=d, k=k, m=m)
ylims = (0, 1)

def err(a,b): return LA.norm(a-b)

plot_m_loss = rl.plot(model, model_params, err, keys)
plot_m_loss.setdata('eps', eps_bounds, trials, ylims)

# %%
plot_m_loss.plotxy('eps', eps_bounds, (0,1))
# Out:
# <style>
#
# </style>
#
# <div id="fig_el56517348300118645319041774"></div>
# <script>
# function mpld3_load_lib(url, callback){
#   var s = document.createElement('script');
#   s.src = url;
#   s.async = true;
#   s.onreadystatechange = s.onload = callback;
#   s.onerror = function(){console.warn("failed to load library " + url);};
#   document.getElementsByTagName("head")[0].appendChild(s);
# }
#
# if(typeof(mpld3) !== "undefined" && mpld3._mpld3IsLoaded){
#    // already loaded: just create the figure
#    !function(mpld3){
#
#        mpld3.draw_figure("fig_el56517348300118645319041774", {"width": 432.0, "height": 288.0, "axes": [], "data": {}, "id": "el5651734830011864", "plugins": [{"type": "reset"}, {"type": "zoom", "button": true, "enabled": false}, {"type": "boxzoom", "button": true, "enabled": false}]});
#    }(mpld3);
# }else if(typeof define === "function" && define.amd){
#    // require.js is available: use it to load d3/mpld3
#    require.config({paths: {d3: "https://mpld3.github.io/js/d3.v3.min"}});
#    require(["d3"], function(d3){
#       window.d3 = d3;
#       mpld3_load_lib("https://mpld3.github.io/js/mpld3.v0.3.1.dev1.js", function(){
#
#          mpld3.draw_figure("fig_el56517348300118645319041774", {"width": 432.0, "height": 288.0, "axes": [], "data": {}, "id": "el5651734830011864", "plugins": [{"type": "reset"}, {"type": "zoom", "button": true, "enabled": false}, {"type": "boxzoom", "button": true, "enabled": false}]});
#       });
#     });
# }else{
#     // require.js not available: dynamically load d3 & mpld3
#     mpld3_load_lib("https://mpld3.github.io/js/d3.v3.min.js", function(){
#          mpld3_load_lib("https://mpld3.github.io/js/mpld3.v0.3.1.dev1.js", function(){
#
#                  mpld3.draw_figure("fig_el56517348300118645319041774", {"width": 432.0, "height": 288.0, "axes": [], "data": {}, "id": "el5651734830011864", "plugins": [{"type": "reset"}, {"type": "zoom", "button": true, "enabled": false}, {"type": "boxzoom", "button": true, "enabled": false}]});
#             })
#          });
# }
# </script>

# %%
"Loss vs sparsity"
il.reload(rl)

trials = 5
d, eps, m = 1000, 0.1, 20000
k_bounds = (50, 200, 25)

# model = rl.DenseNoiseModel(-2)
model = rl.BimodalModel()

keys = [rl.RME_sp, rl.NP_sp, rl.RME, rl.RME_sp_L, rl.ransacGaussianMean]
model_params = rl.Params(d = d, eps = eps, m = m)
ylims = (0, 1)

def err(a,b): return LA.norm(a-b)

plot_m_loss = rl.plot(model, model_params, err, keys)
plot_m_loss.setdata('k', k_bounds, trials, ylims)
# Out:
# Linear filter...
# Filtered out 0/19982, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/19982, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 1030/19982, 0.0 false (0.00 vs 0.1)
# condition 18952 19982
# Linear filter...
# Filtered out 0/18952, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 913/18952, 0.0 false (0.00 vs 0.1)
# condition 18039 18952
# Quadratic filter...
# Filtered out 0/18039, 0.0 false (nan vs 0.1)
# condition 18039 18039
# Could not filter
# Linear filter...
# Filtered out 1122/19982, 114.0 false (0.10 vs 0.1)
# Linear filter...
# Filtered out 291/18860, 155.0 false (0.53 vs 0.1)
# Linear filter...
# Filtered out 278/18569, 157.0 false (0.56 vs 0.1)
# Linear filter...
# Filtered out 240/18291, 148.0 false (0.62 vs 0.1)
# Linear filter...
# Filtered out 204/18051, 122.0 false (0.60 vs 0.1)
# Linear filter...
# Filtered out 179/17847, 102.0 false (0.57 vs 0.1)
# Linear filter...
# Filtered out 191/17668, 128.0 false (0.67 vs 0.1)
# Linear filter...
# Filtered out 159/17477, 116.0 false (0.73 vs 0.1)
# Linear filter...
# Filtered out 166/17318, 113.0 false (0.68 vs 0.1)
# Linear filter...
# Filtered out 172/17152, 132.0 false (0.77 vs 0.1)
# Linear filter...
# Filtered out 104/16980, 83.0 false (0.80 vs 0.1)
# Linear filter...
# Filtered out 149/16876, 115.0 false (0.77 vs 0.1)
# Linear filter...
# Filtered out 112/16727, 85.0 false (0.76 vs 0.1)
# Linear filter...
# Filtered out 105/16615, 83.0 false (0.79 vs 0.1)
# Linear filter...
# Filtered out 81/16510, 64.0 false (0.79 vs 0.1)
# Linear filter...
# Filtered out 93/16429, 78.0 false (0.84 vs 0.1)
# Linear filter...
# Filtered out 61/16336, 56.0 false (0.92 vs 0.1)
# Linear filter...
# Filtered out 80/16275, 67.0 false (0.84 vs 0.1)
# Linear filter...
# Filtered out 71/16195, 59.0 false (0.83 vs 0.1)
# Linear filter...
# Filtered out 110/16124, 101.0 false (0.92 vs 0.1)
# Linear filter...
# Filtered out 79/16014, 66.0 false (0.84 vs 0.1)
# Linear filter...
# Filtered out 81/15935, 71.0 false (0.88 vs 0.1)
# Linear filter...
# Filtered out 74/15854, 69.0 false (0.93 vs 0.1)
# Linear filter...
# Filtered out 95/15780, 90.0 false (0.95 vs 0.1)
# Linear filter...
# Filtered out 84/15685, 78.0 false (0.93 vs 0.1)
# Linear filter...
# Filtered out 83/15601, 79.0 false (0.95 vs 0.1)
# Linear filter...
# Filtered out 84/15518, 78.0 false (0.93 vs 0.1)
# Linear filter...
# Filtered out 71/15434, 69.0 false (0.97 vs 0.1)
# Linear filter...
# Filtered out 80/15363, 73.0 false (0.91 vs 0.1)
# Linear filter...
# Filtered out 83/15283, 80.0 false (0.96 vs 0.1)
# Linear filter...
# Filtered out 64/15200, 62.0 false (0.97 vs 0.1)
# Linear filter...
# Filtered out 57/15136, 53.0 false (0.93 vs 0.1)
# Linear filter...
# Filtered out 81/15079, 78.0 false (0.96 vs 0.1)
# Linear filter...
# Filtered out 74/14998, 73.0 false (0.99 vs 0.1)
# Linear filter...
# Filtered out 37/14924, 36.0 false (0.97 vs 0.1)
# Linear filter...
# Filtered out 86/14887, 84.0 false (0.98 vs 0.1)
# Linear filter...
# Filtered out 77/14801, 76.0 false (0.99 vs 0.1)
# Linear filter...
# Filtered out 54/14724, 52.0 false (0.96 vs 0.1)
# Linear filter...
# Filtered out 44/14670, 44.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 46/14626, 46.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 81/14580, 79.0 false (0.98 vs 0.1)
# Linear filter...
# Filtered out 59/14499, 58.0 false (0.98 vs 0.1)
# Linear filter...
# Filtered out 30/14440, 30.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 95/14410, 94.0 false (0.99 vs 0.1)
# Linear filter...
# Filtered out 78/14315, 77.0 false (0.99 vs 0.1)
# Linear filter...
# Filtered out 43/14237, 43.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 26/14194, 26.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 89/14168, 88.0 false (0.99 vs 0.1)
# Linear filter...
# Filtered out 54/14079, 54.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 89/14025, 89.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 60/13936, 60.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 42/13876, 42.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 34/13834, 34.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 43/13800, 43.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 27/13757, 27.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 53/13730, 52.0 false (0.98 vs 0.1)
# Linear filter...
# Filtered out 59/13677, 59.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 54/13618, 53.0 false (0.98 vs 0.1)
# Linear filter...
# Filtered out 71/13564, 70.0 false (0.99 vs 0.1)
# Linear filter...
# Filtered out 20/13493, 20.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 61/13473, 61.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 35/13412, 34.0 false (0.97 vs 0.1)
# Linear filter...
# Filtered out 31/13377, 31.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 76/13346, 76.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 55/13270, 55.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 49/13215, 48.0 false (0.98 vs 0.1)
# Linear filter...
# Filtered out 88/13166, 88.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 38/13078, 37.0 false (0.97 vs 0.1)
# Linear filter...
# Filtered out 47/13040, 47.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 74/12993, 74.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 63/12919, 63.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 71/12856, 71.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 63/12785, 62.0 false (0.98 vs 0.1)
# Linear filter...
# Filtered out 22/12722, 22.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 52/12700, 52.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 58/12648, 58.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 34/12590, 34.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 41/12556, 41.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 68/12515, 68.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 74/12447, 74.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 71/12373, 71.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 91/12302, 91.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 83/12211, 83.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 79/12128, 79.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 65/12049, 64.0 false (0.98 vs 0.1)
# Linear filter...
# Filtered out 30/11984, 30.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 48/11954, 47.0 false (0.98 vs 0.1)
# Linear filter...
# Filtered out 64/11906, 64.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 71/11842, 71.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 54/11771, 54.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 73/11717, 73.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 34/11644, 34.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 58/11610, 58.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 66/11552, 66.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 97/11486, 97.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 85/11389, 85.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 41/11304, 41.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 58/11263, 58.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 41/11205, 41.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 23/11164, 23.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 77/11141, 77.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 68/11064, 68.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 27/10996, 27.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 71/10969, 71.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 86/10898, 86.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 39/10812, 39.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 74/10773, 74.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 79/10699, 79.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 81/10620, 81.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 96/10539, 96.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 64/10443, 64.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 64/10379, 64.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 44/10315, 44.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 58/10271, 58.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 110/10213, 110.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 109/10103, 109.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 82/9994, 82.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 69/9912, 69.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 80/9843, 80.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 79/9763, 79.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 93/9684, 93.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 106/9591, 106.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 63/9485, 63.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 99/9422, 99.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 92/9323, 92.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 110/9231, 110.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 100/9121, 100.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 61/9021, 61.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 117/8960, 117.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 88/8843, 88.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 117/8755, 117.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 96/8638, 96.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 135/8542, 135.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 106/8407, 106.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 93/8301, 93.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 93/8208, 93.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 72/8115, 72.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 93/8043, 93.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 87/7950, 87.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 138/7863, 138.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 75/7725, 75.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 81/7650, 81.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 97/7569, 97.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 123/7472, 123.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 93/7349, 93.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 137/7256, 137.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 129/7119, 129.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 152/6990, 152.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 187/6838, 187.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 145/6651, 145.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 152/6506, 152.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 156/6354, 156.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 130/6198, 130.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 136/6068, 136.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 149/5932, 149.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 156/5783, 156.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 167/5627, 167.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 191/5460, 191.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 194/5269, 194.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 165/5075, 165.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 161/4910, 161.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 198/4749, 198.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 198/4551, 198.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 196/4353, 196.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 201/4157, 201.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 187/3956, 187.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 256/3769, 256.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 231/3513, 231.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 201/3282, 201.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 264/3081, 264.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 261/2817, 261.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 248/2556, 248.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 250/2308, 250.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 257/2058, 257.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 268/1801, 268.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 246/1533, 246.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 253/1287, 253.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 238/1034, 238.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 229/796, 229.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 194/567, 194.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 156/373, 156.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 102/217, 102.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 0/115, 0.0 false (nan vs 0.1)
# Could not filter
# Linear filter...
# Filtered out 0/19982, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/19982, 0.0 false (nan vs 0.1)
# Could not filter
# ransacN 9991
# Linear filter...
# Filtered out 0/19974, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/19974, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 1006/19974, 0.0 false (0.00 vs 0.1)
# condition 18968 19974
# Linear filter...
# Filtered out 0/18968, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 928/18968, 0.0 false (0.00 vs 0.1)
# condition 18040 18968
# Quadratic filter...
# Filtered out 0/18040, 0.0 false (nan vs 0.1)
# condition 18040 18040
# Could not filter
# Linear filter...
# Filtered out 1133/19974, 124.0 false (0.11 vs 0.1)
# Linear filter...
# Filtered out 242/18841, 127.0 false (0.52 vs 0.1)
# Linear filter...
# Filtered out 251/18599, 145.0 false (0.58 vs 0.1)
# Linear filter...
# Filtered out 159/18348, 81.0 false (0.51 vs 0.1)
# Linear filter...
# Filtered out 202/18189, 127.0 false (0.63 vs 0.1)
# Linear filter...
# Filtered out 193/17987, 124.0 false (0.64 vs 0.1)
# Linear filter...
# Filtered out 176/17794, 114.0 false (0.65 vs 0.1)
# Linear filter...
# Filtered out 161/17618, 109.0 false (0.68 vs 0.1)
# Linear filter...
# Filtered out 170/17457, 114.0 false (0.67 vs 0.1)
# Linear filter...
# Filtered out 168/17287, 128.0 false (0.76 vs 0.1)
# Linear filter...
# Filtered out 112/17119, 82.0 false (0.73 vs 0.1)
# Linear filter...
# Filtered out 98/17007, 74.0 false (0.76 vs 0.1)
# Linear filter...
# Filtered out 107/16909, 88.0 false (0.82 vs 0.1)
# Linear filter...
# Filtered out 118/16802, 96.0 false (0.81 vs 0.1)
# Linear filter...
# Filtered out 119/16684, 90.0 false (0.76 vs 0.1)
# Linear filter...
# Filtered out 115/16565, 90.0 false (0.78 vs 0.1)
# Linear filter...
# Filtered out 105/16450, 88.0 false (0.84 vs 0.1)
# Linear filter...
# Filtered out 113/16345, 95.0 false (0.84 vs 0.1)
# Linear filter...
# Filtered out 73/16232, 62.0 false (0.85 vs 0.1)
# Linear filter...
# Filtered out 102/16159, 90.0 false (0.88 vs 0.1)
# Linear filter...
# Filtered out 67/16057, 53.0 false (0.79 vs 0.1)
# Linear filter...
# Filtered out 82/15990, 69.0 false (0.84 vs 0.1)
# Linear filter...
# Filtered out 43/15908, 39.0 false (0.91 vs 0.1)
# Linear filter...
# Filtered out 72/15865, 68.0 false (0.94 vs 0.1)
# Linear filter...
# Filtered out 52/15793, 48.0 false (0.92 vs 0.1)
# Linear filter...
# Filtered out 74/15741, 66.0 false (0.89 vs 0.1)
# Linear filter...
# Filtered out 104/15667, 100.0 false (0.96 vs 0.1)
# Linear filter...
# Filtered out 69/15563, 66.0 false (0.96 vs 0.1)
# Linear filter...
# Filtered out 64/15494, 59.0 false (0.92 vs 0.1)
# Linear filter...
# Filtered out 63/15430, 60.0 false (0.95 vs 0.1)
# Linear filter...
# Filtered out 79/15367, 73.0 false (0.92 vs 0.1)
# Linear filter...
# Filtered out 67/15288, 63.0 false (0.94 vs 0.1)
# Linear filter...
# Filtered out 80/15221, 79.0 false (0.99 vs 0.1)
# Linear filter...
# Filtered out 22/15141, 21.0 false (0.95 vs 0.1)
# Linear filter...
# Filtered out 54/15119, 52.0 false (0.96 vs 0.1)
# Linear filter...
# Filtered out 56/15065, 55.0 false (0.98 vs 0.1)
# Linear filter...
# Filtered out 69/15009, 67.0 false (0.97 vs 0.1)
# Linear filter...
# Filtered out 73/14940, 72.0 false (0.99 vs 0.1)
# Linear filter...
# Filtered out 78/14867, 76.0 false (0.97 vs 0.1)
# Linear filter...
# Filtered out 38/14789, 36.0 false (0.95 vs 0.1)
# Linear filter...
# Filtered out 58/14751, 57.0 false (0.98 vs 0.1)
# Linear filter...
# Filtered out 52/14693, 50.0 false (0.96 vs 0.1)
# Linear filter...
# Filtered out 66/14641, 65.0 false (0.98 vs 0.1)
# Linear filter...
# Filtered out 12/14575, 12.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 53/14563, 52.0 false (0.98 vs 0.1)
# Linear filter...
# Filtered out 44/14510, 42.0 false (0.95 vs 0.1)
# Linear filter...
# Filtered out 42/14466, 41.0 false (0.98 vs 0.1)
# Linear filter...
# Filtered out 61/14424, 60.0 false (0.98 vs 0.1)
# Linear filter...
# Filtered out 69/14363, 69.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 35/14294, 35.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 48/14259, 48.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 64/14211, 63.0 false (0.98 vs 0.1)
# Linear filter...
# Filtered out 32/14147, 32.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 36/14115, 34.0 false (0.94 vs 0.1)
# Linear filter...
# Filtered out 53/14079, 53.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 36/14026, 35.0 false (0.97 vs 0.1)
# Linear filter...
# Filtered out 28/13990, 27.0 false (0.96 vs 0.1)
# Linear filter...
# Filtered out 52/13962, 51.0 false (0.98 vs 0.1)
# Linear filter...
# Filtered out 47/13910, 46.0 false (0.98 vs 0.1)
# Linear filter...
# Filtered out 51/13863, 50.0 false (0.98 vs 0.1)
# Linear filter...
# Filtered out 30/13812, 30.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 53/13782, 53.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 59/13729, 59.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 72/13670, 72.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 72/13598, 71.0 false (0.99 vs 0.1)
# Linear filter...
# Filtered out 53/13526, 53.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 55/13473, 54.0 false (0.98 vs 0.1)
# Linear filter...
# Filtered out 70/13418, 70.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 56/13348, 56.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 25/13292, 25.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 55/13267, 55.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 106/13212, 106.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 46/13106, 46.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 82/13060, 82.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 58/12978, 58.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 62/12920, 62.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 70/12858, 70.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 56/12788, 56.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 43/12732, 43.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 28/12689, 28.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 84/12661, 83.0 false (0.99 vs 0.1)
# Linear filter...
# Filtered out 19/12577, 19.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 39/12558, 39.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 42/12519, 42.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 33/12477, 33.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 72/12444, 72.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 64/12372, 64.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 86/12308, 86.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 59/12222, 59.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 35/12163, 35.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 46/12128, 45.0 false (0.98 vs 0.1)
# Linear filter...
# Filtered out 48/12082, 48.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 86/12034, 86.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 67/11948, 67.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 52/11881, 52.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 68/11829, 68.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 46/11761, 46.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 56/11715, 56.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 66/11659, 66.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 86/11593, 86.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 57/11507, 57.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 78/11450, 78.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 56/11372, 56.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 64/11316, 64.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 84/11252, 84.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 95/11168, 95.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 108/11073, 108.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 71/10965, 71.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 56/10894, 56.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 97/10838, 97.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 48/10741, 48.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 92/10693, 92.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 97/10601, 97.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 55/10504, 55.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 87/10449, 87.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 31/10362, 31.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 89/10331, 89.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 82/10242, 82.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 73/10160, 73.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 88/10087, 88.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 110/9999, 110.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 100/9889, 100.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 100/9789, 100.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 106/9689, 106.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 51/9583, 51.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 54/9532, 54.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 100/9478, 100.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 95/9378, 95.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 126/9283, 126.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 34/9157, 34.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 111/9123, 111.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 46/9012, 46.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 87/8966, 87.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 130/8879, 130.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 101/8749, 101.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 92/8648, 92.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 103/8556, 103.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 115/8453, 115.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 127/8338, 127.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 85/8211, 85.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 75/8126, 75.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 92/8051, 92.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 113/7959, 113.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 122/7846, 122.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 68/7724, 68.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 123/7656, 123.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 83/7533, 83.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 150/7450, 150.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 96/7300, 96.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 95/7204, 95.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 133/7109, 133.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 101/6976, 101.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 108/6875, 108.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 160/6767, 160.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 133/6607, 133.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 151/6474, 151.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 157/6323, 157.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 135/6166, 135.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 156/6031, 156.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 172/5875, 172.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 160/5703, 160.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 165/5543, 165.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 168/5378, 168.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 204/5210, 204.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 162/5006, 162.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 188/4844, 188.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 206/4656, 206.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 182/4450, 182.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 182/4268, 182.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 168/4086, 168.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 186/3918, 186.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 190/3732, 190.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 217/3542, 217.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 223/3325, 223.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 253/3102, 253.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 247/2849, 247.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 275/2602, 275.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 243/2327, 243.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 287/2084, 287.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 269/1797, 269.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 253/1528, 253.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 264/1275, 264.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 237/1011, 237.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 209/774, 209.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 191/565, 191.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 163/374, 163.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 124/211, 124.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 0/87, 0.0 false (nan vs 0.1)
# Could not filter
# Linear filter...
# Filtered out 0/19974, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/19974, 0.0 false (nan vs 0.1)
# Could not filter
# ransacN 9987
# Linear filter...
# Filtered out 0/19989, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/19989, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 1003/19989, 0.0 false (0.00 vs 0.1)
# condition 18986 19989
# Linear filter...
# Filtered out 0/18986, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 885/18986, 0.0 false (0.00 vs 0.1)
# condition 18101 18986
# Linear filter...
# Filtered out 0/18101, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/18101, 0.0 false (nan vs 0.1)
# condition 18101 18101
# Could not filter
# Linear filter...
# Filtered out 1117/19989, 109.0 false (0.10 vs 0.1)
# Linear filter...
# Filtered out 248/18872, 138.0 false (0.56 vs 0.1)
# Linear filter...
# Filtered out 209/18624, 109.0 false (0.52 vs 0.1)
# Linear filter...
# Filtered out 184/18415, 101.0 false (0.55 vs 0.1)
# Linear filter...
# Filtered out 207/18231, 124.0 false (0.60 vs 0.1)
# Linear filter...
# Filtered out 154/18024, 100.0 false (0.65 vs 0.1)
# Linear filter...
# Filtered out 215/17870, 133.0 false (0.62 vs 0.1)
# Linear filter...
# Filtered out 154/17655, 106.0 false (0.69 vs 0.1)
# Linear filter...
# Filtered out 158/17501, 109.0 false (0.69 vs 0.1)
# Linear filter...
# Filtered out 141/17343, 96.0 false (0.68 vs 0.1)
# Linear filter...
# Filtered out 163/17202, 121.0 false (0.74 vs 0.1)
# Linear filter...
# Filtered out 120/17039, 90.0 false (0.75 vs 0.1)
# Linear filter...
# Filtered out 122/16919, 93.0 false (0.76 vs 0.1)
# Linear filter...
# Filtered out 122/16797, 104.0 false (0.85 vs 0.1)
# Linear filter...
# Filtered out 105/16675, 90.0 false (0.86 vs 0.1)
# Linear filter...
# Filtered out 114/16570, 96.0 false (0.84 vs 0.1)
# Linear filter...
# Filtered out 134/16456, 114.0 false (0.85 vs 0.1)
# Linear filter...
# Filtered out 84/16322, 61.0 false (0.73 vs 0.1)
# Linear filter...
# Filtered out 74/16238, 57.0 false (0.77 vs 0.1)
# Linear filter...
# Filtered out 91/16164, 81.0 false (0.89 vs 0.1)
# Linear filter...
# Filtered out 82/16073, 70.0 false (0.85 vs 0.1)
# Linear filter...
# Filtered out 72/15991, 67.0 false (0.93 vs 0.1)
# Linear filter...
# Filtered out 83/15919, 73.0 false (0.88 vs 0.1)
# Linear filter...
# Filtered out 107/15836, 96.0 false (0.90 vs 0.1)
# Linear filter...
# Filtered out 58/15729, 53.0 false (0.91 vs 0.1)
# Linear filter...
# Filtered out 103/15671, 99.0 false (0.96 vs 0.1)
# Linear filter...
# Filtered out 72/15568, 66.0 false (0.92 vs 0.1)
# Linear filter...
# Filtered out 69/15496, 64.0 false (0.93 vs 0.1)
# Linear filter...
# Filtered out 78/15427, 71.0 false (0.91 vs 0.1)
# Linear filter...
# Filtered out 38/15349, 37.0 false (0.97 vs 0.1)
# Linear filter...
# Filtered out 35/15311, 34.0 false (0.97 vs 0.1)
# Linear filter...
# Filtered out 70/15276, 65.0 false (0.93 vs 0.1)
# Linear filter...
# Filtered out 60/15206, 59.0 false (0.98 vs 0.1)
# Linear filter...
# Filtered out 63/15146, 58.0 false (0.92 vs 0.1)
# Linear filter...
# Filtered out 75/15083, 73.0 false (0.97 vs 0.1)
# Linear filter...
# Filtered out 89/15008, 87.0 false (0.98 vs 0.1)
# Linear filter...
# Filtered out 49/14919, 47.0 false (0.96 vs 0.1)
# Linear filter...
# Filtered out 87/14870, 83.0 false (0.95 vs 0.1)
# Linear filter...
# Filtered out 52/14783, 50.0 false (0.96 vs 0.1)
# Linear filter...
# Filtered out 46/14731, 46.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 70/14685, 70.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 57/14615, 54.0 false (0.95 vs 0.1)
# Linear filter...
# Filtered out 73/14558, 71.0 false (0.97 vs 0.1)
# Linear filter...
# Filtered out 33/14485, 32.0 false (0.97 vs 0.1)
# Linear filter...
# Filtered out 30/14452, 30.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 22/14422, 21.0 false (0.95 vs 0.1)
# Linear filter...
# Filtered out 43/14400, 42.0 false (0.98 vs 0.1)
# Linear filter...
# Filtered out 23/14357, 23.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 51/14334, 49.0 false (0.96 vs 0.1)
# Linear filter...
# Filtered out 33/14283, 33.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 53/14250, 53.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 9/14197, 9.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 64/14188, 62.0 false (0.97 vs 0.1)
# Linear filter...
# Filtered out 46/14124, 45.0 false (0.98 vs 0.1)
# Linear filter...
# Filtered out 74/14078, 74.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 52/14004, 52.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 53/13952, 53.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 46/13899, 46.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 37/13853, 37.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 78/13816, 78.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 70/13738, 70.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 49/13668, 49.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 66/13619, 66.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 73/13553, 73.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 50/13480, 50.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 65/13430, 65.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 74/13365, 74.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 58/13291, 58.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 42/13233, 41.0 false (0.98 vs 0.1)
# Linear filter...
# Filtered out 39/13191, 39.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 28/13152, 28.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 76/13124, 76.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 59/13048, 59.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 71/12989, 71.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 33/12918, 33.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 43/12885, 43.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 26/12842, 26.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 84/12816, 84.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 84/12732, 84.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 48/12648, 48.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 87/12600, 87.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 52/12513, 52.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 52/12461, 52.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 47/12409, 46.0 false (0.98 vs 0.1)
# Linear filter...
# Filtered out 51/12362, 51.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 64/12311, 64.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 45/12247, 45.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 22/12202, 22.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 60/12180, 60.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 79/12120, 79.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 34/12041, 34.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 98/12007, 98.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 50/11909, 50.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 67/11859, 67.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 81/11792, 81.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 72/11711, 72.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 60/11639, 60.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 76/11579, 76.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 68/11503, 68.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 77/11435, 77.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 50/11358, 50.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 63/11308, 63.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 92/11245, 92.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 130/11153, 130.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 50/11023, 50.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 60/10973, 60.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 77/10913, 77.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 66/10836, 66.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 96/10770, 96.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 41/10674, 41.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 69/10633, 69.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 78/10564, 78.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 39/10486, 39.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 77/10447, 77.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 70/10370, 70.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 45/10300, 45.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 99/10255, 99.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 61/10156, 61.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 67/10095, 67.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 78/10028, 78.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 81/9950, 81.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 102/9869, 102.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 107/9767, 107.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 57/9660, 57.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 105/9603, 105.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 98/9498, 98.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 87/9400, 87.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 123/9313, 123.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 73/9190, 73.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 116/9117, 116.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 114/9001, 114.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 107/8887, 107.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 94/8780, 94.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 86/8686, 86.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 115/8600, 115.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 89/8485, 89.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 55/8396, 55.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 100/8341, 100.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 89/8241, 89.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 123/8152, 123.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 116/8029, 116.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 90/7913, 90.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 104/7823, 104.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 142/7719, 142.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 98/7577, 98.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 100/7479, 100.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 106/7379, 106.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 126/7273, 126.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 151/7147, 151.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 124/6996, 124.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 154/6872, 154.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 171/6718, 171.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 115/6547, 115.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 129/6432, 129.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 190/6303, 190.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 105/6113, 105.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 173/6008, 173.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 146/5835, 146.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 135/5689, 135.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 187/5554, 187.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 140/5367, 140.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 123/5227, 123.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 197/5104, 197.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 186/4907, 186.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 207/4721, 207.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 167/4514, 167.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 181/4347, 181.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 166/4166, 166.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 221/4000, 221.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 205/3779, 205.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 204/3574, 204.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 228/3370, 228.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 248/3142, 248.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 259/2894, 259.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 248/2635, 248.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 274/2387, 274.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 252/2113, 252.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 244/1861, 244.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 263/1617, 263.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 282/1354, 282.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 251/1072, 251.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 224/821, 224.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 206/597, 206.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 147/391, 147.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 122/244, 122.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 73/122, 73.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 0/49, 0.0 false (nan vs 0.1)
# Could not filter
# Linear filter...
# Filtered out 0/19989, 0.0 false (nan vs 0.1)
# Linear filter...
# Filtered out 0/19989, 0.0 false (nan vs 0.1)
# Could not filter
# ransacN 9994
# Linear filter...
# Filtered out 325/19982, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/19657, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 675/19657, 0.0 false (0.00 vs 0.1)
# condition 18982 19657
# Linear filter...
# Filtered out 0/18982, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 694/18982, 0.0 false (0.00 vs 0.1)
# condition 18288 18982
# Linear filter...
# Filtered out 0/18288, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/18288, 0.0 false (nan vs 0.1)
# condition 18288 18288
# Could not filter
# Linear filter...
# Filtered out 1125/19982, 117.0 false (0.10 vs 0.1)
# Linear filter...
# Filtered out 239/18857, 126.0 false (0.53 vs 0.1)
# Linear filter...
# Filtered out 227/18618, 142.0 false (0.63 vs 0.1)
# Linear filter...
# Filtered out 207/18391, 130.0 false (0.63 vs 0.1)
# Linear filter...
# Filtered out 222/18184, 154.0 false (0.69 vs 0.1)
# Linear filter...
# Filtered out 123/17962, 71.0 false (0.58 vs 0.1)
# Linear filter...
# Filtered out 203/17839, 140.0 false (0.69 vs 0.1)
# Linear filter...
# Filtered out 155/17636, 103.0 false (0.66 vs 0.1)
# Linear filter...
# Filtered out 164/17481, 114.0 false (0.70 vs 0.1)
# Linear filter...
# Filtered out 163/17317, 113.0 false (0.69 vs 0.1)
# Linear filter...
# Filtered out 110/17154, 80.0 false (0.73 vs 0.1)
# Linear filter...
# Filtered out 134/17044, 106.0 false (0.79 vs 0.1)
# Linear filter...
# Filtered out 178/16910, 139.0 false (0.78 vs 0.1)
# Linear filter...
# Filtered out 104/16732, 84.0 false (0.81 vs 0.1)
# Linear filter...
# Filtered out 112/16628, 90.0 false (0.80 vs 0.1)
# Linear filter...
# Filtered out 110/16516, 85.0 false (0.77 vs 0.1)
# Linear filter...
# Filtered out 140/16406, 120.0 false (0.86 vs 0.1)
# Linear filter...
# Filtered out 134/16266, 106.0 false (0.79 vs 0.1)
# Linear filter...
# Filtered out 80/16132, 66.0 false (0.82 vs 0.1)
# Linear filter...
# Filtered out 88/16052, 78.0 false (0.89 vs 0.1)
# Linear filter...
# Filtered out 58/15964, 44.0 false (0.76 vs 0.1)
# Linear filter...
# Filtered out 93/15906, 83.0 false (0.89 vs 0.1)
# Linear filter...
# Filtered out 116/15813, 102.0 false (0.88 vs 0.1)
# Linear filter...
# Filtered out 81/15697, 73.0 false (0.90 vs 0.1)
# Linear filter...
# Filtered out 110/15616, 106.0 false (0.96 vs 0.1)
# Linear filter...
# Filtered out 61/15506, 54.0 false (0.89 vs 0.1)
# Linear filter...
# Filtered out 64/15445, 60.0 false (0.94 vs 0.1)
# Linear filter...
# Filtered out 57/15381, 50.0 false (0.88 vs 0.1)
# Linear filter...
# Filtered out 50/15324, 43.0 false (0.86 vs 0.1)
# Linear filter...
# Filtered out 59/15274, 56.0 false (0.95 vs 0.1)
# Linear filter...
# Filtered out 59/15215, 58.0 false (0.98 vs 0.1)
# Linear filter...
# Filtered out 41/15156, 39.0 false (0.95 vs 0.1)
# Linear filter...
# Filtered out 29/15115, 26.0 false (0.90 vs 0.1)
# Linear filter...
# Filtered out 54/15086, 51.0 false (0.94 vs 0.1)
# Linear filter...
# Filtered out 48/15032, 44.0 false (0.92 vs 0.1)
# Linear filter...
# Filtered out 61/14984, 58.0 false (0.95 vs 0.1)
# Linear filter...
# Filtered out 63/14923, 60.0 false (0.95 vs 0.1)
# Linear filter...
# Filtered out 73/14860, 70.0 false (0.96 vs 0.1)
# Linear filter...
# Filtered out 91/14787, 88.0 false (0.97 vs 0.1)
# Linear filter...
# Filtered out 81/14696, 78.0 false (0.96 vs 0.1)
# Linear filter...
# Filtered out 71/14615, 71.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 54/14544, 53.0 false (0.98 vs 0.1)
# Linear filter...
# Filtered out 52/14490, 51.0 false (0.98 vs 0.1)
# Linear filter...
# Filtered out 48/14438, 47.0 false (0.98 vs 0.1)
# Linear filter...
# Filtered out 55/14390, 54.0 false (0.98 vs 0.1)
# Linear filter...
# Filtered out 59/14335, 57.0 false (0.97 vs 0.1)
# Linear filter...
# Filtered out 52/14276, 50.0 false (0.96 vs 0.1)
# Linear filter...
# Filtered out 56/14224, 54.0 false (0.96 vs 0.1)
# Linear filter...
# Filtered out 26/14168, 25.0 false (0.96 vs 0.1)
# Linear filter...
# Filtered out 33/14142, 33.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 78/14109, 76.0 false (0.97 vs 0.1)
# Linear filter...
# Filtered out 27/14031, 27.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 89/14004, 89.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 54/13915, 53.0 false (0.98 vs 0.1)
# Linear filter...
# Filtered out 81/13861, 80.0 false (0.99 vs 0.1)
# Linear filter...
# Filtered out 63/13780, 63.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 35/13717, 35.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 46/13682, 46.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 41/13636, 40.0 false (0.98 vs 0.1)
# Linear filter...
# Filtered out 45/13595, 44.0 false (0.98 vs 0.1)
# Linear filter...
# Filtered out 111/13550, 111.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 47/13439, 47.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 83/13392, 83.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 67/13309, 67.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 35/13242, 35.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 19/13207, 19.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 90/13188, 90.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 72/13098, 72.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 70/13026, 70.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 44/12956, 43.0 false (0.98 vs 0.1)
# Linear filter...
# Filtered out 62/12912, 62.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 40/12850, 40.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 34/12810, 34.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 65/12776, 65.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 45/12711, 45.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 57/12666, 56.0 false (0.98 vs 0.1)
# Linear filter...
# Filtered out 26/12609, 26.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 32/12583, 32.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 53/12551, 53.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 70/12498, 70.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 86/12428, 86.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 65/12342, 65.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 55/12277, 55.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 31/12222, 31.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 36/12191, 36.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 84/12155, 84.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 52/12071, 52.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 48/12019, 48.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 48/11971, 48.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 56/11923, 56.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 26/11867, 26.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 76/11841, 76.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 51/11765, 51.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 49/11714, 49.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 76/11665, 75.0 false (0.99 vs 0.1)
# Linear filter...
# Filtered out 43/11589, 43.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 84/11546, 84.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 57/11462, 56.0 false (0.98 vs 0.1)
# Linear filter...
# Filtered out 78/11405, 77.0 false (0.99 vs 0.1)
# Linear filter...
# Filtered out 44/11327, 44.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 81/11283, 81.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 57/11202, 57.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 58/11145, 58.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 47/11087, 47.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 94/11040, 94.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 67/10946, 67.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 57/10879, 57.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 100/10822, 100.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 59/10722, 59.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 56/10663, 56.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 72/10607, 72.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 87/10535, 87.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 82/10448, 82.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 73/10366, 73.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 47/10293, 47.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 57/10246, 57.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 75/10189, 75.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 69/10114, 69.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 78/10045, 78.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 95/9967, 95.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 81/9872, 81.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 92/9791, 92.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 95/9699, 95.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 70/9604, 70.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 59/9534, 59.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 100/9475, 100.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 93/9375, 93.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 66/9282, 66.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 102/9216, 102.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 105/9114, 105.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 110/9009, 110.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 112/8899, 112.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 93/8787, 93.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 111/8694, 111.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 99/8583, 99.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 85/8484, 85.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 36/8399, 36.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 129/8363, 129.0 false (1.00 vs 0.1)
# Linear filter...
# ...
# Filtered out 96/8867, 96.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 67/8771, 67.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 61/8704, 60.0 false (0.98 vs 0.1)
# Linear filter...
# Filtered out 59/8643, 59.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 122/8584, 122.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 93/8462, 93.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 85/8369, 85.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 79/8284, 79.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 81/8205, 81.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 91/8124, 91.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 96/8033, 96.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 121/7937, 121.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 111/7816, 111.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 111/7705, 111.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 108/7594, 108.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 127/7486, 127.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 99/7359, 99.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 137/7260, 137.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 155/7123, 155.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 95/6968, 95.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 160/6873, 160.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 168/6713, 168.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 101/6545, 101.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 110/6444, 110.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 130/6334, 130.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 162/6204, 162.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 161/6042, 161.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 146/5881, 146.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 124/5735, 124.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 140/5611, 140.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 126/5471, 126.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 174/5345, 174.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 162/5171, 162.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 157/5009, 157.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 186/4852, 186.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 199/4666, 199.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 179/4467, 179.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 197/4288, 197.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 201/4091, 201.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 234/3890, 234.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 249/3656, 249.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 214/3407, 214.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 186/3193, 186.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 222/3007, 222.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 258/2785, 258.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 233/2527, 233.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 255/2294, 255.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 288/2039, 288.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 228/1751, 228.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 291/1523, 291.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 275/1232, 275.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 230/957, 230.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 237/727, 237.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 196/490, 196.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 119/294, 119.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 98/175, 98.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 0/77, 0.0 false (nan vs 0.1)
# Could not filter
# Linear filter...
# Filtered out 655/19982, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/19327, 0.0 false (nan vs 0.1)
# Could not filter
# ransacN 9991
# Linear filter...
# Filtered out 882/19984, 1.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/19102, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/19102, 0.0 false (nan vs 0.1)
# condition 19102 19102
# Could not filter
# Linear filter...
# Filtered out 1103/19984, 95.0 false (0.09 vs 0.1)
# Linear filter...
# Filtered out 240/18881, 132.0 false (0.55 vs 0.1)
# Linear filter...
# Filtered out 266/18641, 158.0 false (0.59 vs 0.1)
# Linear filter...
# Filtered out 200/18375, 126.0 false (0.63 vs 0.1)
# Linear filter...
# Filtered out 171/18175, 105.0 false (0.61 vs 0.1)
# Linear filter...
# Filtered out 198/18004, 140.0 false (0.71 vs 0.1)
# Linear filter...
# Filtered out 180/17806, 127.0 false (0.71 vs 0.1)
# Linear filter...
# Filtered out 139/17626, 98.0 false (0.71 vs 0.1)
# Linear filter...
# Filtered out 165/17487, 109.0 false (0.66 vs 0.1)
# Linear filter...
# Filtered out 121/17322, 80.0 false (0.66 vs 0.1)
# Linear filter...
# Filtered out 145/17201, 111.0 false (0.77 vs 0.1)
# Linear filter...
# Filtered out 118/17056, 86.0 false (0.73 vs 0.1)
# Linear filter...
# Filtered out 134/16938, 109.0 false (0.81 vs 0.1)
# Linear filter...
# Filtered out 135/16804, 108.0 false (0.80 vs 0.1)
# Linear filter...
# Filtered out 116/16669, 95.0 false (0.82 vs 0.1)
# Linear filter...
# Filtered out 98/16553, 83.0 false (0.85 vs 0.1)
# Linear filter...
# Filtered out 112/16455, 95.0 false (0.85 vs 0.1)
# Linear filter...
# Filtered out 74/16343, 61.0 false (0.82 vs 0.1)
# Linear filter...
# Filtered out 139/16269, 122.0 false (0.88 vs 0.1)
# Linear filter...
# Filtered out 81/16130, 70.0 false (0.86 vs 0.1)
# Linear filter...
# Filtered out 110/16049, 92.0 false (0.84 vs 0.1)
# Linear filter...
# Filtered out 92/15939, 80.0 false (0.87 vs 0.1)
# Linear filter...
# Filtered out 96/15847, 87.0 false (0.91 vs 0.1)
# Linear filter...
# Filtered out 87/15751, 75.0 false (0.86 vs 0.1)
# Linear filter...
# Filtered out 30/15664, 27.0 false (0.90 vs 0.1)
# Linear filter...
# Filtered out 95/15634, 82.0 false (0.86 vs 0.1)
# Linear filter...
# Filtered out 44/15539, 43.0 false (0.98 vs 0.1)
# Linear filter...
# Filtered out 50/15495, 44.0 false (0.88 vs 0.1)
# Linear filter...
# Filtered out 72/15445, 64.0 false (0.89 vs 0.1)
# Linear filter...
# Filtered out 121/15373, 114.0 false (0.94 vs 0.1)
# Linear filter...
# Filtered out 58/15252, 53.0 false (0.91 vs 0.1)
# Linear filter...
# Filtered out 86/15194, 81.0 false (0.94 vs 0.1)
# Linear filter...
# Filtered out 104/15108, 99.0 false (0.95 vs 0.1)
# Linear filter...
# Filtered out 36/15004, 35.0 false (0.97 vs 0.1)
# Linear filter...
# Filtered out 68/14968, 66.0 false (0.97 vs 0.1)
# Linear filter...
# Filtered out 75/14900, 72.0 false (0.96 vs 0.1)
# Linear filter...
# Filtered out 75/14825, 68.0 false (0.91 vs 0.1)
# Linear filter...
# Filtered out 78/14750, 77.0 false (0.99 vs 0.1)
# Linear filter...
# Filtered out 39/14672, 38.0 false (0.97 vs 0.1)
# Linear filter...
# Filtered out 50/14633, 48.0 false (0.96 vs 0.1)
# Linear filter...
# Filtered out 51/14583, 50.0 false (0.98 vs 0.1)
# Linear filter...
# Filtered out 95/14532, 93.0 false (0.98 vs 0.1)
# Linear filter...
# Filtered out 39/14437, 38.0 false (0.97 vs 0.1)
# Linear filter...
# Filtered out 49/14398, 48.0 false (0.98 vs 0.1)
# Linear filter...
# Filtered out 58/14349, 58.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 107/14291, 106.0 false (0.99 vs 0.1)
# Linear filter...
# Filtered out 52/14184, 51.0 false (0.98 vs 0.1)
# Linear filter...
# Filtered out 44/14132, 44.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 55/14088, 53.0 false (0.96 vs 0.1)
# Linear filter...
# Filtered out 33/14033, 33.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 58/14000, 57.0 false (0.98 vs 0.1)
# Linear filter...
# Filtered out 62/13942, 60.0 false (0.97 vs 0.1)
# Linear filter...
# Filtered out 45/13880, 45.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 33/13835, 33.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 74/13802, 73.0 false (0.99 vs 0.1)
# Linear filter...
# Filtered out 67/13728, 67.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 78/13661, 78.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 84/13583, 82.0 false (0.98 vs 0.1)
# Linear filter...
# Filtered out 77/13499, 73.0 false (0.95 vs 0.1)
# Linear filter...
# Filtered out 63/13422, 61.0 false (0.97 vs 0.1)
# Linear filter...
# Filtered out 94/13359, 92.0 false (0.98 vs 0.1)
# Linear filter...
# Filtered out 42/13265, 42.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 21/13223, 21.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 47/13202, 46.0 false (0.98 vs 0.1)
# Linear filter...
# Filtered out 85/13155, 84.0 false (0.99 vs 0.1)
# Linear filter...
# Filtered out 70/13070, 68.0 false (0.97 vs 0.1)
# Linear filter...
# Filtered out 15/13000, 15.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 45/12985, 43.0 false (0.96 vs 0.1)
# Linear filter...
# Filtered out 26/12940, 26.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 95/12914, 95.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 80/12819, 80.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 55/12739, 55.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 48/12684, 47.0 false (0.98 vs 0.1)
# Linear filter...
# Filtered out 61/12636, 60.0 false (0.98 vs 0.1)
# Linear filter...
# Filtered out 50/12575, 50.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 43/12525, 43.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 72/12482, 71.0 false (0.99 vs 0.1)
# Linear filter...
# Filtered out 78/12410, 77.0 false (0.99 vs 0.1)
# Linear filter...
# Filtered out 53/12332, 52.0 false (0.98 vs 0.1)
# Linear filter...
# Filtered out 78/12279, 78.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 98/12201, 98.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 65/12103, 64.0 false (0.98 vs 0.1)
# Linear filter...
# Filtered out 46/12038, 46.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 60/11992, 60.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 61/11932, 61.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 106/11871, 104.0 false (0.98 vs 0.1)
# Linear filter...
# Filtered out 26/11765, 26.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 60/11739, 60.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 65/11679, 65.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 51/11614, 51.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 75/11563, 75.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 102/11488, 102.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 75/11386, 75.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 109/11311, 109.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 95/11202, 95.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 67/11107, 67.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 82/11040, 82.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 73/10958, 73.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 82/10885, 82.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 57/10803, 57.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 74/10746, 74.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 70/10672, 70.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 91/10602, 91.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 56/10511, 55.0 false (0.98 vs 0.1)
# Linear filter...
# Filtered out 95/10455, 95.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 55/10360, 55.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 48/10305, 48.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 69/10257, 69.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 111/10188, 111.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 72/10077, 72.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 60/10005, 60.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 97/9945, 97.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 61/9848, 61.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 125/9787, 125.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 64/9662, 64.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 91/9598, 91.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 91/9507, 91.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 66/9416, 66.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 93/9350, 93.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 27/9257, 27.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 69/9230, 69.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 114/9161, 114.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 114/9047, 114.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 126/8933, 126.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 116/8807, 116.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 86/8691, 86.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 102/8605, 102.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 116/8503, 116.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 110/8387, 110.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 91/8277, 91.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 117/8186, 117.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 85/8069, 85.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 91/7984, 91.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 165/7893, 165.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 128/7728, 128.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 96/7600, 96.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 104/7504, 104.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 104/7400, 104.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 95/7296, 95.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 104/7201, 104.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 104/7097, 104.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 119/6993, 119.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 123/6874, 123.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 83/6751, 83.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 107/6668, 107.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 177/6561, 177.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 149/6384, 149.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 150/6235, 150.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 128/6085, 128.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 107/5957, 107.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 148/5850, 148.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 205/5702, 205.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 203/5497, 203.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 160/5294, 160.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 193/5134, 193.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 217/4941, 217.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 188/4724, 188.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 201/4536, 201.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 197/4335, 197.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 212/4138, 212.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 203/3926, 203.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 219/3723, 219.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 225/3504, 225.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 210/3279, 210.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 245/3069, 245.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 259/2824, 259.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 246/2565, 246.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 234/2319, 234.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 231/2085, 231.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 254/1854, 254.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 270/1600, 270.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 250/1330, 250.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 237/1080, 237.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 235/843, 235.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 194/608, 194.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 174/414, 174.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 121/240, 121.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 67/119, 67.0 false (1.00 vs 0.1)
# Linear filter...
# Filtered out 0/52, 0.0 false (nan vs 0.1)
# Could not filter
# Linear filter...
# Filtered out 882/19984, 1.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/19102, 0.0 false (nan vs 0.1)
# Could not filter
# ransacN 9992

# %%
plot_m_loss.plotxy('k', k_bounds, (0,4))
# Out:
# <style>
#
# </style>
#
# <div id="fig_el56517348043820164750440373"></div>
# <script>
# function mpld3_load_lib(url, callback){
#   var s = document.createElement('script');
#   s.src = url;
#   s.async = true;
#   s.onreadystatechange = s.onload = callback;
#   s.onerror = function(){console.warn("failed to load library " + url);};
#   document.getElementsByTagName("head")[0].appendChild(s);
# }
#
# if(typeof(mpld3) !== "undefined" && mpld3._mpld3IsLoaded){
#    // already loaded: just create the figure
#    !function(mpld3){
#
#        mpld3.draw_figure("fig_el56517348043820164750440373", {"width": 432.0, "height": 288.0, "axes": [], "data": {}, "id": "el5651734804382016", "plugins": [{"type": "reset"}, {"type": "zoom", "button": true, "enabled": false}, {"type": "boxzoom", "button": true, "enabled": false}]});
#    }(mpld3);
# }else if(typeof define === "function" && define.amd){
#    // require.js is available: use it to load d3/mpld3
#    require.config({paths: {d3: "https://mpld3.github.io/js/d3.v3.min"}});
#    require(["d3"], function(d3){
#       window.d3 = d3;
#       mpld3_load_lib("https://mpld3.github.io/js/mpld3.v0.3.1.dev1.js", function(){
#
#          mpld3.draw_figure("fig_el56517348043820164750440373", {"width": 432.0, "height": 288.0, "axes": [], "data": {}, "id": "el5651734804382016", "plugins": [{"type": "reset"}, {"type": "zoom", "button": true, "enabled": false}, {"type": "boxzoom", "button": true, "enabled": false}]});
#       });
#     });
# }else{
#     // require.js not available: dynamically load d3 & mpld3
#     mpld3_load_lib("https://mpld3.github.io/js/d3.v3.min.js", function(){
#          mpld3_load_lib("https://mpld3.github.io/js/mpld3.v0.3.1.dev1.js", function(){
#
#                  mpld3.draw_figure("fig_el56517348043820164750440373", {"width": 432.0, "height": 288.0, "axes": [], "data": {}, "id": "el5651734804382016", "plugins": [{"type": "reset"}, {"type": "zoom", "button": true, "enabled": false}, {"type": "boxzoom", "button": true, "enabled": false}]});
#             })
#          });
# }
# </script>

# %%
"<<<< ALL RELEVANT PLOTS SHOULD BE ABOVE >>>>"
# Out:
# '<<<< ALL RELEVANT PLOTS SHOULD BE ABOVE >>>>'

# %%
d = 100
k = 70
eps = 0.1
tau = 0.02 # Failure prob
# sample_size = int(4*((k**2)*np.log(d) + np.log(1/tau))*(1/eps**2))
m = 9000

true_mean = np.append(np.ones(k), np.zeros(d-k))
false_mean = np.append(np.zeros(d-k), np.ones(k))

tm = np.append(np.ones(k), np.zeros(d-k))
fm = np.append(np.zeros(d-k), np.ones(k))

cov = 2*np.identity(d) - np.diag(tm)

G = np.random.randn(m, d) + tm/LA.norm(tm)
G2 = np.random.multivariate_normal(np.zeros(d), cov, (m,))
G1 = np.random.multivariate_normal(np.zeros(d), cov, (m,))

# G1 = np.random.multivariate_normal(np.zeros(d), cov, (sample_size,))



print(G.shape)
S = G.copy()

indicator = np.zeros(len(S))
L = int(m*(1-eps))
M = int((L + m)/2)

S[L:M] = G1[L:M]
S[M:] = G2[M:]

# S[int(sample_size*(1-eps)):] += false_mean - true_mean
# S[int(sample_size*(1-eps)):] = true_mean + 4.1
indicator[:L] = 1
# print(sum(indicator))
# print(len(indicator))
# print(indicator)
# print(len(S))

params = S, indicator, k, eps, tau
# params =  (G.copy(), S.copy(), indicator, m, d, eps, tau)

# %%
il.reload(rl)
# print("Dense mean estimation:", LA.norm(true_mean - rl.RME(params, plot=1)))
# print("Linear only:", LA.norm(true_mean - rl.RME_sp_L(params, plotl=1, plotc=0)))
# ans = rl.RME_sp_L(params, plotl=0, plotc=0)
print("Quadratic:", LA.norm(tm/LA.norm(tm) - rl.RME_sp(params, plotl=0, plotc=1, fdr=0.3)))
ans = rl.RME_sp(params, plotl=0, plotc=1, fdr=0.9)
print("fraction of zeros", len(ans[ans==0])/len(ans))
# print(tm)
# print("Ransac", LA.norm(true_mean - rl.ransacGaussianMean(params)))

# %%
plt.close()

# %%
il.reload(rl)

s = 10
m = 100
params = (3, m, 0.2, 0.02)
bounds = (5, 10, 10)
Runs = [rl.sparse_eps(params, bounds) for i in range(s)]

# %%
# fig1, ax1 = plt.subplots()
cols = {'RME_sp':'b', 'RME_sp_L':'g', 'RME':'r'}
for key in ['RME_sp', 'RME_sp_L']:#,'rl.ransacGaussianMean']:
#     for d in bounds[2]*np.arange(bounds[0], bounds[1]):

#         ax1.boxplot(np.array([res[key+str(eps)] for res in Runs]).transpose(), showfliers=False, whis = 0)
    A = np.array([res[key] for res in Runs])
    plt.plot(bounds[2]*np.arange(bounds[0], bounds[1]), np.array(np.median(A,axis = 0)), label=key, color = cols[key])
    mins = [np.sort(x)[int(s*0.25)] for x in A.T]
    maxs = [np.sort(x)[int(s*0.75)] for x in A.T]
    plt.fill_between(bounds[2]*np.arange(bounds[0], bounds[1]), mins, maxs, color=cols[key], alpha=0.2)
plt.title('k={}, naive filter algorithm'.format(params[0]))
plt.xlabel('dimension')
plt.ylabel('L2 - loss, scaled by eps')
plt.legend()

# for key in ['RME_sp', 'oracle', 'NP_sp']:
    
#     x = []
#     for d in  bounds[2]*np.arange(bounds[0], bounds[1]):
#         x.append(res[key+str(d)])
#     plt.plot(bounds[2]*np.arange(bounds[0], bounds[1]), x, label=key)

# #plt.plot(bounds[2]*np.arange(bounds[0], bounds[1]),np.sqrt(bounds[2]*np.arange(bounds[0], bounds[1])), label='sqrt')
# plt.title('k={}, naive filter algorithm'.format(params[0]))
# plt.xlabel('dimension')
# plt.ylabel('L2 - loss, scaled by eps')
# plt.legend()

# %%
il.reload(rl)
d = 100
k = 10
eps = 0.1
m = 100
s = 10

params = (d, k, m, eps, 0.02)
bounds = (0, 0.9, 0.1)
Runs = [rl.sparse_eps_dist(params, bounds) for i in range(s)]

# %%
cols = {'RME_sp':'b', 'RME_sp_L':'g', 'RME':'r'}
for key in ['RME_sp', 'RME_sp_L']:#,'rl.ransacGaussianMean']:
#     for d in bounds[2]*np.arange(bounds[0], bounds[1]):

#         ax1.boxplot(np.array([res[key+str(eps)] for res in Runs]).transpose(), showfliers=False, whis = 0)
    A = np.array([res[key] for res in Runs])
    plt.plot(np.arange(bounds[0], bounds[1], bounds[2]), np.array(np.median(A,axis = 0)), label=key, color = cols[key])
    mins = [np.sort(x)[int(s*0.25)] for x in A.T]
    maxs = [np.sort(x)[int(s*0.75)] for x in A.T]
    plt.fill_between(np.arange(bounds[0], bounds[1], bounds[2]), mins, maxs, color=cols[key], alpha=0.2)
plt.title('d = {}, k = {}, m = {}, eps = {}'.format(params[0], params[1], params[2], params[3]))
plt.xlabel('distance')
plt.ylabel('(loss)/eps')
plt.legend()



# for key in ['rl.RME_sp','rl.NP_sp', 'rl.ransacGaussianMean']:
#     x = []
#     for d in np.arange(bounds[0], bounds[1], bounds[2]):
#         x.append(np.array(res[key+str(d)]) - np.array(res['oracle'+str(d)]))
#     plt.plot(np.arange(bounds[0], bounds[1], bounds[2]), x, label=key)

# plt.title('d = {}, k = {}, m = {}, eps = {}'.format(params[0], params[1], params[2], params[3]))
# plt.xlabel('distance')
# plt.ylabel('(loss-(oracle loss))/eps')
# plt.legend()

# %%
def sparse_eps_eta(params, step): 
    (d, k, m, dist, tau) = params
    
    results = {}

    for eps in np.arange(step, 0.5, step):
        
        true_mean = np.append(np.ones(k),np.zeros(d-k))
#        true_mean = 0
        G = np.random.randn(m, d) + true_mean

        true_mean = np.append(np.ones(k),np.zeros(d-k))
        false_mean = np.append(np.zeros(d-k), np.ones(k))
#        true_mean = 0
        G = np.random.randn(m, d) + true_mean

        S = G.copy()
#        S[int(m*(1-eps)):] = true_mean + dist
        S[int(m*(1-eps)):] += dist*false_mean + true_mean
        indicator = np.ones(len(S))
        indicator[int(m*(1-eps)):] = 0

        params = (S.copy(), indicator, k, eps, tau)

        mu_o = np.mean(S[:int(m*(1-eps))], axis=0)
        u2 = np.argpartition(mu_o, -k)[-k:]
        z = np.zeros(len(mu_o))
        z[u2] = mu_o[u2]

        O = LA.norm(true_mean - z)

        # for func in [RME_sp, NP_sp]:
        # ... func(params)
        # Option 1: set RME_sp.name = 'RME_sp' somewhere, use func.name
        # Option 2: func.__name__
        
        for key in ['rl.RME_sp_L', 'rl.NP_sp', 'rl.ransacGaussianMean']:
            results.setdefault(key, []).append(LA.norm(true_mean - eval(key+'(params)')))

        results.setdefault('oracle', []).append(O)
        results.setdefault('eps', []).append(eps)
    
    return results

# %%
d = 10
k = 5
tau = 0.02
m = int(4*((k**2)*np.log(d) + np.log(1/tau))*(1/eps**2))
dist = 2
params = (d, k, m, dist, tau)
step = 0.01
res = sparse_eps_eta(params, step)

# %%
for key in ['rl.RME_sp_L', 'rl.NP_sp', 'rl.ransacGaussianMean']:
#     x = []
#     for d in np.arange(step, 0.5, step):
#         x.append(res[key+str(d)])
    plt.plot(np.arange(step, 0.5, step), (np.array(res[key])-np.array(res['oracle'])), label=key)

plt.title('d = {}, k = {}, m = {}, dist = {}'.format(params[0], params[1], params[2], params[3]))
plt.xlabel('eps')
plt.ylabel('(loss-(oracle loss))')
plt.legend()

# %%
def sparse_icml2017(params, bounds, toggle=0):
    (k, eps, tau) = params
    (Low, Up, step) = bounds
    
    results = {}

    for d in np.arange(Low, Up, step):
        
        m = int(4*((k**2)*np.log(d) + np.log(1/tau))*(1/eps**2))
        G, S = rl.ICML2017Noise_sp(d, k, m, eps,toggle)
        true_mean = np.append(np.ones(k), np.zeros(d-k))
        params = (S.copy(), eps, k, m, d, tau)
        
        mu_o = np.mean(S[:int(m*(1-eps))], axis=0)
        u2 = np.argpartition(mu_o, -k)[-k:]
        z = np.zeros(len(mu_o))
        z[u2] = mu_o[u2]

        O = LA.norm(true_mean - z)
        
        for key in ['RME_sp', 'NP_sp']:
            results.setdefault(key+str(d), []).append(LA.norm(true_mean - eval(key+'(params)'))/eps)

        results.setdefault('oracle'+str(d), []).append(O/eps)
        results.setdefault('eps'+str(d), []).append(1)
    
    return results

# %%
params = (3, 0.2, 0.02)
bounds = (10,4000,500)
res = sparse_icml2017(params, bounds, toggle=0)

# %%
for key in ['RME_sp', 'NP_sp', 'oracle']:
    x = []
    for d in np.arange(bounds[0], bounds[1], bounds[2]):
        x.append(res[key+str(d)])
    plt.plot(np.arange(bounds[0], bounds[1], bounds[2]), x, label=key)

plt.title('k={} naive filter algorithm on ICML2017 data'.format(params[0]))
plt.xlabel('dimension')
plt.ylabel('L2 - loss, scaled by eps')
plt.legend()

# %%
d = 2000
k = 3
eps = 0.2
m = int(4*((k**2)*np.log(d) + np.log(1/tau))*(1/eps**2))
G, S = rl.ICML2017Noise_sp(d, k, m, eps,toggle=0)
true_mean = np.append(np.ones(k), np.zeros(d-k))
params = (S.copy(), eps, k, m, d, tau)
